# %%
import pandas as pd
import ast

df = pd.read_csv('IPL_dataset_cleaned.csv',index_col = 'ID')
df.head()

# string to list of string
for idx, match in df.iterrows():
    if isinstance(match['Team1Players'], str):
        df.at[idx, 'Team1Players'] = ast.literal_eval(match['Team1Players'])
    if isinstance(match['Team2Players'], str):
        df.at[idx, 'Team2Players'] = ast.literal_eval(match['Team2Players'])
df.head()
# Out:
#               City        Date Season  MatchNumber  \
# ID
# 1312200  Ahmedabad  2022-05-29   2022        Final
# 1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 1312198    Kolkata  2022-05-25   2022   Eliminator
# 1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 1304116     Mumbai  2022-05-22   2022           70
#
#                                Team1                 Team2  \
# ID
# 1312200             Rajasthan Royals        Gujarat Titans
# 1312199  Royal Challengers Bangalore      Rajasthan Royals
# 1312198  Royal Challengers Bangalore  Lucknow Super Giants
# 1312197             Rajasthan Royals        Gujarat Titans
# 1304116          Sunrisers Hyderabad          Punjab Kings
#
#                                     Venue            TossWinner TossDecision  \
# ID
# 1312200  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1312199  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 1312198             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 1312197             Eden Gardens, Kolkata        Gujarat Titans        field
# 1304116          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#         SuperOver                  WinningTeam    WonBy  Margin    method  \
# ID
# 1312200         N               Gujarat Titans  Wickets     7.0  Standard
# 1312199         N             Rajasthan Royals  Wickets     7.0  Standard
# 1312198         N  Royal Challengers Bangalore     Runs    14.0  Standard
# 1312197         N               Gujarat Titans  Wickets     7.0  Standard
# 1304116         N                 Punjab Kings  Wickets     5.0  Standard
#
#         Player_of_Match                                       Team1Players  \
# ID
# 1312200       HH Pandya  [YBK Jaiswal, JC Buttler, SV Samson, D Padikka...
# 1312199      JC Buttler  [V Kohli, F du Plessis, RM Patidar, GJ Maxwell...
# 1312198      RM Patidar  [V Kohli, F du Plessis, RM Patidar, GJ Maxwell...
# 1312197       DA Miller  [YBK Jaiswal, JC Buttler, SV Samson, D Padikka...
# 1304116   Harpreet Brar  [PK Garg, Abhishek Sharma, RA Tripathi, AK Mar...
#
#                                               Team2Players        Umpire1  \
# ID
# 1312200  [WP Saha, Shubman Gill, MS Wade, HH Pandya, DA...    CB Gaffaney
# 1312199  [YBK Jaiswal, JC Buttler, SV Samson, D Padikka...    CB Gaffaney
# 1312198  [Q de Kock, KL Rahul, M Vohra, DJ Hooda, MP St...  J Madanagopal
# 1312197  [WP Saha, Shubman Gill, MS Wade, HH Pandya, DA...   BNJ Oxenford
# 1304116  [JM Bairstow, S Dhawan, M Shahrukh Khan, MA Ag...   AK Chaudhary
#
#                Umpire2
# ID
# 1312200    Nitin Menon
# 1312199    Nitin Menon
# 1312198       MA Gough
# 1312197      VK Sharma
# 1304116  NA Patwardhan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 950 entries, 1312200 to 335982
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             950 non-null    object
#  1   Date             950 non-null    object
#  2   Season           950 non-null    object
#  3   MatchNumber      950 non-null    object
#  4   Team1            950 non-null    object
#  5   Team2            950 non-null    object
#  6   Venue            950 non-null    object
#  7   TossWinner       950 non-null    object
#  8   TossDecision     950 non-null    object
#  9   SuperOver        950 non-null    object
#  10  WinningTeam      950 non-null    object
#  11  WonBy            950 non-null    object
#  12  Margin           950 non-null    float64
#  13  method           950 non-null    object
#  14  Player_of_Match  950 non-null    object
#  15  Team1Players     950 non-null    object
#  16  Team2Players     950 non-null    object
#  17  Umpire1          950 non-null    object
#  18  Umpire2          950 non-null    object
# dtypes: float64(1), object(18)
# memory usage: 180.7+ KB

# %%
df.isna().sum()
# Out:
# City               0
# Date               0
# Season             0
# MatchNumber        0
# Team1              0
# Team2              0
# Venue              0
# TossWinner         0
# TossDecision       0
# SuperOver          0
# WinningTeam        0
# WonBy              0
# Margin             0
# method             0
# Player_of_Match    0
# Team1Players       0
# Team2Players       0
# Umpire1            0
# Umpire2            0
# dtype: int64

# %%
id = 1312200
try:
    print(df.loc[[id]])
except Exception as e:
    print(str(e))
# Out:
#               City        Date Season MatchNumber             Team1  \
# ID
# 1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#                   Team2                             Venue        TossWinner  \
# ID
# 1312200  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#         TossDecision SuperOver     WinningTeam    WonBy  Margin    method  \
# ID
# 1312200          bat         N  Gujarat Titans  Wickets     7.0  Standard
#
#         Player_of_Match                                       Team1Players  \
# ID
# 1312200       HH Pandya  [YBK Jaiswal, JC Buttler, SV Samson, D Padikka...
#
#                                               Team2Players      Umpire1  \
# ID
# 1312200  [WP Saha, Shubman Gill, MS Wade, HH Pandya, DA...  CB Gaffaney
#
#              Umpire2
# ID
# 1312200  Nitin Menon

# %% [markdown]
# ## teams names

# %%
def teams():
    return {'teams' : list(set(list(df['Team1'])+list(df['Team2'])))}

teams()
# Out:
# {'teams': ['Kings XI Punjab',
#   'Kochi Tuskers Kerala',
#   'Deccan Chargers',
#   'Punjab Kings',
#   'Kolkata Knight Riders',
#   'Gujarat Lions',
#   'Rajasthan Royals',
#   'Mumbai Indians',
#   'Royal Challengers Bangalore',
#   'Delhi Capitals',
#   'Sunrisers Hyderabad',
#   'Lucknow Super Giants',
#   'Delhi Daredevils',
#   'Chennai Super Kings',
#   'Rising Pune Supergiants',
#   'Pune Warriors',
#   'Gujarat Titans']}

# %% [markdown]
# # match summury by ID

# %%
def match_summury(ID):
    try:
        x = df.loc[[ID]]
        return list(x.to_dict())
    except Exception as e:
        return {"error": "Match not found"}

# %%
match_summury(131220)
# Out:
# {'error': 'Match not found'}

# %% [markdown]
# ## match won by team

# %%
def match_won_by_team(team):
    matches = []
    for index,match in df.iterrows():
        if match['WinningTeam'] == team:
            matches.append({
                'Against' : match['Team1'] if team==match['Team2'] else match['Team2'], 
                'Venue' : match['Venue'],
                'TossWinner' : match['TossWinner'],   
                'TossDecision' : match['TossDecision'],
                'SuperOver' : 'No' if match['SuperOver']=='N' else 'Yes',
                'WonBy' : match['WonBy'],
                'Margin' : match['Margin'],   
                'Player_of_Match' : match['Player_of_Match'],   
                f'{match["Team1"]}' : match['Team1Players'],    
                f'{match["Team2"]}' : match['Team2Players'],  
                'Umpire1' : match['Umpire1'],
                'Umpire2' : match['Umpire2']
            })
    if len(matches) > 0:
        return {'Winnig Matches' : matches}
    return {'error':'does not won any match'}

# %%
match_won_by_team('Rajasthan Royals')
# Out:
# {'Winnig Matches': [{'Against': 'Royal Challengers Bangalore',
#    'Venue': 'Narendra Modi Stadium, Ahmedabad',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 7.0,
#    'Player_of_Match': 'JC Buttler',
#    'Royal Challengers Bangalore': ['V Kohli',
#     'F du Plessis',
#     'RM Patidar',
#     'GJ Maxwell',
#     'MK Lomror',
#     'KD Karthik',
#     'Shahbaz Ahmed',
#     'PWH de Silva',
#     'HV Patel',
#     'JR Hazlewood',
#     'Mohammed Siraj'],
#    'Rajasthan Royals': ['YBK Jaiswal',
#     'JC Buttler',
#     'SV Samson',
#     'D Padikkal',
#     'SO Hetmyer',
#     'R Parag',
#     'R Ashwin',
#     'TA Boult',
#     'YS Chahal',
#     'M Prasidh Krishna',
#     'OC McCoy'],
#    'Umpire1': 'CB Gaffaney',
#    'Umpire2': 'Nitin Menon'},
#   {'Against': 'Chennai Super Kings',
#    'Venue': 'Brabourne Stadium, Mumbai',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 5.0,
#    'Player_of_Match': 'R Ashwin',
#    'Chennai Super Kings': ['RD Gaikwad',
#     'DP Conway',
#     'MM Ali',
#     'N Jagadeesan',
#     'AT Rayudu',
#     'MS Dhoni',
#     'MJ Santner',
#     'Simarjeet Singh',
#     'Mukesh Choudhary',
#     'PH Solanki',
#     'M Pathirana'],
#    'Rajasthan Royals': ['YBK Jaiswal',
#     'JC Buttler',
#     'SV Samson',
#     'D Padikkal',
#     'R Ashwin',
#     'SO Hetmyer',
#     'R Parag',
#     'TA Boult',
#     'YS Chahal',
#     'M Prasidh Krishna',
#     'OC McCoy'],
#    'Umpire1': 'CB Gaffaney',
#    'Umpire2': 'NA Patwardhan'},
#   {'Against': 'Lucknow Super Giants',
#    'Venue': 'Brabourne Stadium, Mumbai',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 24.0,
#    'Player_of_Match': 'TA Boult',
#    'Rajasthan Royals': ['YBK Jaiswal',
#     'JC Buttler',
#     'SV Samson',
#     'D Padikkal',
#     'R Parag',
#     'JDS Neesham',
#     'R Ashwin',
#     'TA Boult',
#     'M Prasidh Krishna',
#     'YS Chahal',
#     'OC McCoy'],
#    'Lucknow Super Giants': ['Q de Kock',
#     'KL Rahul',
#     'A Badoni',
#     'DJ Hooda',
#     'KH Pandya',
#     'MP Stoinis',
#     'JO Holder',
#     'PVD Chameera',
#     'Mohsin Khan',
#     'Avesh Khan',
#     'Ravi Bishnoi'],
#    'Umpire1': 'PG Pathak',
#    'Umpire2': 'Tapan Sharma'},
#   {'Against': 'Punjab Kings',
#    'Venue': 'Wankhede Stadium, Mumbai',
#    'TossWinner': 'Punjab Kings',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 6.0,
#    'Player_of_Match': 'YBK Jaiswal',
#    'Punjab Kings': ['JM Bairstow',
#     'S Dhawan',
#     'PBB Rajapaksa',
#     'MA Agarwal',
#     'JM Sharma',
#     'LS Livingstone',
#     'R Dhawan',
#     'K Rabada',
#     'RD Chahar',
#     'Arshdeep Singh',
#     'Sandeep Sharma'],
#    'Rajasthan Royals': ['YBK Jaiswal',
#     'JC Buttler',
#     'SV Samson',
#     'D Padikkal',
#     'SO Hetmyer',
#     'R Parag',
#     'R Ashwin',
#     'TA Boult',
#     'M Prasidh Krishna',
#     'YS Chahal',
#     'KR Sen'],
#    'Umpire1': 'Chirra Ravikanthreddy',
#    'Umpire2': 'YC Barde'},
#   {'Against': 'Royal Challengers Bangalore',
#    'Venue': 'Maharashtra Cricket Association Stadium, Pune',
#    'TossWinner': 'Royal Challengers Bangalore',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 29.0,
#    'Player_of_Match': 'R Parag',
#    'Rajasthan Royals': ['JC Buttler',
#     'D Padikkal',
#     'R Ashwin',
#     'SV Samson',
#     'DJ Mitchell',
#     'R Parag',
#     'SO Hetmyer',
#     'TA Boult',
#     'M Prasidh Krishna',
#     'YS Chahal',
#     'KR Sen'],
#    'Royal Challengers Bangalore': ['V Kohli',
#     'F du Plessis',
#     'RM Patidar',
#     'GJ Maxwell',
#     'Shahbaz Ahmed',
#     'SS Prabhudessai',
#     'KD Karthik',
#     'PWH de Silva',
#     'HV Patel',
#     'Mohammed Siraj',
#     'JR Hazlewood'],
#    'Umpire1': 'BNJ Oxenford',
#    'Umpire2': 'KN Ananthapadmanabhan'},
#   {'Against': 'Delhi Capitals',
#    'Venue': 'Wankhede Stadium, Mumbai',
#    'TossWinner': 'Delhi Capitals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 15.0,
#    'Player_of_Match': 'JC Buttler',
#    'Rajasthan Royals': ['JC Buttler',
#     'D Padikkal',
#     'SV Samson',
#     'SO Hetmyer',
#     'R Parag',
#     'KK Nair',
#     'R Ashwin',
#     'TA Boult',
#     'OC McCoy',
#     'M Prasidh Krishna',
#     'YS Chahal'],
#    'Delhi Capitals': ['PP Shaw',
#     'DA Warner',
#     'SN Khan',
#     'RR Pant',
#     'Lalit Yadav',
#     'AR Patel',
#     'SN Thakur',
#     'R Powell',
#     'Kuldeep Yadav',
#     'Mustafizur Rahman',
#     'KK Ahmed'],
#    'Umpire1': 'NA Patwardhan',
#    'Umpire2': 'Nitin Menon'},
#   {'Against': 'Kolkata Knight Riders',
#    'Venue': 'Brabourne Stadium, Mumbai',
#    'TossWinner': 'Kolkata Knight Riders',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 7.0,
#    'Player_of_Match': 'YS Chahal',
#    'Rajasthan Royals': ['JC Buttler',
#     'D Padikkal',
#     'SV Samson',
#     'SO Hetmyer',
#     'R Parag',
#     'KK Nair',
#     'R Ashwin',
#     'TA Boult',
#     'OC McCoy',
#     'M Prasidh Krishna',
#     'YS Chahal'],
#    'Kolkata Knight Riders': ['AJ Finch',
#     'SP Narine',
#     'SS Iyer',
#     'N Rana',
#     'AD Russell',
#     'VR Iyer',
#     'SP Jackson',
#     'Shivam Mavi',
#     'PJ Cummins',
#     'UT Yadav',
#     'CV Varun'],
#    'Umpire1': 'GR Sadashiv Iyer',
#    'Umpire2': 'VK Sharma'},
#   {'Against': 'Lucknow Super Giants',
#    'Venue': 'Wankhede Stadium, Mumbai',
#    'TossWinner': 'Lucknow Super Giants',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 3.0,
#    'Player_of_Match': 'YS Chahal',
#    'Rajasthan Royals': ['JC Buttler',
#     'D Padikkal',
#     'SV Samson',
#     'HE van der Dussen',
#     'SO Hetmyer',
#     'R Ashwin',
#     'R Parag',
#     'TA Boult',
#     'YS Chahal',
#     'KR Sen',
#     'M Prasidh Krishna'],
#    'Lucknow Super Giants': ['KL Rahul',
#     'Q de Kock',
#     'K Gowtham',
#     'JO Holder',
#     'DJ Hooda',
#     'A Badoni',
#     'KH Pandya',
#     'MP Stoinis',
#     'PVD Chameera',
#     'Avesh Khan',
#     'Ravi Bishnoi'],
#    'Umpire1': 'AK Chaudhary',
#    'Umpire2': 'Tapan Sharma'},
#   {'Against': 'Mumbai Indians',
#    'Venue': 'Dr DY Patil Sports Academy, Mumbai',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 23.0,
#    'Player_of_Match': 'JC Buttler',
#    'Rajasthan Royals': ['JC Buttler',
#     'YBK Jaiswal',
#     'D Padikkal',
#     'SV Samson',
#     'SO Hetmyer',
#     'R Parag',
#     'R Ashwin',
#     'Navdeep Saini',
#     'TA Boult',
#     'YS Chahal',
#     'M Prasidh Krishna'],
#    'Mumbai Indians': ['Ishan Kishan',
#     'RG Sharma',
#     'Anmolpreet Singh',
#     'Tilak Varma',
#     'KA Pollard',
#     'TH David',
#     'DR Sams',
#     'M Ashwin',
#     'JJ Bumrah',
#     'TS Mills',
#     'Basil Thampi'],
#    'Umpire1': 'Nitin Menon',
#    'Umpire2': 'PG Pathak'},
#   {'Against': 'Sunrisers Hyderabad',
#    'Venue': 'Maharashtra Cricket Association Stadium, Pune',
#    'TossWinner': 'Sunrisers Hyderabad',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 61.0,
#    'Player_of_Match': 'SV Samson',
#    'Rajasthan Royals': ['JC Buttler',
#     'YBK Jaiswal',
#     'SV Samson',
#     'D Padikkal',
#     'SO Hetmyer',
#     'R Parag',
#     'NM Coulter-Nile',
#     'R Ashwin',
#     'YS Chahal',
#     'TA Boult',
#     'M Prasidh Krishna'],
#    'Sunrisers Hyderabad': ['KS Williamson',
#     'Abhishek Sharma',
#     'RA Tripathi',
#     'N Pooran',
#     'AK Markram',
#     'Abdul Samad',
#     'R Shepherd',
#     'Washington Sundar',
#     'B Kumar',
#     'Umran Malik',
#     'T Natarajan'],
#    'Umpire1': 'BNJ Oxenford',
#    'Umpire2': 'UV Gandhe'},
#   {'Against': 'Chennai Super Kings',
#    'Venue': 'Zayed Cricket Stadium, Abu Dhabi',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 7.0,
#    'Player_of_Match': 'RD Gaikwad',
#    'Chennai Super Kings': ['RD Gaikwad',
#     'F du Plessis',
#     'SK Raina',
#     'MM Ali',
#     'AT Rayudu',
#     'RA Jadeja',
#     'MS Dhoni',
#     'SM Curran',
#     'SN Thakur',
#     'JR Hazlewood',
#     'KM Asif'],
#    'Rajasthan Royals': ['E Lewis',
#     'YBK Jaiswal',
#     'SV Samson',
#     'S Dube',
#     'GD Phillips',
#     'DA Miller',
#     'R Tewatia',
#     'Akash Singh',
#     'M Markande',
#     'C Sakariya',
#     'Mustafizur Rahman'],
#    'Umpire1': 'CB Gaffaney',
#    'Umpire2': 'VK Sharma'},
#   {'Against': 'Punjab Kings',
#    'Venue': 'Dubai International Cricket Stadium',
#    'TossWinner': 'Punjab Kings',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 2.0,
#    'Player_of_Match': 'Kartik Tyagi',
#    'Rajasthan Royals': ['E Lewis',
#     'YBK Jaiswal',
#     'SV Samson',
#     'LS Livingstone',
#     'MK Lomror',
#     'R Parag',
#     'R Tewatia',
#     'CH Morris',
#     'C Sakariya',
#     'Kartik Tyagi',
#     'Mustafizur Rahman'],
#    'Punjab Kings': ['KL Rahul',
#     'MA Agarwal',
#     'AK Markram',
#     'N Pooran',
#     'DJ Hooda',
#     'FA Allen',
#     'IC Porel',
#     'AU Rashid',
#     'Harpreet Brar',
#     'Arshdeep Singh',
#     'Mohammed Shami'],
#    'Umpire1': 'AK Chaudhary',
#    'Umpire2': 'MA Gough'},
#   {'Against': 'Sunrisers Hyderabad',
#    'Venue': 'Arun Jaitley Stadium, Delhi',
#    'TossWinner': 'Sunrisers Hyderabad',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 55.0,
#    'Player_of_Match': 'JC Buttler',
#    'Rajasthan Royals': ['JC Buttler',
#     'YBK Jaiswal',
#     'SV Samson',
#     'R Parag',
#     'DA Miller',
#     'Anuj Rawat',
#     'R Tewatia',
#     'CH Morris',
#     'Kartik Tyagi',
#     'C Sakariya',
#     'Mustafizur Rahman'],
#    'Sunrisers Hyderabad': ['MK Pandey',
#     'JM Bairstow',
#     'KS Williamson',
#     'V Shankar',
#     'KM Jadhav',
#     'Mohammad Nabi',
#     'Abdul Samad',
#     'Rashid Khan',
#     'B Kumar',
#     'Sandeep Sharma',
#     'KK Ahmed'],
#    'Umpire1': 'C Shamshuddin',
#    'Umpire2': 'CB Gaffaney'},
#   {'Against': 'Kolkata Knight Riders',
#    'Venue': 'Wankhede Stadium, Mumbai',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 6.0,
#    'Player_of_Match': 'CH Morris',
#    'Kolkata Knight Riders': ['N Rana',
#     'Shubman Gill',
#     'RA Tripathi',
#     'SP Narine',
#     'EJG Morgan',
#     'KD Karthik',
#     'AD Russell',
#     'PJ Cummins',
#     'Shivam Mavi',
#     'M Prasidh Krishna',
#     'CV Varun'],
#    'Rajasthan Royals': ['JC Buttler',
#     'YBK Jaiswal',
#     'SV Samson',
#     'S Dube',
#     'R Tewatia',
#     'DA Miller',
#     'R Parag',
#     'CH Morris',
#     'JD Unadkat',
#     'C Sakariya',
#     'Mustafizur Rahman'],
#    'Umpire1': 'Navdeep Singh',
#    'Umpire2': 'S Ravi'},
#   {'Against': 'Delhi Capitals',
#    'Venue': 'Wankhede Stadium, Mumbai',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 3.0,
#    'Player_of_Match': 'JD Unadkat',
#    'Delhi Capitals': ['PP Shaw',
#     'S Dhawan',
#     'AM Rahane',
#     'RR Pant',
#     'MP Stoinis',
#     'Lalit Yadav',
#     'TK Curran',
#     'CR Woakes',
#     'R Ashwin',
#     'K Rabada',
#     'Avesh Khan'],
#    'Rajasthan Royals': ['JC Buttler',
#     'M Vohra',
#     'SV Samson',
#     'S Dube',
#     'DA Miller',
#     'R Parag',
#     'R Tewatia',
#     'CH Morris',
#     'JD Unadkat',
#     'C Sakariya',
#     'Mustafizur Rahman'],
#    'Umpire1': 'S Ravi',
#    'Umpire2': 'VK Sharma'},
#   {'Against': 'Kings XI Punjab',
#    'Venue': 'Sheikh Zayed Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 7.0,
#    'Player_of_Match': 'BA Stokes',
#    'Kings XI Punjab': ['KL Rahul',
#     'Mandeep Singh',
#     'CH Gayle',
#     'N Pooran',
#     'GJ Maxwell',
#     'DJ Hooda',
#     'CJ Jordan',
#     'M Ashwin',
#     'Ravi Bishnoi',
#     'Mohammed Shami',
#     'Arshdeep Singh'],
#    'Rajasthan Royals': ['RV Uthappa',
#     'BA Stokes',
#     'SV Samson',
#     'SPD Smith',
#     'JC Buttler',
#     'R Parag',
#     'R Tewatia',
#     'JC Archer',
#     'S Gopal',
#     'Kartik Tyagi',
#     'VR Aaron'],
#    'Umpire1': 'CB Gaffaney',
#    'Umpire2': 'S Ravi'},
#   {'Against': 'Mumbai Indians',
#    'Venue': 'Sheikh Zayed Stadium',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 8.0,
#    'Player_of_Match': 'BA Stokes',
#    'Mumbai Indians': ['Ishan Kishan',
#     'Q de Kock',
#     'SA Yadav',
#     'SS Tiwary',
#     'KA Pollard',
#     'HH Pandya',
#     'KH Pandya',
#     'JL Pattinson',
#     'RD Chahar',
#     'TA Boult',
#     'JJ Bumrah'],
#    'Rajasthan Royals': ['RV Uthappa',
#     'BA Stokes',
#     'SPD Smith',
#     'SV Samson',
#     'JC Buttler',
#     'R Parag',
#     'R Tewatia',
#     'JC Archer',
#     'S Gopal',
#     'AS Rajpoot',
#     'Kartik Tyagi'],
#    'Umpire1': 'UV Gandhe',
#    'Umpire2': 'VK Sharma'},
#   {'Against': 'Chennai Super Kings',
#    'Venue': 'Sheikh Zayed Stadium',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 7.0,
#    'Player_of_Match': 'JC Buttler',
#    'Chennai Super Kings': ['SM Curran',
#     'F du Plessis',
#     'SR Watson',
#     'AT Rayudu',
#     'MS Dhoni',
#     'RA Jadeja',
#     'KM Jadhav',
#     'PP Chawla',
#     'DL Chahar',
#     'SN Thakur',
#     'JR Hazlewood'],
#    'Rajasthan Royals': ['BA Stokes',
#     'RV Uthappa',
#     'SV Samson',
#     'SPD Smith',
#     'JC Buttler',
#     'R Tewatia',
#     'R Parag',
#     'JC Archer',
#     'S Gopal',
#     'AS Rajpoot',
#     'Kartik Tyagi'],
#    'Umpire1': 'CB Gaffaney',
#    'Umpire2': 'VK Sharma'},
#   {'Against': 'Sunrisers Hyderabad',
#    'Venue': 'Dubai International Cricket Stadium',
#    'TossWinner': 'Sunrisers Hyderabad',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 5.0,
#    'Player_of_Match': 'R Tewatia',
#    'Sunrisers Hyderabad': ['DA Warner',
#     'JM Bairstow',
#     'MK Pandey',
#     'KS Williamson',
#     'PK Garg',
#     'V Shankar',
#     'Abhishek Sharma',
#     'Rashid Khan',
#     'Sandeep Sharma',
#     'KK Ahmed',
#     'T Natarajan'],
#    'Rajasthan Royals': ['BA Stokes',
#     'JC Buttler',
#     'SPD Smith',
#     'SV Samson',
#     'RV Uthappa',
#     'R Parag',
#     'R Tewatia',
#     'JC Archer',
#     'S Gopal',
#     'JD Unadkat',
#     'Kartik Tyagi'],
#    'Umpire1': 'YC Barde',
#    'Umpire2': 'PR Reiffel'},
#   {'Against': 'Kings XI Punjab',
#    'Venue': 'Sharjah Cricket Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 4.0,
#    'Player_of_Match': 'SV Samson',
#    'Kings XI Punjab': ['KL Rahul',
#     'MA Agarwal',
#     'GJ Maxwell',
#     'N Pooran',
#     'KK Nair',
#     'JDS Neesham',
#     'SN Khan',
#     'Mohammed Shami',
#     'SS Cottrell',
#     'Ravi Bishnoi',
#     'M Ashwin'],
#    'Rajasthan Royals': ['JC Buttler',
#     'SPD Smith',
#     'SV Samson',
#     'R Tewatia',
#     'RV Uthappa',
#     'JC Archer',
#     'R Parag',
#     'TK Curran',
#     'S Gopal',
#     'AS Rajpoot',
#     'JD Unadkat'],
#    'Umpire1': 'RK Illingworth',
#    'Umpire2': 'K Srinivasan'},
#   {'Against': 'Chennai Super Kings',
#    'Venue': 'Sharjah Cricket Stadium',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 16.0,
#    'Player_of_Match': 'SV Samson',
#    'Rajasthan Royals': ['YBK Jaiswal',
#     'SPD Smith',
#     'SV Samson',
#     'DA Miller',
#     'RV Uthappa',
#     'R Tewatia',
#     'R Parag',
#     'TK Curran',
#     'JC Archer',
#     'S Gopal',
#     'JD Unadkat'],
#    'Chennai Super Kings': ['M Vijay',
#     'SR Watson',
#     'F du Plessis',
#     'SM Curran',
#     'RD Gaikwad',
#     'KM Jadhav',
#     'MS Dhoni',
#     'RA Jadeja',
#     'PP Chawla',
#     'DL Chahar',
#     'L Ngidi'],
#    'Umpire1': 'C Shamshuddin',
#    'Umpire2': 'VA Kulkarni'},
#   {'Against': 'Sunrisers Hyderabad',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 7.0,
#    'Player_of_Match': 'JD Unadkat',
#    'Sunrisers Hyderabad': ['DA Warner',
#     'KS Williamson',
#     'MK Pandey',
#     'V Shankar',
#     'Shakib Al Hasan',
#     'DJ Hooda',
#     'WP Saha',
#     'Rashid Khan',
#     'B Kumar',
#     'S Kaul',
#     'KK Ahmed'],
#    'Rajasthan Royals': ['AM Rahane',
#     'LS Livingstone',
#     'SV Samson',
#     'SPD Smith',
#     'AJ Turner',
#     'R Parag',
#     'STR Binny',
#     'S Gopal',
#     'JD Unadkat',
#     'VR Aaron',
#     'O Thomas'],
#    'Umpire1': 'A Nand Kishore',
#    'Umpire2': 'YC Barde'},
#   {'Against': 'Kolkata Knight Riders',
#    'Venue': 'Eden Gardens',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 3.0,
#    'Player_of_Match': 'VR Aaron',
#    'Kolkata Knight Riders': ['CA Lynn',
#     'Shubman Gill',
#     'N Rana',
#     'KD Karthik',
#     'SP Narine',
#     'AD Russell',
#     'CR Brathwaite',
#     'RK Singh',
#     'PP Chawla',
#     'Y Prithvi Raj',
#     'M Prasidh Krishna'],
#    'Rajasthan Royals': ['AM Rahane',
#     'SV Samson',
#     'SPD Smith',
#     'BA Stokes',
#     'R Parag',
#     'STR Binny',
#     'S Gopal',
#     'JC Archer',
#     'JD Unadkat',
#     'VR Aaron',
#     'O Thomas'],
#    'Umpire1': 'AY Dandekar',
#    'Umpire2': 'IJ Gould'},
#   {'Against': 'Mumbai Indians',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 5.0,
#    'Player_of_Match': 'SPD Smith',
#    'Mumbai Indians': ['Q de Kock',
#     'RG Sharma',
#     'SA Yadav',
#     'HH Pandya',
#     'KA Pollard',
#     'BCJ Cutting',
#     'KH Pandya',
#     'RD Chahar',
#     'JJ Bumrah',
#     'SL Malinga',
#     'M Markande'],
#    'Rajasthan Royals': ['AM Rahane',
#     'SV Samson',
#     'SPD Smith',
#     'BA Stokes',
#     'R Parag',
#     'AJ Turner',
#     'STR Binny',
#     'JC Archer',
#     'S Gopal',
#     'JD Unadkat',
#     'DS Kulkarni'],
#    'Umpire1': 'S Ravi',
#    'Umpire2': 'YC Barde'},
#   {'Against': 'Mumbai Indians',
#    'Venue': 'Wankhede Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 4.0,
#    'Player_of_Match': 'JC Buttler',
#    'Mumbai Indians': ['RG Sharma',
#     'Q de Kock',
#     'SA Yadav',
#     'KA Pollard',
#     'HH Pandya',
#     'Ishan Kishan',
#     'KH Pandya',
#     'AS Joseph',
#     'RD Chahar',
#     'JP Behrendorff',
#     'JJ Bumrah'],
#    'Rajasthan Royals': ['AM Rahane',
#     'JC Buttler',
#     'SV Samson',
#     'SPD Smith',
#     'RA Tripathi',
#     'LS Livingstone',
#     'S Gopal',
#     'K Gowtham',
#     'JC Archer',
#     'JD Unadkat',
#     'DS Kulkarni'],
#    'Umpire1': 'A Nand Kishore',
#    'Umpire2': 'Nitin Menon'},
#   {'Against': 'Royal Challengers Bangalore',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 7.0,
#    'Player_of_Match': 'S Gopal',
#    'Royal Challengers Bangalore': ['V Kohli',
#     'PA Patel',
#     'AB de Villiers',
#     'SO Hetmyer',
#     'MP Stoinis',
#     'MM Ali',
#     'AD Nath',
#     'UT Yadav',
#     'Navdeep Saini',
#     'YS Chahal',
#     'Mohammed Siraj'],
#    'Rajasthan Royals': ['AM Rahane',
#     'JC Buttler',
#     'SPD Smith',
#     'RA Tripathi',
#     'BA Stokes',
#     'STR Binny',
#     'K Gowtham',
#     'JC Archer',
#     'S Gopal',
#     'VR Aaron',
#     'DS Kulkarni'],
#    'Umpire1': 'AY Dandekar',
#    'Umpire2': 'M Erasmus'},
#   {'Against': 'Royal Challengers Bangalore',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 30.0,
#    'Player_of_Match': 'S Gopal',
#    'Rajasthan Royals': ['RA Tripathi',
#     'JC Archer',
#     'AM Rahane',
#     'SV Samson',
#     'H Klaasen',
#     'K Gowtham',
#     'STR Binny',
#     'S Gopal',
#     'IS Sodhi',
#     'JD Unadkat',
#     'B Laughlin'],
#    'Royal Challengers Bangalore': ['V Kohli',
#     'PA Patel',
#     'AB de Villiers',
#     'MM Ali',
#     'Mandeep Singh',
#     'C de Grandhomme',
#     'SN Khan',
#     'TG Southee',
#     'UT Yadav',
#     'Mohammed Siraj',
#     'YS Chahal'],
#    'Umpire1': 'BNJ Oxenford',
#    'Umpire2': 'VK Sharma'},
#   {'Against': 'Mumbai Indians',
#    'Venue': 'Wankhede Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 7.0,
#    'Player_of_Match': 'JC Buttler',
#    'Mumbai Indians': ['SA Yadav',
#     'E Lewis',
#     'RG Sharma',
#     'Ishan Kishan',
#     'HH Pandya',
#     'KH Pandya',
#     'BCJ Cutting',
#     'JP Duminy',
#     'MJ McClenaghan',
#     'M Markande',
#     'JJ Bumrah'],
#    'Rajasthan Royals': ['DJM Short',
#     'JC Buttler',
#     'AM Rahane',
#     'SV Samson',
#     'BA Stokes',
#     'STR Binny',
#     'JC Archer',
#     'K Gowtham',
#     'S Gopal',
#     'JD Unadkat',
#     'DS Kulkarni'],
#    'Umpire1': 'Nitin Menon',
#    'Umpire2': 'S Ravi'},
#   {'Against': 'Chennai Super Kings',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 4.0,
#    'Player_of_Match': 'JC Buttler',
#    'Chennai Super Kings': ['SR Watson',
#     'AT Rayudu',
#     'SK Raina',
#     'MS Dhoni',
#     'SW Billings',
#     'DJ Bravo',
#     'RA Jadeja',
#     'DJ Willey',
#     'Harbhajan Singh',
#     'SN Thakur',
#     'KV Sharma'],
#    'Rajasthan Royals': ['JC Buttler',
#     'BA Stokes',
#     'AM Rahane',
#     'SV Samson',
#     'P Chopra',
#     'STR Binny',
#     'K Gowtham',
#     'JC Archer',
#     'Ankit Sharma',
#     'JD Unadkat',
#     'IS Sodhi'],
#    'Umpire1': 'M Erasmus',
#    'Umpire2': 'YC Barde'},
#   {'Against': 'Kings XI Punjab',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 15.0,
#    'Player_of_Match': 'JC Buttler',
#    'Rajasthan Royals': ['AM Rahane',
#     'JC Buttler',
#     'K Gowtham',
#     'SV Samson',
#     'BA Stokes',
#     'STR Binny',
#     'MK Lomror',
#     'JC Archer',
#     'JD Unadkat',
#     'IS Sodhi',
#     'Anureet Singh'],
#    'Kings XI Punjab': ['KL Rahul',
#     'CH Gayle',
#     'R Ashwin',
#     'KK Nair',
#     'AD Nath',
#     'MK Tiwary',
#     'AR Patel',
#     'MP Stoinis',
#     'AJ Tye',
#     'MM Sharma',
#     'Mujeeb Ur Rahman'],
#    'Umpire1': 'M Erasmus',
#    'Umpire2': 'Nitin Menon'},
#   {'Against': 'Mumbai Indians',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 3.0,
#    'Player_of_Match': 'JC Archer',
#    'Mumbai Indians': ['SA Yadav',
#     'E Lewis',
#     'Ishan Kishan',
#     'KA Pollard',
#     'RG Sharma',
#     'KH Pandya',
#     'HH Pandya',
#     'MJ McClenaghan',
#     'M Markande',
#     'JJ Bumrah',
#     'Mustafizur Rahman'],
#    'Rajasthan Royals': ['AM Rahane',
#     'RA Tripathi',
#     'SV Samson',
#     'BA Stokes',
#     'JC Buttler',
#     'H Klaasen',
#     'JC Archer',
#     'K Gowtham',
#     'JD Unadkat',
#     'DS Kulkarni',
#     'S Gopal'],
#    'Umpire1': 'KN Ananthapadmanabhan',
#    'Umpire2': 'RJ Tucker'},
#   {'Against': 'Royal Challengers Bangalore',
#    'Venue': 'M.Chinnaswamy Stadium',
#    'TossWinner': 'Royal Challengers Bangalore',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 19.0,
#    'Player_of_Match': 'SV Samson',
#    'Rajasthan Royals': ['AM Rahane',
#     'DJM Short',
#     'SV Samson',
#     'BA Stokes',
#     'JC Buttler',
#     'RA Tripathi',
#     'K Gowtham',
#     'S Gopal',
#     'DS Kulkarni',
#     'JD Unadkat',
#     'B Laughlin'],
#    'Royal Challengers Bangalore': ['BB McCullum',
#     'Q de Kock',
#     'V Kohli',
#     'AB de Villiers',
#     'Mandeep Singh',
#     'P Negi',
#     'Washington Sundar',
#     'CR Woakes',
#     'UT Yadav',
#     'K Khejroliya',
#     'YS Chahal'],
#    'Umpire1': 'C Shamshuddin',
#    'Umpire2': 'S Ravi'},
#   {'Against': 'Delhi Daredevils',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Delhi Daredevils',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 10.0,
#    'Player_of_Match': 'SV Samson',
#    'Rajasthan Royals': ['AM Rahane',
#     'DJM Short',
#     'BA Stokes',
#     'SV Samson',
#     'JC Buttler',
#     'RA Tripathi',
#     'K Gowtham',
#     'S Gopal',
#     'DS Kulkarni',
#     'JD Unadkat',
#     'B Laughlin'],
#    'Delhi Daredevils': ['GJ Maxwell',
#     'C Munro',
#     'RR Pant',
#     'CH Morris',
#     'V Shankar',
#     'SS Iyer',
#     'G Gambhir',
#     'R Tewatia',
#     'S Nadeem',
#     'TA Boult',
#     'Mohammed Shami'],
#    'Umpire1': 'KN Ananthapadmanabhan',
#    'Umpire2': 'Nitin Menon'},
#   {'Against': 'Kolkata Knight Riders',
#    'Venue': 'Brabourne Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 9.0,
#    'Player_of_Match': 'SR Watson',
#    'Rajasthan Royals': ['AM Rahane',
#     'SR Watson',
#     'SPD Smith',
#     'SV Samson',
#     'JP Faulkner',
#     'KK Nair',
#     'CH Morris',
#     'DJ Hooda',
#     'STR Binny',
#     'DS Kulkarni',
#     'BB Sran'],
#    'Kolkata Knight Riders': ['RV Uthappa',
#     'G Gambhir',
#     'MK Pandey',
#     'YK Pathan',
#     'AD Russell',
#     'SA Yadav',
#     'Shakib Al Hasan',
#     'Azhar Mahmood',
#     'PP Chawla',
#     'UT Yadav',
#     'M Morkel'],
#    'Umpire1': 'RM Deshpande',
#    'Umpire2': 'RK Illingworth'},
#   {'Against': 'Delhi Daredevils',
#    'Venue': 'Brabourne Stadium',
#    'TossWinner': 'Delhi Daredevils',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 14.0,
#    'Player_of_Match': 'AM Rahane',
#    'Rajasthan Royals': ['AM Rahane',
#     'SR Watson',
#     'KK Nair',
#     'JP Faulkner',
#     'SPD Smith',
#     'SV Samson',
#     'STR Binny',
#     'DJ Hooda',
#     'TG Southee',
#     'DS Kulkarni',
#     'R Bhatia'],
#    'Delhi Daredevils': ['MA Agarwal',
#     'SS Iyer',
#     'JP Duminy',
#     'Yuvraj Singh',
#     'AD Mathews',
#     'KM Jadhav',
#     'SS Tiwary',
#     'NM Coulter-Nile',
#     'A Mishra',
#     'Z Khan',
#     'GS Sandhu'],
#    'Umpire1': 'HDPK Dharmasena',
#    'Umpire2': 'CB Gaffaney'},
#   {'Against': 'Chennai Super Kings',
#    'Venue': 'Sardar Patel Stadium, Motera',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 8.0,
#    'Player_of_Match': 'AM Rahane',
#    'Rajasthan Royals': ['AM Rahane',
#     'SR Watson',
#     'SPD Smith',
#     'KK Nair',
#     'SV Samson',
#     'STR Binny',
#     'DJ Hooda',
#     'JP Faulkner',
#     'CH Morris',
#     'PV Tambe',
#     'Ankit Sharma'],
#    'Chennai Super Kings': ['DR Smith',
#     'BB McCullum',
#     'SK Raina',
#     'F du Plessis',
#     'DJ Bravo',
#     'MS Dhoni',
#     'RA Jadeja',
#     'R Ashwin',
#     'MM Sharma',
#     'IC Pandey',
#     'A Nehra'],
#    'Umpire1': 'AK Chaudhary',
#    'Umpire2': 'M Erasmus'},
#   {'Against': 'Sunrisers Hyderabad',
#    'Venue': 'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 6.0,
#    'Player_of_Match': 'AM Rahane',
#    'Sunrisers Hyderabad': ['DA Warner',
#     'S Dhawan',
#     'KL Rahul',
#     'NV Ojha',
#     'EJG Morgan',
#     'RS Bopara',
#     'A Ashish Reddy',
#     'KV Sharma',
#     'P Kumar',
#     'B Kumar',
#     'TA Boult'],
#    'Rajasthan Royals': ['AM Rahane',
#     'SV Samson',
#     'SPD Smith',
#     'KK Nair',
#     'STR Binny',
#     'JP Faulkner',
#     'DJ Hooda',
#     'CH Morris',
#     'TG Southee',
#     'DS Kulkarni',
#     'PV Tambe'],
#    'Umpire1': 'PG Pathak',
#    'Umpire2': 'S Ravi'},
#   {'Against': 'Mumbai Indians',
#    'Venue': 'Sardar Patel Stadium, Motera',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 7.0,
#    'Player_of_Match': 'SPD Smith',
#    'Rajasthan Royals': ['AM Rahane',
#     'SV Samson',
#     'SPD Smith',
#     'DJ Hooda',
#     'JP Faulkner',
#     'KK Nair',
#     'STR Binny',
#     'CH Morris',
#     'TG Southee',
#     'DS Kulkarni',
#     'PV Tambe'],
#    'Mumbai Indians': ['AJ Finch',
#     'PA Patel',
#     'UBT Chand',
#     'RG Sharma',
#     'CJ Anderson',
#     'KA Pollard',
#     'J Suchith',
#     'S Gopal',
#     'SL Malinga',
#     'R Vinay Kumar',
#     'P Suyal'],
#    'Umpire1': 'AK Chaudhary',
#    'Umpire2': 'SD Fry'},
#   {'Against': 'Delhi Daredevils',
#    'Venue': 'Feroz Shah Kotla',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 3.0,
#    'Player_of_Match': 'DJ Hooda',
#    'Delhi Daredevils': ['MA Agarwal',
#     'SS Iyer',
#     'JP Duminy',
#     'Yuvraj Singh',
#     'AD Mathews',
#     'MK Tiwary',
#     'KM Jadhav',
#     'NM Coulter-Nile',
#     'A Mishra',
#     'Imran Tahir',
#     'JD Unadkat'],
#    'Rajasthan Royals': ['AM Rahane',
#     'SV Samson',
#     'SPD Smith',
#     'KK Nair',
#     'STR Binny',
#     'DJ Hooda',
#     'JP Faulkner',
#     'CH Morris',
#     'TG Southee',
#     'DS Kulkarni',
#     'PV Tambe'],
#    'Umpire1': 'SD Fry',
#    'Umpire2': 'CB Gaffaney'},
#   {'Against': 'Kings XI Punjab',
#    'Venue': 'Maharashtra Cricket Association Stadium',
#    'TossWinner': 'Kings XI Punjab',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 26.0,
#    'Player_of_Match': 'JP Faulkner',
#    'Kings XI Punjab': ['V Sehwag',
#     'M Vijay',
#     'WP Saha',
#     'GJ Maxwell',
#     'AR Patel',
#     'DA Miller',
#     'GJ Bailey',
#     'MG Johnson',
#     'Anureet Singh',
#     'Karanveer Singh',
#     'Sandeep Sharma'],
#    'Rajasthan Royals': ['AM Rahane',
#     'SV Samson',
#     'SPD Smith',
#     'KK Nair',
#     'STR Binny',
#     'DJ Hooda',
#     'JP Faulkner',
#     'CH Morris',
#     'TG Southee',
#     'DS Kulkarni',
#     'PV Tambe'],
#    'Umpire1': 'SD Fry',
#    'Umpire2': 'CB Gaffaney'},
#   {'Against': 'Delhi Daredevils',
#    'Venue': 'Sardar Patel Stadium, Motera',
#    'TossWinner': 'Delhi Daredevils',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 62.0,
#    'Player_of_Match': 'AM Rahane',
#    'Rajasthan Royals': ['AM Rahane',
#     'KK Nair',
#     'KK Cooper',
#     'SV Samson',
#     'STR Binny',
#     'BCJ Cutting',
#     'JP Faulkner',
#     'SPD Smith',
#     'R Bhatia',
#     'DS Kulkarni',
#     'PV Tambe'],
#    'Delhi Daredevils': ['KP Pietersen',
#     'MA Agarwal',
#     'KD Karthik',
#     'JP Duminy',
#     'MK Tiwary',
#     'LRPL Taylor',
#     'KM Jadhav',
#     'S Nadeem',
#     'Imran Tahir',
#     'R Shukla',
#     'S Kaul'],
#    'Umpire1': 'S Ravi',
#    'Umpire2': 'RJ Tucker'},
#   {'Against': 'Royal Challengers Bangalore',
#    'Venue': 'M Chinnaswamy Stadium',
#    'TossWinner': 'Royal Challengers Bangalore',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 5.0,
#    'Player_of_Match': 'JP Faulkner',
#    'Royal Challengers Bangalore': ['V Kohli',
#     'CH Gayle',
#     'VH Zol',
#     'AB de Villiers',
#     'Yuvraj Singh',
#     'JA Morkel',
#     'PA Patel',
#     'MA Starc',
#     'VR Aaron',
#     'YS Chahal',
#     'AB Dinda'],
#    'Rajasthan Royals': ['AM Rahane',
#     'KK Nair',
#     'SR Watson',
#     'STR Binny',
#     'SV Samson',
#     'SPD Smith',
#     'JP Faulkner',
#     'R Bhatia',
#     'KW Richardson',
#     'PV Tambe',
#     'R Tewatia'],
#    'Umpire1': 'S Ravi',
#    'Umpire2': 'RJ Tucker'},
#   {'Against': 'Kolkata Knight Riders',
#    'Venue': 'Sardar Patel Stadium, Motera',
#    'TossWinner': 'Kolkata Knight Riders',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 10.0,
#    'Player_of_Match': 'PV Tambe',
#    'Rajasthan Royals': ['AM Rahane',
#     'KK Nair',
#     'SV Samson',
#     'SR Watson',
#     'STR Binny',
#     'SPD Smith',
#     'JP Faulkner',
#     'R Bhatia',
#     'TG Southee',
#     'PV Tambe',
#     'R Tewatia'],
#    'Kolkata Knight Riders': ['RV Uthappa',
#     'G Gambhir',
#     'AD Russell',
#     'MK Pandey',
#     'Shakib Al Hasan',
#     'YK Pathan',
#     'RN ten Doeschate',
#     'SA Yadav',
#     'R Vinay Kumar',
#     'SP Narine',
#     'UT Yadav'],
#    'Umpire1': 'NJ Llong',
#    'Umpire2': 'CK Nandan'},
#   {'Against': 'Delhi Daredevils',
#    'Venue': 'Feroz Shah Kotla',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 7.0,
#    'Player_of_Match': 'KK Nair',
#    'Delhi Daredevils': ['Q de Kock',
#     'M Vijay',
#     'KP Pietersen',
#     'KD Karthik',
#     'JP Duminy',
#     'KM Jadhav',
#     'WD Parnell',
#     'S Nadeem',
#     'Mohammed Shami',
#     'JD Unadkat',
#     'R Sharma'],
#    'Rajasthan Royals': ['AM Rahane',
#     'KK Nair',
#     'SV Samson',
#     'R Bhatia',
#     'SR Watson',
#     'STR Binny',
#     'SPD Smith',
#     'JP Faulkner',
#     'DS Kulkarni',
#     'KW Richardson',
#     'PV Tambe'],
#    'Umpire1': 'SS Hazare',
#    'Umpire2': 'S Ravi'},
#   {'Against': 'Kolkata Knight Riders',
#    'Venue': 'Sheikh Zayed Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'bat',
#    'SuperOver': 'Yes',
#    'WonBy': 'SuperOver',
#    'Margin': 0.0,
#    'Player_of_Match': 'JP Faulkner',
#    'Kolkata Knight Riders': ['G Gambhir',
#     'MS Bisla',
#     'JH Kallis',
#     'MK Pandey',
#     'SA Yadav',
#     'Shakib Al Hasan',
#     'RV Uthappa',
#     'R Vinay Kumar',
#     'PP Chawla',
#     'SP Narine',
#     'M Morkel'],
#    'Rajasthan Royals': ['AM Rahane',
#     'KK Nair',
#     'SV Samson',
#     'SR Watson',
#     'STR Binny',
#     'SPD Smith',
#     'JP Faulkner',
#     'R Bhatia',
#     'KW Richardson',
#     'PV Tambe',
#     'Iqbal Abdulla'],
#    'Umpire1': 'Aleem Dar',
#    'Umpire2': 'AK Chaudhary'},
#   {'Against': 'Royal Challengers Bangalore',
#    'Venue': 'Sheikh Zayed Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 6.0,
#    'Player_of_Match': 'PV Tambe',
#    'Rajasthan Royals': ['AM Rahane',
#     'KK Nair',
#     'SV Samson',
#     'AM Nayar',
#     'SR Watson',
#     'STR Binny',
#     'SPD Smith',
#     'R Bhatia',
#     'KW Richardson',
#     'PV Tambe',
#     'TG Southee'],
#    'Royal Challengers Bangalore': ['PA Patel',
#     'YV Takawale',
#     'V Kohli',
#     'Yuvraj Singh',
#     'AB de Villiers',
#     'S Rana',
#     'JA Morkel',
#     'MA Starc',
#     'R Rampaul',
#     'AB Dinda',
#     'YS Chahal'],
#    'Umpire1': 'HDPK Dharmasena',
#    'Umpire2': 'C Shamshuddin'},
#   {'Against': 'Sunrisers Hyderabad',
#    'Venue': 'Sheikh Zayed Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 4.0,
#    'Player_of_Match': 'AM Rahane',
#    'Sunrisers Hyderabad': ['AJ Finch',
#     'S Dhawan',
#     'DA Warner',
#     'KL Rahul',
#     'DJG Sammy',
#     'Y Venugopal Rao',
#     'KV Sharma',
#     'DW Steyn',
#     'A Mishra',
#     'B Kumar',
#     'I Sharma'],
#    'Rajasthan Royals': ['AM Nayar',
#     'AM Rahane',
#     'SV Samson',
#     'SR Watson',
#     'STR Binny',
#     'BJ Hodge',
#     'R Bhatia',
#     'JP Faulkner',
#     'KW Richardson',
#     'DS Kulkarni',
#     'PV Tambe'],
#    'Umpire1': 'BF Bowden',
#    'Umpire2': 'RK Illingworth'},
#   {'Against': 'Sunrisers Hyderabad',
#    'Venue': 'Feroz Shah Kotla',
#    'TossWinner': 'Sunrisers Hyderabad',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 4.0,
#    'Player_of_Match': 'BJ Hodge',
#    'Rajasthan Royals': ['R Dravid',
#     'AM Rahane',
#     'SR Watson',
#     'DH Yagnik',
#     'STR Binny',
#     'SV Samson',
#     'BJ Hodge',
#     'JP Faulkner',
#     'KK Cooper',
#     'VS Malik',
#     'SK Trivedi'],
#    'Sunrisers Hyderabad': ['PA Patel',
#     'S Dhawan',
#     'GH Vihari',
#     'CL White',
#     'DJG Sammy',
#     'NLTC Perera',
#     'BB Samantray',
#     'KV Sharma',
#     'DW Steyn',
#     'A Mishra',
#     'I Sharma'],
#    'Umpire1': 'S Ravi',
#    'Umpire2': 'RJ Tucker'},
#   {'Against': 'Chennai Super Kings',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 5.0,
#    'Player_of_Match': 'SR Watson',
#    'Rajasthan Royals': ['R Dravid',
#     'AM Rahane',
#     'JP Faulkner',
#     'SV Samson',
#     'SR Watson',
#     'STR Binny',
#     'BJ Hodge',
#     'DH Yagnik',
#     'SK Trivedi',
#     'KK Cooper',
#     'VS Malik'],
#    'Chennai Super Kings': ['MEK Hussey',
#     'M Vijay',
#     'SK Raina',
#     'MS Dhoni',
#     'RA Jadeja',
#     'DJ Bravo',
#     'S Badrinath',
#     'CH Morris',
#     'R Ashwin',
#     'JO Holder',
#     'MM Sharma'],
#    'Umpire1': 'HDPK Dharmasena',
#    'Umpire2': 'CK Nandan'},
#   {'Against': 'Kings XI Punjab',
#    'Venue': 'Punjab Cricket Association Stadium, Mohali',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 8.0,
#    'Player_of_Match': 'KK Cooper',
#    'Kings XI Punjab': ['Mandeep Singh',
#     'AC Gilchrist',
#     'SE Marsh',
#     'DJ Hussey',
#     'DA Miller',
#     'MS Gony',
#     'R Sathish',
#     'PP Chawla',
#     'Bipul Sharma',
#     'P Kumar',
#     'P Awana'],
#    'Rajasthan Royals': ['R Dravid',
#     'AM Rahane',
#     'SR Watson',
#     'SV Samson',
#     'BJ Hodge',
#     'DH Yagnik',
#     'KK Cooper',
#     'JP Faulkner',
#     'A Chandila',
#     'S Sreesanth',
#     'SK Trivedi'],
#    'Umpire1': 'HDPK Dharmasena',
#    'Umpire2': 'S Ravi'},
#   {'Against': 'Delhi Daredevils',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Delhi Daredevils',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 9.0,
#    'Player_of_Match': 'AM Rahane',
#    'Rajasthan Royals': ['R Dravid',
#     'AM Rahane',
#     'SR Watson',
#     'SV Samson',
#     'STR Binny',
#     'BJ Hodge',
#     'Sachin Baby',
#     'JP Faulkner',
#     'SK Trivedi',
#     'PV Tambe',
#     'SW Tait'],
#    'Delhi Daredevils': ['DPMD Jayawardene',
#     'V Sehwag',
#     'CM Gautam',
#     'DA Warner',
#     'BJ Rohrer',
#     'KM Jadhav',
#     'AB Agarkar',
#     'M Morkel',
#     'UT Yadav',
#     'P Negi',
#     'S Kaul'],
#    'Umpire1': 'Aleem Dar',
#    'Umpire2': 'RJ Tucker'},
#   {'Against': 'Pune Warriors',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Pune Warriors',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 5.0,
#    'Player_of_Match': 'AM Rahane',
#    'Rajasthan Royals': ['R Dravid',
#     'AM Rahane',
#     'SR Watson',
#     'BJ Hodge',
#     'STR Binny',
#     'SV Samson',
#     'JP Faulkner',
#     'Sachin Baby',
#     'KK Cooper',
#     'A Chandila',
#     'SK Trivedi'],
#    'Pune Warriors': ['RV Uthappa',
#     'AJ Finch',
#     'Yuvraj Singh',
#     'MR Marsh',
#     'AD Mathews',
#     'M Rawat',
#     'UA Birla',
#     'B Kumar',
#     'WD Parnell',
#     'K Upadhyay',
#     'R Sharma'],
#    'Umpire1': 'C Shamshuddin',
#    'Umpire2': 'RJ Tucker'},
#   {'Against': 'Royal Challengers Bangalore',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 4.0,
#    'Player_of_Match': 'SV Samson',
#    'Rajasthan Royals': ['R Dravid',
#     'AM Rahane',
#     'SV Samson',
#     'SR Watson',
#     'BJ Hodge',
#     'STR Binny',
#     'OA Shah',
#     'JP Faulkner',
#     'A Chandila',
#     'SK Trivedi',
#     'S Sreesanth'],
#    'Royal Challengers Bangalore': ['A Mukund',
#     'CH Gayle',
#     'V Kohli',
#     'AB de Villiers',
#     'MC Henriques',
#     'SS Tiwary',
#     'R Rampaul',
#     'R Vinay Kumar',
#     'M Kartik',
#     'RP Singh',
#     'JD Unadkat'],
#    'Umpire1': 'M Erasmus',
#    'Umpire2': 'K Srinath'},
#   {'Against': 'Sunrisers Hyderabad',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Sunrisers Hyderabad',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 8.0,
#    'Player_of_Match': 'JP Faulkner',
#    'Rajasthan Royals': ['R Dravid',
#     'AM Rahane',
#     'SR Watson',
#     'STR Binny',
#     'BJ Hodge',
#     'DH Yagnik',
#     'Sachin Baby',
#     'JP Faulkner',
#     'KK Cooper',
#     'A Chandila',
#     'SK Trivedi'],
#    'Sunrisers Hyderabad': ['PA Reddy',
#     'S Dhawan',
#     'KC Sangakkara',
#     'GH Vihari',
#     'KV Sharma',
#     'NLTC Perera',
#     'DJG Sammy',
#     'A Mishra',
#     'A Ashish Reddy',
#     'DW Steyn',
#     'I Sharma'],
#    'Umpire1': 'VA Kulkarni',
#    'Umpire2': 'K Srinath'},
#   {'Against': 'Mumbai Indians',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 87.0,
#    'Player_of_Match': 'AM Rahane',
#    'Rajasthan Royals': ['SR Watson',
#     'AM Rahane',
#     'DH Yagnik',
#     'STR Binny',
#     'BJ Hodge',
#     'R Dravid',
#     'JP Faulkner',
#     'KK Cooper',
#     'AA Chavan',
#     'A Chandila',
#     'SK Trivedi'],
#    'Mumbai Indians': ['SR Tendulkar',
#     'RT Ponting',
#     'KD Karthik',
#     'RG Sharma',
#     'KA Pollard',
#     'AT Rayudu',
#     'R Dhawan',
#     'Harbhajan Singh',
#     'MG Johnson',
#     'SL Malinga',
#     'PP Ojha'],
#    'Umpire1': 'Aleem Dar',
#    'Umpire2': 'C Shamshuddin'},
#   {'Against': 'Kings XI Punjab',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 6.0,
#    'Player_of_Match': 'JP Faulkner',
#    'Rajasthan Royals': ['SR Watson',
#     'AM Rahane',
#     'R Dravid',
#     'STR Binny',
#     'BJ Hodge',
#     'SV Samson',
#     'JP Faulkner',
#     'KK Cooper',
#     'SK Trivedi',
#     'A Chandila',
#     'S Sreesanth'],
#    'Kings XI Punjab': ['Mandeep Singh',
#     'AC Gilchrist',
#     'M Vohra',
#     'DJ Hussey',
#     'Gurkeerat Singh',
#     'R Sathish',
#     'Azhar Mahmood',
#     'PP Chawla',
#     'RJ Harris',
#     'P Kumar',
#     'P Awana'],
#    'Umpire1': 'Aleem Dar',
#    'Umpire2': 'C Shamshuddin'},
#   {'Against': 'Kolkata Knight Riders',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Kolkata Knight Riders',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 19.0,
#    'Player_of_Match': 'SK Trivedi',
#    'Rajasthan Royals': ['SR Watson',
#     'AM Rahane',
#     'R Dravid',
#     'STR Binny',
#     'BJ Hodge',
#     'KK Cooper',
#     'DH Yagnik',
#     'S Sreesanth',
#     'SK Trivedi',
#     'SW Tait',
#     'R Shukla'],
#    'Kolkata Knight Riders': ['MS Bisla',
#     'G Gambhir',
#     'JH Kallis',
#     'MK Tiwary',
#     'EJG Morgan',
#     'YK Pathan',
#     'LR Shukla',
#     'R Bhatia',
#     'B Lee',
#     'Mohammed Shami',
#     'SP Narine'],
#    'Umpire1': 'Aleem Dar',
#    'Umpire2': 'S Das'},
#   {'Against': 'Delhi Daredevils',
#    'Venue': 'Feroz Shah Kotla',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 5.0,
#    'Player_of_Match': 'R Dravid',
#    'Delhi Daredevils': ['DA Warner',
#     'UBT Chand',
#     'DPMD Jayawardene',
#     'MC Juneja',
#     'AD Russell',
#     'J Botha',
#     'IK Pathan',
#     'NV Ojha',
#     'A Nehra',
#     'S Nadeem',
#     'UT Yadav'],
#    'Rajasthan Royals': ['MDKJ Perera',
#     'AM Rahane',
#     'R Dravid',
#     'STR Binny',
#     'BJ Hodge',
#     'KK Cooper',
#     'AL Menaria',
#     'S Sreesanth',
#     'R Shukla',
#     'SK Trivedi',
#     'S Badree'],
#    'Umpire1': 'S Das',
#    'Umpire2': 'C Shamshuddin'},
#   {'Against': 'Pune Warriors',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 45.0,
#    'Player_of_Match': 'A Chandila',
#    'Rajasthan Royals': ['R Dravid',
#     'AM Rahane',
#     'SR Watson',
#     'BJ Hodge',
#     'STR Binny',
#     'J Botha',
#     'SP Goswami',
#     'AL Menaria',
#     'SW Tait',
#     'SK Trivedi',
#     'A Chandila'],
#    'Pune Warriors': ['SC Ganguly',
#     'JD Ryder',
#     'RV Uthappa',
#     'AP Majumdar',
#     'CJ Ferguson',
#     'SPD Smith',
#     'AD Mathews',
#     'B Kumar',
#     'M Kartik',
#     'R Sharma',
#     'A Nehra'],
#    'Umpire1': 'BF Bowden',
#    'Umpire2': 'SK Tarapore'},
#   {'Against': 'Pune Warriors',
#    'Venue': 'Subrata Roy Sahara Stadium',
#    'TossWinner': 'Pune Warriors',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 7.0,
#    'Player_of_Match': 'SR Watson',
#    'Pune Warriors': ['SC Ganguly',
#     'MJ Clarke',
#     'RV Uthappa',
#     'AP Majumdar',
#     'SPD Smith',
#     'AD Mathews',
#     'M Manhas',
#     'WD Parnell',
#     'B Kumar',
#     'M Kartik',
#     'A Nehra'],
#    'Rajasthan Royals': ['R Dravid',
#     'AM Rahane',
#     'SR Watson',
#     'AL Menaria',
#     'OA Shah',
#     'AA Chavan',
#     'J Botha',
#     'STR Binny',
#     'DH Yagnik',
#     'SW Tait',
#     'SK Trivedi'],
#    'Umpire1': 'Asad Rauf',
#    'Umpire2': 'BR Doctrove'},
#   {'Against': 'Kings XI Punjab',
#    'Venue': 'Punjab Cricket Association Stadium, Mohali',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 43.0,
#    'Player_of_Match': 'SR Watson',
#    'Kings XI Punjab': ['SE Marsh',
#     'Mandeep Singh',
#     'N Saini',
#     'DJ Hussey',
#     'Azhar Mahmood',
#     'Gurkeerat Singh',
#     'AM Nayar',
#     'PP Chawla',
#     'RJ Harris',
#     'P Kumar',
#     'P Awana'],
#    'Rajasthan Royals': ['R Dravid',
#     'AM Rahane',
#     'SR Watson',
#     'AL Menaria',
#     'BJ Hodge',
#     'J Botha',
#     'STR Binny',
#     'AA Chavan',
#     'DH Yagnik',
#     'SW Tait',
#     'SK Trivedi'],
#    'Umpire1': 'JD Cloete',
#    'Umpire2': 'SJA Taufel'},
#   {'Against': 'Deccan Chargers',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Deccan Chargers',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 5.0,
#    'Player_of_Match': 'BJ Hodge',
#    'Rajasthan Royals': ['R Dravid',
#     'AM Rahane',
#     'AL Menaria',
#     'OA Shah',
#     'BJ Hodge',
#     'J Botha',
#     'DH Yagnik',
#     'GB Hogg',
#     'A Singh',
#     'SK Trivedi',
#     'Pankaj Singh'],
#    'Deccan Chargers': ['KC Sangakkara',
#     'S Dhawan',
#     'DT Christian',
#     'JP Duminy',
#     'B Chipli',
#     'T Mishra',
#     'AA Jhunjhunwala',
#     'Ankit Sharma',
#     'A Mishra',
#     'DW Steyn',
#     'Anand Rajan'],
#    'Umpire1': 'Aleem Dar',
#    'Umpire2': 'BNJ Oxenford'},
#   {'Against': 'Royal Challengers Bangalore',
#    'Venue': 'M Chinnaswamy Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 59.0,
#    'Player_of_Match': 'AM Rahane',
#    'Royal Challengers Bangalore': ['MA Agarwal',
#     'CH Gayle',
#     'V Kohli',
#     'AB de Villiers',
#     'SS Tiwary',
#     'M Kaif',
#     'DL Vettori',
#     'R Vinay Kumar',
#     'Z Khan',
#     'S Aravind',
#     'M Muralitharan'],
#    'Rajasthan Royals': ['R Dravid',
#     'AM Rahane',
#     'OA Shah',
#     'BJ Hodge',
#     'AL Menaria',
#     'J Botha',
#     'GB Hogg',
#     'SP Goswami',
#     'A Singh',
#     'SK Trivedi',
#     'Pankaj Singh'],
#    'Umpire1': 'JD Cloete',
#    'Umpire2': 'RJ Tucker'},
#   {'Against': 'Kolkata Knight Riders',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Kolkata Knight Riders',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 22.0,
#    'Player_of_Match': 'BJ Hodge',
#    'Rajasthan Royals': ['R Dravid',
#     'AM Rahane',
#     'SP Goswami',
#     'AL Menaria',
#     'BJ Hodge',
#     'OA Shah',
#     'KK Cooper',
#     'J Botha',
#     'AA Chavan',
#     'A Singh',
#     'SK Trivedi'],
#    'Kolkata Knight Riders': ['JH Kallis',
#     'BB McCullum',
#     'G Gambhir',
#     'MK Tiwary',
#     'DB Das',
#     'YK Pathan',
#     'R Bhatia',
#     'LR Shukla',
#     'B Lee',
#     'SP Narine',
#     'Iqbal Abdulla'],
#    'Umpire1': 'BF Bowden',
#    'Umpire2': 'VA Kulkarni'},
#   {'Against': 'Kings XI Punjab',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Kings XI Punjab',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 31.0,
#    'Player_of_Match': 'AM Rahane',
#    'Rajasthan Royals': ['R Dravid',
#     'AM Rahane',
#     'AL Menaria',
#     'BJ Hodge',
#     'OA Shah',
#     'KK Cooper',
#     'J Botha',
#     'AA Chavan',
#     'SP Goswami',
#     'A Singh',
#     'SK Trivedi'],
#    'Kings XI Punjab': ['AC Gilchrist',
#     'PC Valthaty',
#     'SE Marsh',
#     'AM Nayar',
#     'DJ Hussey',
#     'Mandeep Singh',
#     'Bipul Sharma',
#     'PP Chawla',
#     'JP Faulkner',
#     'P Kumar',
#     'Harmeet Singh'],
#    'Umpire1': 'BF Bowden',
#    'Umpire2': 'SK Tarapore'},
#   {'Against': 'Mumbai Indians',
#    'Venue': 'Wankhede Stadium',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 10.0,
#    'Player_of_Match': 'SR Watson',
#    'Mumbai Indians': ['TL Suman',
#     'SR Tendulkar',
#     'AT Rayudu',
#     'RG Sharma',
#     'KA Pollard',
#     'JEC Franklin',
#     'Harbhajan Singh',
#     'A Symonds',
#     'DS Kulkarni',
#     'MM Patel',
#     'SL Malinga'],
#    'Rajasthan Royals': ['SR Watson',
#     'R Dravid',
#     'J Botha',
#     'AL Menaria',
#     'AM Rahane',
#     'LRPL Taylor',
#     'PR Shah',
#     'AA Chavan',
#     'SK Warne',
#     'A Singh',
#     'SK Trivedi'],
#    'Umpire1': 'RE Koertzen',
#    'Umpire2': 'PR Reiffel'},
#   {'Against': 'Pune Warriors',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
# ...
#     'SK Raina',
#     'MS Dhoni',
#     'S Badrinath',
#     'JA Morkel',
#     'KB Arun Karthik',
#     'T Thushara',
#     'Joginder Sharma',
#     'M Muralitharan',
#     'SB Jakati'],
#    'Umpire1': 'SS Hazare',
#    'Umpire2': 'SJA Taufel'},
#   {'Against': 'Deccan Chargers',
#    'Venue': 'Sardar Patel Stadium, Motera',
#    'TossWinner': 'Deccan Chargers',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 8.0,
#    'Player_of_Match': 'YK Pathan',
#    'Rajasthan Royals': ['MJ Lumb',
#     'NV Ojha',
#     'YK Pathan',
#     'FY Fazal',
#     'AC Voges',
#     'AA Jhunjhunwala',
#     'P Dogra',
#     'SK Warne',
#     'S Narwal',
#     'SK Trivedi',
#     'SW Tait'],
#    'Deccan Chargers': ['AC Gilchrist',
#     'VVS Laxman',
#     'HH Gibbs',
#     'A Symonds',
#     'RG Sharma',
#     'TL Suman',
#     'Y Venugopal Rao',
#     'WPUJC Vaas',
#     'R Sharma',
#     'RP Singh',
#     'PP Ojha'],
#    'Umpire1': 'HDPK Dharmasena',
#    'Umpire2': 'SJA Taufel'},
#   {'Against': 'Kings XI Punjab',
#    'Venue': 'Punjab Cricket Association Stadium, Mohali',
#    'TossWinner': 'Kings XI Punjab',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 31.0,
#    'Player_of_Match': 'AC Voges',
#    'Kings XI Punjab': ['RS Bopara',
#     'KC Sangakkara',
#     'MS Bisla',
#     'Yuvraj Singh',
#     'DPMD Jayawardene',
#     'IK Pathan',
#     'M Kaif',
#     'PP Chawla',
#     'J Theron',
#     'S Sreesanth',
#     'SJ Srivastava'],
#    'Rajasthan Royals': ['MJ Lumb',
#     'NV Ojha',
#     'FY Fazal',
#     'YK Pathan',
#     'AC Voges',
#     'P Dogra',
#     'AA Jhunjhunwala',
#     'SK Warne',
#     'MM Patel',
#     'SK Trivedi',
#     'SW Tait'],
#    'Umpire1': 'BR Doctrove',
#    'Umpire2': 'SK Tarapore'},
#   {'Against': 'Kolkata Knight Riders',
#    'Venue': 'Sardar Patel Stadium, Motera',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 34.0,
#    'Player_of_Match': 'AA Jhunjhunwala',
#    'Rajasthan Royals': ['MJ Lumb',
#     'NV Ojha',
#     'FY Fazal',
#     'AA Jhunjhunwala',
#     'YK Pathan',
#     'AC Voges',
#     'P Dogra',
#     'SK Warne',
#     'MM Patel',
#     'SK Trivedi',
#     'SW Tait'],
#    'Kolkata Knight Riders': ['MK Tiwary',
#     'BJ Hodge',
#     'CA Pujara',
#     'SC Ganguly',
#     'OA Shah',
#     'AD Mathews',
#     'WP Saha',
#     'M Kartik',
#     'AB Dinda',
#     'SE Bond',
#     'I Sharma'],
#    'Umpire1': 'RE Koertzen',
#    'Umpire2': 'RB Tiffin'},
#   {'Against': 'Mumbai Indians',
#    'Venue': 'Kingsmead',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 2.0,
#    'Player_of_Match': 'SK Warne',
#    'Mumbai Indians': ['DJ Bravo',
#     'YV Takawale',
#     'AM Rahane',
#     'ST Jayasuriya',
#     'SR Tendulkar',
#     'JP Duminy',
#     'AM Nayar',
#     'Harbhajan Singh',
#     'DS Kulkarni',
#     'C Nanda',
#     'SL Malinga'],
#    'Rajasthan Royals': ['RJ Quiney',
#     'GC Smith',
#     'YK Pathan',
#     'RA Jadeja',
#     'SD Chitnis',
#     'NV Ojha',
#     'J Botha',
#     'SK Warne',
#     'AS Raut',
#     'MM Patel',
#     'SK Trivedi'],
#    'Umpire1': 'BR Doctrove',
#    'Umpire2': 'DJ Harper'},
#   {'Against': 'Royal Challengers Bangalore',
#    'Venue': 'SuperSport Park',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 7.0,
#    'Player_of_Match': 'A Singh',
#    'Royal Challengers Bangalore': ['JH Kallis',
#     'W Jaffer',
#     'RV Uthappa',
#     'R Dravid',
#     'V Kohli',
#     'MV Boucher',
#     'RE van der Merwe',
#     'D du Preez',
#     'P Kumar',
#     'R Vinay Kumar',
#     'A Kumble'],
#    'Rajasthan Royals': ['GC Smith',
#     'NV Ojha',
#     'LA Carseldine',
#     'YK Pathan',
#     'RA Jadeja',
#     'AS Raut',
#     'NK Patel',
#     'SK Warne',
#     'M Morkel',
#     'MM Patel',
#     'A Singh'],
#    'Umpire1': 'K Hariharan',
#    'Umpire2': 'DJ Harper'},
#   {'Against': 'Kings XI Punjab',
#    'Venue': 'Kingsmead',
#    'TossWinner': 'Kings XI Punjab',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 78.0,
#    'Player_of_Match': 'GC Smith',
#    'Kings XI Punjab': ['S Sohal',
#     'KC Sangakkara',
#     'K Goel',
#     'SM Katich',
#     'DPMD Jayawardene',
#     'Yuvraj Singh',
#     'IK Pathan',
#     'PP Chawla',
#     'RR Powar',
#     'S Sreesanth',
#     'YA Abdulla'],
#    'Rajasthan Royals': ['NV Ojha',
#     'GC Smith',
#     'YK Pathan',
#     'RA Jadeja',
#     'LA Carseldine',
#     'AS Raut',
#     'NK Patel',
#     'SK Warne',
#     'SM Harwood',
#     'SK Trivedi',
#     'A Singh'],
#    'Umpire1': 'SS Hazare',
#    'Umpire2': 'IL Howell'},
#   {'Against': 'Deccan Chargers',
#    'Venue': "St George's Park",
#    'TossWinner': 'Deccan Chargers',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 3.0,
#    'Player_of_Match': 'YK Pathan',
#    'Deccan Chargers': ['HH Gibbs',
#     'AC Gilchrist',
#     'AA Bilakhia',
#     'RG Sharma',
#     'TL Suman',
#     'DR Smith',
#     'Y Venugopal Rao',
#     'Shoaib Ahmed',
#     'PP Ojha',
#     'RP Singh',
#     'FH Edwards'],
#    'Rajasthan Royals': ['GC Smith',
#     'SA Asnodkar',
#     'LA Carseldine',
#     'NV Ojha',
#     'RA Jadeja',
#     'SK Warne',
#     'AS Raut',
#     'YK Pathan',
#     'SM Harwood',
#     'SK Trivedi',
#     'MM Patel'],
#    'Umpire1': 'S Asnani',
#    'Umpire2': 'BG Jerling'},
#   {'Against': 'Delhi Daredevils',
#    'Venue': 'SuperSport Park',
#    'TossWinner': 'Delhi Daredevils',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 5.0,
#    'Player_of_Match': 'YK Pathan',
#    'Delhi Daredevils': ['G Gambhir',
#     'V Sehwag',
#     'AB de Villiers',
#     'TM Dilshan',
#     'KD Karthik',
#     'DL Vettori',
#     'M Manhas',
#     'A Mishra',
#     'PJ Sangwan',
#     'A Nehra',
#     'DP Nannes'],
#    'Rajasthan Royals': ['RJ Quiney',
#     'GC Smith',
#     'SA Asnodkar',
#     'PC Valthaty',
#     'RA Jadeja',
#     'SK Warne',
#     'YK Pathan',
#     'AD Mascarenhas',
#     'M Rawat',
#     'MM Patel',
#     'Kamran Khan'],
#    'Umpire1': 'GAV Baxter',
#    'Umpire2': 'RE Koertzen'},
#   {'Against': 'Kolkata Knight Riders',
#    'Venue': 'Newlands',
#    'TossWinner': 'Kolkata Knight Riders',
#    'TossDecision': 'field',
#    'SuperOver': 'Yes',
#    'WonBy': 'SuperOver',
#    'Margin': 0.0,
#    'Player_of_Match': 'YK Pathan',
#    'Kolkata Knight Riders': ['CH Gayle',
#     'BB McCullum',
#     'LR Shukla',
#     'BJ Hodge',
#     'SC Ganguly',
#     'SB Bangar',
#     'Yashpal Singh',
#     'AB Agarkar',
#     'I Sharma',
#     'BAW Mendis',
#     'Anureet Singh'],
#    'Rajasthan Royals': ['GC Smith',
#     'PC Valthaty',
#     'RJ Quiney',
#     'YK Pathan',
#     'RA Jadeja',
#     'AD Mascarenhas',
#     'AS Raut',
#     'SK Warne',
#     'M Rawat',
#     'MM Patel',
#     'Kamran Khan'],
#    'Umpire1': 'MR Benson',
#    'Umpire2': 'M Erasmus'},
#   {'Against': 'Chennai Super Kings',
#    'Venue': 'Dr DY Patil Sports Academy',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 3.0,
#    'Player_of_Match': 'YK Pathan',
#    'Chennai Super Kings': ['PA Patel',
#     'S Vidyut',
#     'SK Raina',
#     'JA Morkel',
#     'MS Dhoni',
#     'CK Kapugedera',
#     'S Badrinath',
#     'MS Gony',
#     'L Balaji',
#     'M Muralitharan',
#     'M Ntini'],
#    'Rajasthan Royals': ['NK Patel',
#     'SA Asnodkar',
#     'Kamran Akmal',
#     'SR Watson',
#     'YK Pathan',
#     'M Kaif',
#     'RA Jadeja',
#     'SK Warne',
#     'Sohail Tanvir',
#     'SK Trivedi',
#     'MM Patel'],
#    'Umpire1': 'BF Bowden',
#    'Umpire2': 'RE Koertzen'},
#   {'Against': 'Delhi Daredevils',
#    'Venue': 'Wankhede Stadium',
#    'TossWinner': 'Delhi Daredevils',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 105.0,
#    'Player_of_Match': 'SR Watson',
#    'Delhi Daredevils': ['G Gambhir',
#     'V Sehwag',
#     'S Dhawan',
#     'MK Tiwary',
#     'TM Dilshan',
#     'KD Karthik',
#     'MF Maharoof',
#     'A Mishra',
#     'VY Mahesh',
#     'Mohammad Asif',
#     'GD McGrath'],
#    'Rajasthan Royals': ['GC Smith',
#     'SA Asnodkar',
#     'Sohail Tanvir',
#     'SR Watson',
#     'M Kaif',
#     'YK Pathan',
#     'RA Jadeja',
#     'SK Warne',
#     'M Rawat',
#     'MM Patel',
#     'SK Trivedi'],
#    'Umpire1': 'BF Bowden',
#    'Umpire2': 'RE Koertzen'},
#   {'Against': 'Mumbai Indians',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 5.0,
#    'Player_of_Match': 'Sohail Tanvir',
#    'Rajasthan Royals': ['Kamran Akmal',
#     'SA Asnodkar',
#     'YK Pathan',
#     'SR Watson',
#     'M Kaif',
#     'RA Jadeja',
#     'NK Patel',
#     'SK Warne',
#     'Sohail Tanvir',
#     'SK Trivedi',
#     'Pankaj Singh'],
#    'Mumbai Indians': ['ST Jayasuriya',
#     'SR Tendulkar',
#     'AM Nayar',
#     'RV Uthappa',
#     'DR Smith',
#     'SM Pollock',
#     'MK Pandey',
#     'YV Takawale',
#     'RR Raje',
#     'CRD Fernando',
#     'A Nehra'],
#    'Umpire1': 'BF Bowden',
#    'Umpire2': 'K Hariharan'},
#   {'Against': 'Chennai Super Kings',
#    'Venue': 'MA Chidambaram Stadium, Chepauk',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 10.0,
#    'Player_of_Match': 'JA Morkel',
#    'Chennai Super Kings': ['PA Patel',
#     'SP Fleming',
#     'SK Raina',
#     'JA Morkel',
#     'MS Dhoni',
#     'S Badrinath',
#     'MS Gony',
#     'A Mukund',
#     'L Balaji',
#     'M Muralitharan',
#     'M Ntini'],
#    'Rajasthan Royals': ['GC Smith',
#     'SA Asnodkar',
#     'Kamran Akmal',
#     'YK Pathan',
#     'M Kaif',
#     'T Kohli',
#     'D Salunkhe',
#     'SK Warne',
#     'Sohail Tanvir',
#     'Pankaj Singh',
#     'MM Patel'],
#    'Umpire1': 'DJ Harper',
#    'Umpire2': 'SL Shastri'},
#   {'Against': 'Kolkata Knight Riders',
#    'Venue': 'Eden Gardens',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 6.0,
#    'Player_of_Match': 'YK Pathan',
#    'Kolkata Knight Riders': ['Salman Butt',
#     'Mohammad Hafeez',
#     'SC Ganguly',
#     'DJ Hussey',
#     'DB Das',
#     'LR Shukla',
#     'WP Saha',
#     'AB Agarkar',
#     'Umar Gul',
#     'I Sharma',
#     'AB Dinda'],
#    'Rajasthan Royals': ['GC Smith',
#     'SA Asnodkar',
#     'Sohail Tanvir',
#     'M Kaif',
#     'SR Watson',
#     'YK Pathan',
#     'RA Jadeja',
#     'SK Warne',
#     'M Rawat',
#     'SK Trivedi',
#     'MM Patel'],
#    'Umpire1': 'BG Jerling',
#    'Umpire2': 'RE Koertzen'},
#   {'Against': 'Royal Challengers Bangalore',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Royal Challengers Bangalore',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 65.0,
#    'Player_of_Match': 'GC Smith',
#    'Rajasthan Royals': ['GC Smith',
#     'SA Asnodkar',
#     'SR Watson',
#     'YK Pathan',
#     'M Kaif',
#     'RA Jadeja',
#     'SK Warne',
#     'Sohail Tanvir',
#     'M Rawat',
#     'SK Trivedi',
#     'MM Patel'],
#    'Royal Challengers Bangalore': ['J Arunkumar',
#     'V Kohli',
#     'Misbah-ul-Haq',
#     'JH Kallis',
#     'CL White',
#     'R Dravid',
#     'DT Patil',
#     'P Kumar',
#     'Z Khan',
#     'A Kumble',
#     'Abdur Razzak'],
#    'Umpire1': 'BF Bowden',
#    'Umpire2': 'SL Shastri'},
#   {'Against': 'Delhi Daredevils',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 3.0,
#    'Player_of_Match': 'SR Watson',
#    'Rajasthan Royals': ['YK Pathan',
#     'GC Smith',
#     'M Kaif',
#     'SR Watson',
#     'RA Jadeja',
#     'AD Mascarenhas',
#     'SK Warne',
#     'NK Patel',
#     'M Rawat',
#     'SK Trivedi',
#     'MM Patel'],
#    'Delhi Daredevils': ['G Gambhir',
#     'V Sehwag',
#     'S Dhawan',
#     'AB de Villiers',
#     'KD Karthik',
#     'TM Dilshan',
#     'A Mishra',
#     'MF Maharoof',
#     'VY Mahesh',
#     'GD McGrath',
#     'PJ Sangwan'],
#    'Umpire1': 'SJ Davis',
#    'Umpire2': 'RE Koertzen'},
#   {'Against': 'Deccan Chargers',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 8.0,
#    'Player_of_Match': 'YK Pathan',
#    'Rajasthan Royals': ['GC Smith',
#     'YK Pathan',
#     'M Kaif',
#     'SR Watson',
#     'NK Patel',
#     'RA Jadeja',
#     'SK Warne',
#     'M Rawat',
#     'Sohail Tanvir',
#     'SK Trivedi',
#     'MM Patel'],
#    'Deccan Chargers': ['AC Gilchrist',
#     'HH Gibbs',
#     'SB Styris',
#     'RG Sharma',
#     'Shahid Afridi',
#     'SB Bangar',
#     'DB Ravi Teja',
#     'Y Venugopal Rao',
#     'RP Singh',
#     'PP Ojha',
#     'DP Vijaykumar'],
#    'Umpire1': 'MR Benson',
#    'Umpire2': 'AM Saheba'},
#   {'Against': 'Chennai Super Kings',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 8.0,
#    'Player_of_Match': 'Sohail Tanvir',
#    'Rajasthan Royals': ['GC Smith',
#     'SA Asnodkar',
#     'YK Pathan',
#     'SR Watson',
#     'M Rawat',
#     'M Kaif',
#     'RA Jadeja',
#     'SK Warne',
#     'Sohail Tanvir',
#     'SK Trivedi',
#     'MM Patel'],
#    'Chennai Super Kings': ['PA Patel',
#     'SP Fleming',
#     'S Vidyut',
#     'SK Raina',
#     'S Badrinath',
#     'MS Dhoni',
#     'JA Morkel',
#     'Joginder Sharma',
#     'MS Gony',
#     'M Muralitharan',
#     'M Ntini'],
#    'Umpire1': 'Asad Rauf',
#    'Umpire2': 'AV Jayaprakash'},
#   {'Against': 'Kolkata Knight Riders',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 45.0,
#    'Player_of_Match': 'SA Asnodkar',
#    'Rajasthan Royals': ['GC Smith',
#     'SA Asnodkar',
#     'M Kaif',
#     'YK Pathan',
#     'SR Watson',
#     'RA Jadeja',
#     'SK Warne',
#     'Sohail Tanvir',
#     'M Rawat',
#     'SK Trivedi',
#     'MM Patel'],
#    'Kolkata Knight Riders': ['Salman Butt',
#     'SC Ganguly',
#     'AB Agarkar',
#     'BJ Hodge',
#     'DJ Hussey',
#     'LR Shukla',
#     'DB Das',
#     'WP Saha',
#     'Umar Gul',
#     'I Sharma',
#     'AB Dinda'],
#    'Umpire1': 'RE Koertzen',
#    'Umpire2': 'GA Pratapkumar'},
#   {'Against': 'Royal Challengers Bangalore',
#    'Venue': 'M Chinnaswamy Stadium',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 7.0,
#    'Player_of_Match': 'SR Watson',
#    'Royal Challengers Bangalore': ['S Chanderpaul',
#     'R Dravid',
#     'LRPL Taylor',
#     'JH Kallis',
#     'V Kohli',
#     'MV Boucher',
#     'P Kumar',
#     'SB Joshi',
#     'Z Khan',
#     'R Vinay Kumar',
#     'A Kumble'],
#    'Rajasthan Royals': ['GC Smith',
#     'M Rawat',
#     'YK Pathan',
#     'SR Watson',
#     'M Kaif',
#     'RA Jadeja',
#     'D Salunkhe',
#     'SK Warne',
#     'Sohail Tanvir',
#     'SK Trivedi',
#     'MM Patel'],
#    'Umpire1': 'MR Benson',
#    'Umpire2': 'IL Howell'},
#   {'Against': 'Deccan Chargers',
#    'Venue': 'Rajiv Gandhi International Stadium, Uppal',
#    'TossWinner': 'Rajasthan Royals',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 3.0,
#    'Player_of_Match': 'YK Pathan',
#    'Deccan Chargers': ['AC Gilchrist',
#     'VVS Laxman',
#     'Shahid Afridi',
#     'A Symonds',
#     'RG Sharma',
#     'AS Yadav',
#     'SB Bangar',
#     'WPUJC Vaas',
#     'RP Singh',
#     'PP Ojha',
#     'D Kalyankrishna'],
#    'Rajasthan Royals': ['Kamran Akmal',
#     'GC Smith',
#     'YK Pathan',
#     'SR Watson',
#     'M Kaif',
#     'RA Jadeja',
#     'SK Warne',
#     'D Salunkhe',
#     'Pankaj Singh',
#     'SK Trivedi',
#     'MM Patel'],
#    'Umpire1': 'Asad Rauf',
#    'Umpire2': 'MR Benson'},
#   {'Against': 'Kings XI Punjab',
#    'Venue': 'Sawai Mansingh Stadium',
#    'TossWinner': 'Kings XI Punjab',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 6.0,
#    'Player_of_Match': 'SR Watson',
#    'Rajasthan Royals': ['M Kaif',
#     'Kamran Akmal',
#     'YK Pathan',
#     'SR Watson',
#     'DS Lehmann',
#     'RA Jadeja',
#     'Pankaj Singh',
#     'D Salunkhe',
#     'SK Warne',
#     'SK Trivedi',
#     'MM Patel'],
#    'Kings XI Punjab': ['K Goel',
#     'JR Hopes',
#     'KC Sangakkara',
#     'DPMD Jayawardene',
#     'Yuvraj Singh',
#     'IK Pathan',
#     'S Sohal',
#     'B Lee',
#     'PP Chawla',
#     'WA Mota',
#     'S Sreesanth'],
#    'Umpire1': 'Aleem Dar',
#    'Umpire2': 'RB Tiffin'}]}

# %%
df.loc[[1312200]]['Team1Players']
# Out:
# ID
# 1312200    [YBK Jaiswal, JC Buttler, SV Samson, D Padikka...
# Name: Team1Players, dtype: object

# %% [markdown]
# # Matches Played at a Specific Venue

# %%
def get_matches_by_venue(venue_name):
    venue_matches = []
    for idx,match in df.iterrows():
        if match['Venue'] == venue_name:
            venue_matches.append({
                "city": match['City'],
                "date": match['Date'],
                "team1": match['Team1'],
                "team2": match['Team2'],
                "winning_team": match['WinningTeam']
            })
    if len(venue_matches) > 0:
        return {venue_name : venue_matches}
    return {venue_name : 'No Match Found'}

# %%
get_matches_by_venue('Narendra Modi Stadium, Ahmedabad')
# Out:
# {'Narendra Modi Stadium, Ahmedabad': [{'city': 'Ahmedabad',
#    'date': '2022-05-29',
#    'team1': 'Rajasthan Royals',
#    'team2': 'Gujarat Titans',
#    'winning_team': 'Gujarat Titans'},
#   {'city': 'Ahmedabad',
#    'date': '2022-05-27',
#    'team1': 'Royal Challengers Bangalore',
#    'team2': 'Rajasthan Royals',
#    'winning_team': 'Rajasthan Royals'},
#   {'city': 'Ahmedabad',
#    'date': '2021-05-02',
#    'team1': 'Punjab Kings',
#    'team2': 'Delhi Capitals',
#    'winning_team': 'Delhi Capitals'},
#   {'city': 'Ahmedabad',
#    'date': '2021-04-30',
#    'team1': 'Punjab Kings',
#    'team2': 'Royal Challengers Bangalore',
#    'winning_team': 'Punjab Kings'},
#   {'city': 'Ahmedabad',
#    'date': '2021-04-29',
#    'team1': 'Kolkata Knight Riders',
#    'team2': 'Delhi Capitals',
#    'winning_team': 'Delhi Capitals'},
#   {'city': 'Ahmedabad',
#    'date': '2021-04-27',
#    'team1': 'Royal Challengers Bangalore',
#    'team2': 'Delhi Capitals',
#    'winning_team': 'Royal Challengers Bangalore'},
#   {'city': 'Ahmedabad',
#    'date': '2021-04-26',
#    'team1': 'Punjab Kings',
#    'team2': 'Kolkata Knight Riders',
#    'winning_team': 'Kolkata Knight Riders'}]}

# %%
df['Venue'].value_counts()
# Out:
# Venue
# Eden Gardens                                            77
# Wankhede Stadium                                        73
# M Chinnaswamy Stadium                                   65
# Feroz Shah Kotla                                        60
# Rajiv Gandhi International Stadium, Uppal               49
# MA Chidambaram Stadium, Chepauk                         48
# Sawai Mansingh Stadium                                  47
# Dubai International Cricket Stadium                     46
# Punjab Cricket Association Stadium, Mohali              35
# Wankhede Stadium, Mumbai                                31
# Sheikh Zayed Stadium                                    29
# Sharjah Cricket Stadium                                 28
# Maharashtra Cricket Association Stadium                 22
# Dr DY Patil Sports Academy, Mumbai                      20
# Brabourne Stadium, Mumbai                               17
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              16
# Kingsmead                                               15
# Rajiv Gandhi International Stadium                      15
# M.Chinnaswamy Stadium                                   15
# Arun Jaitley Stadium                                    14
# Maharashtra Cricket Association Stadium, Pune           13
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     13
# Sardar Patel Stadium, Motera                            12
# SuperSport Park                                         12
# Punjab Cricket Association IS Bindra Stadium, Mohali    11
# Saurashtra Cricket Association Stadium                  10
# Punjab Cricket Association IS Bindra Stadium            10
# Brabourne Stadium                                       10
# MA Chidambaram Stadium, Chepauk, Chennai                10
# MA Chidambaram Stadium                                   9
# Himachal Pradesh Cricket Association Stadium             9
# Holkar Cricket Stadium                                   9
# New Wanderers Stadium                                    8
# Zayed Cricket Stadium, Abu Dhabi                         8
# Narendra Modi Stadium, Ahmedabad                         7
# Newlands                                                 7
# Barabati Stadium                                         7
# St George's Park                                         7
# JSCA International Stadium Complex                       7
# Shaheed Veer Narayan Singh International Stadium         6
# Nehru Stadium                                            5
# Arun Jaitley Stadium, Delhi                              4
# Green Park                                               4
# Vidarbha Cricket Association Stadium, Jamtha             3
# Buffalo Park                                             3
# De Beers Diamond Oval                                    3
# Eden Gardens, Kolkata                                    2
# OUTsurance Oval                                          2
# Name: count, dtype: int64

# %% [markdown]
# ## Player of the Match Analysis

# %%
def player_of_match_performance(player_name):
    player_matches = []
    for idx,match in df.iterrows():
        if match['Player_of_Match'] == player_name:
            player_matches.append({
                "date" : match['Date'],
                "Venue" : match['Venue'],
                "winning_team": match['WinningTeam'],
                "won_by": match['WonBy'],
                "margin": match['Margin']
            })
    if len(player_matches) > 0:
        return {player_name : player_matches}
    return {'error' : 'no match found'}

# %%
player_of_match_performance('HH Pandya')
# Out:
# {'HH Pandya': [{'Venue': 'Narendra Modi Stadium, Ahmedabad',
#    'winning_team': 'Gujarat Titans',
#    'won_by': 'Wickets',
#    'margin': 7.0},
#   {'Venue': 'Dr DY Patil Sports Academy, Mumbai',
#    'winning_team': 'Gujarat Titans',
#    'won_by': 'Runs',
#    'margin': 37.0},
#   {'Venue': 'Wankhede Stadium',
#    'winning_team': 'Mumbai Indians',
#    'won_by': 'Wickets',
#    'margin': 9.0},
#   {'Venue': 'Arun Jaitley Stadium',
#    'winning_team': 'Mumbai Indians',
#    'won_by': 'Runs',
#    'margin': 40.0},
#   {'Venue': 'Wankhede Stadium',
#    'winning_team': 'Mumbai Indians',
#    'won_by': 'Runs',
#    'margin': 37.0},
#   {'Venue': 'Wankhede Stadium',
#    'winning_team': 'Mumbai Indians',
#    'won_by': 'Runs',
#    'margin': 13.0},
#   {'Venue': 'Wankhede Stadium',
#    'winning_team': 'Mumbai Indians',
#    'won_by': 'Runs',
#    'margin': 5.0},
#   {'Venue': 'MA Chidambaram Stadium, Chepauk',
#    'winning_team': 'Mumbai Indians',
#    'won_by': 'Wickets',
#    'margin': 6.0}]}

# %%
df['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         18
# DA Warner         18
# MS Dhoni          17
#                   ..
# SA Asnodkar        1
# GD McGrath         1
# SM Katich          1
# JDP Oram           1
# MF Maharoof        1
# Name: count, Length: 263, dtype: int64

# %% [markdown]
# ## Toss Decision Analysis

# %%
def toss_decision_analysis():
    bat_first_and_wins = 0
    field_first_and_wins = 0
    for idx,match in df.iterrows():
        if match['TossWinner'] == match['WinningTeam']:
            if match['TossDecision'] == 'bat':
                bat_first_and_wins += 1
            else:
                field_first_and_wins += 1
    return {
        "chooes bat and wins": bat_first_and_wins,
        "chooes field and wins": field_first_and_wins,
        "total_matches": len(df)
    }

# %%
toss_decision_analysis()
# Out:
# {'chooes bat and wins': 159,
#  'chooes field and wins': 330,
#  'total_matches': 950}

# %% [markdown]
# ## or

# %%
def toss_decision_analysis():
    if df.empty:
        return {
            "chooses bat and wins": 0,
            "chooses field and wins": 0,
            "total_matches": 0
        }

    # Filter matches where TossWinner is also the WinningTeam
    winning_toss = df[df['TossWinner'] == df['WinningTeam']]

    # Count occurrences of each TossDecision
    decision_counts = winning_toss['TossDecision'].value_counts()

    return {
        "chooses bat and wins": int(decision_counts.get('bat', 0)),
        "chooses field and wins": int(decision_counts.get('field', 0)),
        "total_matches": len(df)
    }

# %%
def toss_decision_analysis():
    if df.empty:
        return {
            "chooses bat and wins": 0,
            "chooses field and wins": 0,
            "total matches": 0,
            "total toss winners": 0,
            "win percentage after choosing bat": "0%",
            "win percentage after choosing field": "0%",
            "total teams batting first and winning": 0,
            "total teams fielding first and winning": 0,
            "overall toss winner win percentage": "0%"
        }

    # Count total matches
    total_matches = len(df)

    # Filter matches where TossWinner is also the WinningTeam
    toss_winners = df[df['TossWinner'] == df['WinningTeam']]
    total_toss_winners = len(toss_winners)

    # Count occurrences of TossDecision when TossWinner = WinningTeam
    decision_counts = toss_winners['TossDecision'].value_counts()

    # Matches where the **batting** team won
    bat_first_wins = len(df[df['WinningTeam'] == df['TeamBatFirst']])

    # Matches where the **fielding** team won
    field_first_wins = len(df[df['WinningTeam'] == df['TeamBowlFirst']])

    # Calculate win percentages safely (avoid division by zero)
    def win_percentage(wins, total):
        return f"{round((wins / total) * 100, 2)}%" if total > 0 else "0%"

    return {
        "chooses bat and wins": int(decision_counts.get('bat', 0)),
        "chooses field and wins": int(decision_counts.get('field', 0)),
        "total matches": total_matches,
        "total toss winners": total_toss_winners,
        "win percentage after choosing bat": win_percentage(decision_counts.get('bat', 0), total_toss_winners),
        "win percentage after choosing field": win_percentage(decision_counts.get('field', 0), total_toss_winners),
        "total teams batting first and winning": bat_first_wins,
        "total teams fielding first and winning": field_first_wins,
        "overall toss winner win percentage": win_percentage(total_toss_winners, total_matches)
    }

# %%
toss_decision_analysis()
# Out:
# {'chooses bat and wins': 159,
#  'chooses field and wins': 330,
#  'total_matches': 950}

# %%
df.head(5)
# Out:
#               City        Date Season  MatchNumber  \
# ID
# 1312200  Ahmedabad  2022-05-29   2022        Final
# 1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 1312198    Kolkata  2022-05-25   2022   Eliminator
# 1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 1304116     Mumbai  2022-05-22   2022           70
#
#                                Team1                 Team2  \
# ID
# 1312200             Rajasthan Royals        Gujarat Titans
# 1312199  Royal Challengers Bangalore      Rajasthan Royals
# 1312198  Royal Challengers Bangalore  Lucknow Super Giants
# 1312197             Rajasthan Royals        Gujarat Titans
# 1304116          Sunrisers Hyderabad          Punjab Kings
#
#                                     Venue            TossWinner TossDecision  \
# ID
# 1312200  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1312199  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 1312198             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 1312197             Eden Gardens, Kolkata        Gujarat Titans        field
# 1304116          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#         SuperOver                  WinningTeam    WonBy  Margin    method  \
# ID
# 1312200         N               Gujarat Titans  Wickets     7.0  Standard
# 1312199         N             Rajasthan Royals  Wickets     7.0  Standard
# 1312198         N  Royal Challengers Bangalore     Runs    14.0  Standard
# 1312197         N               Gujarat Titans  Wickets     7.0  Standard
# 1304116         N                 Punjab Kings  Wickets     5.0  Standard
#
#         Player_of_Match                                       Team1Players  \
# ID
# 1312200       HH Pandya  [YBK Jaiswal, JC Buttler, SV Samson, D Padikka...
# 1312199      JC Buttler  [V Kohli, F du Plessis, RM Patidar, GJ Maxwell...
# 1312198      RM Patidar  [V Kohli, F du Plessis, RM Patidar, GJ Maxwell...
# 1312197       DA Miller  [YBK Jaiswal, JC Buttler, SV Samson, D Padikka...
# 1304116   Harpreet Brar  [PK Garg, Abhishek Sharma, RA Tripathi, AK Mar...
#
#                                               Team2Players        Umpire1  \
# ID
# 1312200  [WP Saha, Shubman Gill, MS Wade, HH Pandya, DA...    CB Gaffaney
# 1312199  [YBK Jaiswal, JC Buttler, SV Samson, D Padikka...    CB Gaffaney
# 1312198  [Q de Kock, KL Rahul, M Vohra, DJ Hooda, MP St...  J Madanagopal
# 1312197  [WP Saha, Shubman Gill, MS Wade, HH Pandya, DA...   BNJ Oxenford
# 1304116  [JM Bairstow, S Dhawan, M Shahrukh Khan, MA Ag...   AK Chaudhary
#
#                Umpire2
# ID
# 1312200    Nitin Menon
# 1312199    Nitin Menon
# 1312198       MA Gough
# 1312197      VK Sharma
# 1304116  NA Patwardhan

# %% [markdown]
# ## team head to head

# %%
def head_to_head(team1, team2):
    # Filter head-to-head matches
    head_to_head_matches = df[
        ((df['Team1'] == team1) & (df['Team2'] == team2)) |
        ((df['Team1'] == team2) & (df['Team2'] == team1))
    ].copy()

    if head_to_head_matches.empty:
        return {
            "total_matches": 0,
            "matches": [],
            "win_count": {team1: 0, team2: 0},
            "win_percentage": {team1: "0%", team2: "0%"},
            "close_matches": 0,
            "super_over_count": 0,
            "last_winner": "No matches played"
        }

    # Count wins for each team
    win_counts = {team1: 0, team2: 0}
    for _, match in head_to_head_matches.iterrows():
        winner = match['WinningTeam']
        if winner == team1:
            win_counts[team1] += 1
        elif winner == team2:
            win_counts[team2] += 1

    total_matches = len(head_to_head_matches)

    # Calculate win percentage
    def win_percentage(wins, total):
        return f"{round((wins / total) * 100, 2)}%" if total > 0 else "0%"

    win_percentages = {
        team1: win_percentage(win_counts[team1], total_matches),
        team2: win_percentage(win_counts[team2], total_matches)
    }

    # Count close matches (won by ≤10 runs or ≤5 wickets)
    close_matches = sum(
        (match['WonBy'] == "Runs" and int(match['Margin']) <= 10) or
        (match['WonBy'] == "Wickets" and int(match['Margin']) <= 5)
        for _, match in head_to_head_matches.iterrows()
    )

    # Count Super Over matches
    super_over_count = sum(match['SuperOver'] == 'Y' for _, match in head_to_head_matches.iterrows())

    # Get last match winner
    last_match = head_to_head_matches.iloc[-1]
    last_winner = last_match['WinningTeam']

    # Convert match data to list format
    matches_list = []
    for idx, match in head_to_head_matches.iterrows():
        matches_list.append({
            'ID': idx,
            'Date': match['Date'],
            'MatchNumber': match['MatchNumber'],
            'Venue': match['Venue'],
            'TossWinner': match['TossWinner'],
            'TossDecision': match['TossDecision'],
            'SuperOver': 'No' if match['SuperOver'] == 'N' else 'Yes',
            'WonBy': match['WonBy'],
            'Margin': match['Margin'],
            'Player_of_Match': match['Player_of_Match'],
            team1: match['Team1Players'],
            team2: match['Team2Players'],
            'Umpire1': match['Umpire1'],
            'Umpire2': match['Umpire2']
        })

    return {
        "total_matches": total_matches,
        "matches": matches_list,
        "win_count": win_counts,
        "win_percentage": win_percentages,
        "close_matches": close_matches,
        "super_over_count": super_over_count,
        "last_winner": last_winner
    }

# %%
head_to_head('Chennai Super Kings','Mumbai Indians')
# Out:
# {'total_matches': 34,
#  'matches': [{'ID': 1304105,
#    'Date': '2022-05-12',
#    'MatchNumber': '59',
#    'Venue': 'Wankhede Stadium, Mumbai',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 5.0,
#    'Player_of_Match': 'DR Sams',
#    'Chennai Super Kings': ['RD Gaikwad',
#     'DP Conway',
#     'MM Ali',
#     'RV Uthappa',
#     'AT Rayudu',
#     'MS Dhoni',
#     'S Dube',
#     'DJ Bravo',
#     'Simarjeet Singh',
#     'M Theekshana',
#     'Mukesh Choudhary'],
#    'Mumbai Indians': ['Ishan Kishan',
#     'RG Sharma',
#     'DR Sams',
#     'Tilak Varma',
#     'T Stubbs',
#     'HR Shokeen',
#     'TH David',
#     'Ramandeep Singh',
#     'JJ Bumrah',
#     'RP Meredith',
#     'K Kartikeya'],
#    'Umpire1': 'Chirra Ravikanthreddy',
#    'Umpire2': 'CB Gaffaney'},
#   {'ID': 1304079,
#    'Date': '2022-04-21',
#    'MatchNumber': '33',
#    'Venue': 'Dr DY Patil Sports Academy, Mumbai',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 3.0,
#    'Player_of_Match': 'Mukesh Choudhary',
#    'Chennai Super Kings': ['RG Sharma',
#     'Ishan Kishan',
#     'D Brevis',
#     'SA Yadav',
#     'Tilak Varma',
#     'HR Shokeen',
#     'KA Pollard',
#     'DR Sams',
#     'JD Unadkat',
#     'RP Meredith',
#     'JJ Bumrah'],
#    'Mumbai Indians': ['RD Gaikwad',
#     'RV Uthappa',
#     'MJ Santner',
#     'AT Rayudu',
#     'S Dube',
#     'RA Jadeja',
#     'MS Dhoni',
#     'D Pretorius',
#     'DJ Bravo',
#     'Mukesh Choudhary',
#     'M Theekshana'],
#    'Umpire1': 'BNJ Oxenford',
#    'Umpire2': 'UV Gandhe'},
#   {'ID': 1254104,
#    'Date': '2021-09-19',
#    'MatchNumber': '30',
#    'Venue': 'Dubai International Cricket Stadium',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 20.0,
#    'Player_of_Match': 'RD Gaikwad',
#    'Chennai Super Kings': ['RD Gaikwad',
#     'F du Plessis',
#     'MM Ali',
#     'AT Rayudu',
#     'SK Raina',
#     'MS Dhoni',
#     'RA Jadeja',
#     'DJ Bravo',
#     'SN Thakur',
#     'DL Chahar',
#     'JR Hazlewood'],
#    'Mumbai Indians': ['Q de Kock',
#     'Anmolpreet Singh',
#     'SA Yadav',
#     'Ishan Kishan',
#     'SS Tiwary',
#     'KA Pollard',
#     'KH Pandya',
#     'AF Milne',
#     'RD Chahar',
#     'JJ Bumrah',
#     'TA Boult'],
#    'Umpire1': 'Nitin Menon',
#    'Umpire2': 'RK Illingworth'},
#   {'ID': 1254084,
#    'Date': '2021-05-01',
#    'MatchNumber': '27',
#    'Venue': 'Arun Jaitley Stadium, Delhi',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 4.0,
#    'Player_of_Match': 'KA Pollard',
#    'Chennai Super Kings': ['RD Gaikwad',
#     'F du Plessis',
#     'MM Ali',
#     'SK Raina',
#     'AT Rayudu',
#     'RA Jadeja',
#     'MS Dhoni',
#     'SM Curran',
#     'SN Thakur',
#     'DL Chahar',
#     'L Ngidi'],
#    'Mumbai Indians': ['Q de Kock',
#     'RG Sharma',
#     'SA Yadav',
#     'KH Pandya',
#     'KA Pollard',
#     'HH Pandya',
#     'JDS Neesham',
#     'DS Kulkarni',
#     'RD Chahar',
#     'JJ Bumrah',
#     'TA Boult'],
#    'Umpire1': 'KN Ananthapadmanabhan',
#    'Umpire2': 'CK Nandan'},
#   {'ID': 1216521,
#    'Date': '2020-10-23',
#    'MatchNumber': '41',
#    'Venue': 'Sharjah Cricket Stadium',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 10.0,
#    'Player_of_Match': 'TA Boult',
#    'Chennai Super Kings': ['RD Gaikwad',
#     'F du Plessis',
#     'AT Rayudu',
#     'N Jagadeesan',
#     'MS Dhoni',
#     'RA Jadeja',
#     'SM Curran',
#     'DL Chahar',
#     'SN Thakur',
#     'Imran Tahir',
#     'JR Hazlewood'],
#    'Mumbai Indians': ['Q de Kock',
#     'Ishan Kishan',
#     'SA Yadav',
#     'SS Tiwary',
#     'KH Pandya',
#     'HH Pandya',
#     'KA Pollard',
#     'NM Coulter-Nile',
#     'RD Chahar',
#     'TA Boult',
#     'JJ Bumrah'],
#    'Umpire1': 'C Shamshuddin',
#    'Umpire2': 'VA Kulkarni'},
#   {'ID': 1216492,
#    'Date': '2020-09-19',
#    'MatchNumber': '1',
#    'Venue': 'Sheikh Zayed Stadium',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 5.0,
#    'Player_of_Match': 'AT Rayudu',
#    'Chennai Super Kings': ['RG Sharma',
#     'Q de Kock',
#     'SA Yadav',
#     'SS Tiwary',
#     'HH Pandya',
#     'KA Pollard',
#     'KH Pandya',
#     'JL Pattinson',
#     'RD Chahar',
#     'TA Boult',
#     'JJ Bumrah'],
#    'Mumbai Indians': ['M Vijay',
#     'SR Watson',
#     'F du Plessis',
#     'AT Rayudu',
#     'RA Jadeja',
#     'SM Curran',
#     'MS Dhoni',
#     'KM Jadhav',
#     'PP Chawla',
#     'DL Chahar',
#     'L Ngidi'],
#    'Umpire1': 'CB Gaffaney',
#    'Umpire2': 'VK Sharma'},
#   {'ID': 1181768,
#    'Date': '2019-05-12',
#    'MatchNumber': 'Final',
#    'Venue': 'Rajiv Gandhi International Stadium',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 1.0,
#    'Player_of_Match': 'JJ Bumrah',
#    'Chennai Super Kings': ['Q de Kock',
#     'RG Sharma',
#     'SA Yadav',
#     'Ishan Kishan',
#     'KH Pandya',
#     'KA Pollard',
#     'HH Pandya',
#     'RD Chahar',
#     'MJ McClenaghan',
#     'JJ Bumrah',
#     'SL Malinga'],
#    'Mumbai Indians': ['F du Plessis',
#     'SR Watson',
#     'SK Raina',
#     'AT Rayudu',
#     'MS Dhoni',
#     'DJ Bravo',
#     'RA Jadeja',
#     'SN Thakur',
#     'DL Chahar',
#     'Harbhajan Singh',
#     'Imran Tahir'],
#    'Umpire1': 'IJ Gould',
#    'Umpire2': 'Nitin Menon'},
#   {'ID': 1181764,
#    'Date': '2019-05-07',
#    'MatchNumber': 'Qualifier',
#    'Venue': 'MA Chidambaram Stadium',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 6.0,
#    'Player_of_Match': 'SA Yadav',
#    'Chennai Super Kings': ['F du Plessis',
#     'SR Watson',
#     'SK Raina',
#     'M Vijay',
#     'AT Rayudu',
#     'MS Dhoni',
#     'RA Jadeja',
#     'DJ Bravo',
#     'DL Chahar',
#     'Harbhajan Singh',
#     'Imran Tahir'],
#    'Mumbai Indians': ['RG Sharma',
#     'Q de Kock',
#     'SA Yadav',
#     'Ishan Kishan',
#     'KH Pandya',
#     'HH Pandya',
#     'KA Pollard',
#     'J Yadav',
#     'RD Chahar',
#     'SL Malinga',
#     'JJ Bumrah'],
#    'Umpire1': 'NJ Llong',
#    'Umpire2': 'Nitin Menon'},
#   {'ID': 1178419,
#    'Date': '2019-04-26',
#    'MatchNumber': '44',
#    'Venue': 'MA Chidambaram Stadium',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 46.0,
#    'Player_of_Match': 'RG Sharma',
#    'Chennai Super Kings': ['RG Sharma',
#     'Q de Kock',
#     'E Lewis',
#     'KH Pandya',
#     'HH Pandya',
#     'KA Pollard',
#     'SA Yadav',
#     'AS Roy',
#     'RD Chahar',
#     'JJ Bumrah',
#     'SL Malinga'],
#    'Mumbai Indians': ['M Vijay',
#     'SR Watson',
#     'SK Raina',
#     'AT Rayudu',
#     'KM Jadhav',
#     'DR Shorey',
#     'DJ Bravo',
#     'MJ Santner',
#     'DL Chahar',
#     'Harbhajan Singh',
#     'Imran Tahir'],
#    'Umpire1': 'AK Chaudhary',
#    'Umpire2': 'NJ Llong'},
#   {'ID': 1175370,
#    'Date': '2019-04-03',
#    'MatchNumber': '15',
#    'Venue': 'Wankhede Stadium',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 37.0,
#    'Player_of_Match': 'HH Pandya',
#    'Chennai Super Kings': ['Q de Kock',
#     'RG Sharma',
#     'SA Yadav',
#     'Yuvraj Singh',
#     'KH Pandya',
#     'HH Pandya',
#     'KA Pollard',
#     'JP Behrendorff',
#     'RD Chahar',
#     'SL Malinga',
#     'JJ Bumrah'],
#    'Mumbai Indians': ['SR Watson',
#     'AT Rayudu',
#     'SK Raina',
#     'KM Jadhav',
#     'MS Dhoni',
#     'RA Jadeja',
#     'DJ Bravo',
#     'DL Chahar',
#     'SN Thakur',
#     'MM Sharma',
#     'Imran Tahir'],
#    'Umpire1': 'BNJ Oxenford',
#    'Umpire2': 'RJ Tucker'},
#   {'ID': 1136587,
#    'Date': '2018-04-28',
#    'MatchNumber': '27',
#    'Venue': 'Maharashtra Cricket Association Stadium',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 8.0,
#    'Player_of_Match': 'RG Sharma',
#    'Chennai Super Kings': ['SR Watson',
#     'AT Rayudu',
#     'SK Raina',
#     'MS Dhoni',
#     'DJ Bravo',
#     'SW Billings',
#     'RA Jadeja',
#     'Harbhajan Singh',
#     'DL Chahar',
#     'SN Thakur',
#     'Imran Tahir'],
#    'Mumbai Indians': ['SA Yadav',
#     'E Lewis',
#     'RG Sharma',
#     'HH Pandya',
#     'Ishan Kishan',
#     'JP Duminy',
#     'KH Pandya',
#     'BCJ Cutting',
#     'MJ McClenaghan',
#     'M Markande',
#     'JJ Bumrah'],
#    'Umpire1': 'CB Gaffaney',
#    'Umpire2': 'Nitin Menon'},
#   {'ID': 1136561,
#    'Date': '2018-04-07',
#    'MatchNumber': '1',
#    'Venue': 'Wankhede Stadium',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 1.0,
#    'Player_of_Match': 'DJ Bravo',
#    'Chennai Super Kings': ['RG Sharma',
#     'E Lewis',
#     'Ishan Kishan',
#     'SA Yadav',
#     'HH Pandya',
#     'KH Pandya',
#     'KA Pollard',
#     'JJ Bumrah',
#     'MJ McClenaghan',
#     'Mustafizur Rahman',
#     'M Markande'],
#    'Mumbai Indians': ['SR Watson',
#     'AT Rayudu',
#     'SK Raina',
#     'KM Jadhav',
#     'MS Dhoni',
#     'RA Jadeja',
#     'DJ Bravo',
#     'DL Chahar',
#     'Harbhajan Singh',
#     'MA Wood',
#     'Imran Tahir'],
#    'Umpire1': 'CB Gaffaney',
#    'Umpire2': 'A Nand Kishore'},
#   {'ID': 829823,
#    'Date': '2015-05-24',
#    'MatchNumber': 'Final',
#    'Venue': 'Eden Gardens',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 41.0,
#    'Player_of_Match': 'RG Sharma',
#    'Chennai Super Kings': ['LMP Simmons',
#     'PA Patel',
#     'RG Sharma',
#     'KA Pollard',
#     'AT Rayudu',
#     'HH Pandya',
#     'Harbhajan Singh',
#     'J Suchith',
#     'MJ McClenaghan',
#     'R Vinay Kumar',
#     'SL Malinga'],
#    'Mumbai Indians': ['DR Smith',
#     'MEK Hussey',
#     'SK Raina',
#     'MS Dhoni',
#     'DJ Bravo',
#     'P Negi',
#     'F du Plessis',
#     'RA Jadeja',
#     'R Ashwin',
#     'MM Sharma',
#     'A Nehra'],
#    'Umpire1': 'HDPK Dharmasena',
#    'Umpire2': 'RK Illingworth'},
#   {'ID': 829817,
#    'Date': '2015-05-19',
#    'MatchNumber': 'Qualifier 1',
#    'Venue': 'Wankhede Stadium',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 25.0,
#    'Player_of_Match': 'KA Pollard',
#    'Chennai Super Kings': ['DR Smith',
#     'MEK Hussey',
#     'F du Plessis',
#     'SK Raina',
#     'MS Dhoni',
#     'DJ Bravo',
#     'RA Jadeja',
#     'P Negi',
#     'R Ashwin',
#     'MM Sharma',
#     'A Nehra'],
#    'Mumbai Indians': ['LMP Simmons',
#     'PA Patel',
#     'RG Sharma',
#     'KA Pollard',
#     'HH Pandya',
#     'AT Rayudu',
#     'Harbhajan Singh',
#     'J Suchith',
#     'MJ McClenaghan',
#     'R Vinay Kumar',
#     'SL Malinga'],
#    'Umpire1': 'HDPK Dharmasena',
#    'Umpire2': 'RK Illingworth'},
#   {'ID': 829789,
#    'Date': '2015-05-08',
#    'MatchNumber': '43',
#    'Venue': 'MA Chidambaram Stadium, Chepauk',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 6.0,
#    'Player_of_Match': 'HH Pandya',
#    'Chennai Super Kings': ['DR Smith',
#     'BB McCullum',
#     'SK Raina',
#     'F du Plessis',
#     'MS Dhoni',
#     'P Negi',
#     'RA Jadeja',
#     'DJ Bravo',
#     'R Ashwin',
#     'MM Sharma',
#     'A Nehra'],
#    'Mumbai Indians': ['LMP Simmons',
#     'PA Patel',
#     'RG Sharma',
#     'KA Pollard',
#     'AT Rayudu',
#     'HH Pandya',
#     'Harbhajan Singh',
#     'J Suchith',
#     'R Vinay Kumar',
#     'MJ McClenaghan',
#     'M de Lange'],
#    'Umpire1': 'CB Gaffaney',
#    'Umpire2': 'CK Nandan'},
#   {'ID': 829729,
#    'Date': '2015-04-17',
#    'MatchNumber': '12',
#    'Venue': 'Wankhede Stadium',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 6.0,
#    'Player_of_Match': 'A Nehra',
#    'Chennai Super Kings': ['LMP Simmons',
#     'PA Patel',
#     'CJ Anderson',
#     'RG Sharma',
#     'Harbhajan Singh',
#     'KA Pollard',
#     'AT Rayudu',
#     'J Suchith',
#     'R Vinay Kumar',
#     'SL Malinga',
#     'P Suyal'],
#    'Mumbai Indians': ['DR Smith',
#     'BB McCullum',
#     'SK Raina',
#     'F du Plessis',
#     'MS Dhoni',
#     'DJ Bravo',
#     'RA Jadeja',
#     'R Ashwin',
#     'MM Sharma',
#     'IC Pandey',
#     'A Nehra'],
#    'Umpire1': 'AK Chaudhary',
#    'Umpire2': 'M Erasmus'},
#   {'ID': 734045,
#    'Date': '2014-05-28',
#    'MatchNumber': 'Eliminator',
#    'Venue': 'Brabourne Stadium',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 7.0,
#    'Player_of_Match': 'SK Raina',
#    'Chennai Super Kings': ['DR Smith',
#     'F du Plessis',
#     'SK Raina',
#     'BB McCullum',
#     'DJ Hussey',
#     'MS Dhoni',
#     'RA Jadeja',
#     'R Ashwin',
#     'MM Sharma',
#     'IC Pandey',
#     'A Nehra'],
#    'Mumbai Indians': ['LMP Simmons',
#     'MEK Hussey',
#     'CJ Anderson',
#     'RG Sharma',
#     'KA Pollard',
#     'AT Rayudu',
#     'AP Tare',
#     'Harbhajan Singh',
#     'P Kumar',
#     'PP Ojha',
#     'JJ Bumrah'],
#    'Umpire1': 'VA Kulkarni',
#    'Umpire2': 'BNJ Oxenford'},
#   {'ID': 733995,
#    'Date': '2014-05-10',
#    'MatchNumber': '33',
#    'Venue': 'Wankhede Stadium',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 4.0,
#    'Player_of_Match': 'DR Smith',
#    'Chennai Super Kings': ['LMP Simmons',
#     'CM Gautam',
#     'AT Rayudu',
#     'RG Sharma',
#     'KA Pollard',
#     'CJ Anderson',
#     'AP Tare',
#     'Harbhajan Singh',
#     'SL Malinga',
#     'JJ Bumrah',
#     'P Kumar'],
#    'Mumbai Indians': ['DR Smith',
#     'BB McCullum',
#     'SK Raina',
#     'F du Plessis',
#     'MS Dhoni',
#     'RA Jadeja',
#     'M Manhas',
#     'R Ashwin',
#     'IC Pandey',
#     'MM Sharma',
#     'S Badree'],
#    'Umpire1': 'HDPK Dharmasena',
#    'Umpire2': 'VA Kulkarni'},
#   {'ID': 729303,
#    'Date': '2014-04-25',
#    'MatchNumber': '13',
#    'Venue': 'Dubai International Cricket Stadium',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 7.0,
#    'Player_of_Match': 'MM Sharma',
#    'Chennai Super Kings': ['DR Smith',
#     'BB McCullum',
#     'SK Raina',
#     'F du Plessis',
#     'MS Dhoni',
#     'M Manhas',
#     'RA Jadeja',
#     'R Ashwin',
#     'BW Hilfenhaus',
#     'IC Pandey',
#     'MM Sharma'],
#    'Mumbai Indians': ['MEK Hussey',
#     'AP Tare',
#     'CJ Anderson',
#     'RG Sharma',
#     'KA Pollard',
#     'AT Rayudu',
#     'CM Gautam',
#     'Harbhajan Singh',
#     'Z Khan',
#     'PP Ojha',
#     'SL Malinga'],
#    'Umpire1': 'BF Bowden',
#    'Umpire2': 'M Erasmus'},
#   {'ID': 598073,
#    'Date': '2013-05-26',
#    'MatchNumber': 'Final',
#    'Venue': 'Eden Gardens',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 23.0,
#    'Player_of_Match': 'KA Pollard',
#    'Chennai Super Kings': ['MEK Hussey',
#     'M Vijay',
#     'SK Raina',
#     'S Badrinath',
#     'DJ Bravo',
#     'RA Jadeja',
#     'MS Dhoni',
#     'JA Morkel',
#     'CH Morris',
#     'R Ashwin',
#     'MM Sharma'],
#    'Mumbai Indians': ['DR Smith',
#     'AP Tare',
#     'KD Karthik',
#     'RG Sharma',
#     'AT Rayudu',
#     'KA Pollard',
#     'Harbhajan Singh',
#     'R Dhawan',
#     'MG Johnson',
#     'SL Malinga',
#     'PP Ojha'],
#    'Umpire1': 'HDPK Dharmasena',
#    'Umpire2': 'SJA Taufel'},
#   {'ID': 598070,
#    'Date': '2013-05-21',
#    'MatchNumber': 'Qualifier 1',
#    'Venue': 'Feroz Shah Kotla',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 48.0,
#    'Player_of_Match': 'MEK Hussey',
#    'Chennai Super Kings': ['MEK Hussey',
#     'M Vijay',
#     'SK Raina',
#     'MS Dhoni',
#     'RA Jadeja',
#     'S Badrinath',
#     'DJ Bravo',
#     'JA Morkel',
#     'CH Morris',
#     'R Ashwin',
#     'MM Sharma'],
#    'Mumbai Indians': ['DR Smith',
#     'AP Tare',
#     'KD Karthik',
#     'RG Sharma',
#     'KA Pollard',
#     'AT Rayudu',
#     'Harbhajan Singh',
#     'MG Johnson',
#     'SL Malinga',
#     'PP Ojha',
#     'MM Patel'],
#    'Umpire1': 'NJ Llong',
#    'Umpire2': 'RJ Tucker'},
#   {'ID': 598046,
#    'Date': '2013-05-05',
#    'MatchNumber': '49',
#    'Venue': 'Wankhede Stadium',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 60.0,
#    'Player_of_Match': 'MG Johnson',
#    'Chennai Super Kings': ['DR Smith',
#     'SR Tendulkar',
#     'KD Karthik',
#     'KA Pollard',
#     'RG Sharma',
#     'AT Rayudu',
#     'Harbhajan Singh',
#     'MG Johnson',
#     'SL Malinga',
#     'PP Ojha',
#     'P Suyal'],
#    'Mumbai Indians': ['MEK Hussey',
#     'M Vijay',
#     'SK Raina',
#     'S Badrinath',
#     'DJ Bravo',
#     'R Ashwin',
#     'MS Dhoni',
#     'RA Jadeja',
#     'CH Morris',
#     'MM Sharma',
#     'B Laughlin'],
#    'Umpire1': 'HDPK Dharmasena',
#    'Umpire2': 'CK Nandan'},
#   {'ID': 598002,
#    'Date': '2013-04-06',
#    'MatchNumber': '5',
#    'Venue': 'MA Chidambaram Stadium, Chepauk',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 9.0,
#    'Player_of_Match': 'KA Pollard',
#    'Chennai Super Kings': ['MEK Hussey',
#     'M Vijay',
#     'SK Raina',
#     'DJ Bravo',
#     'S Badrinath',
#     'MS Dhoni',
#     'RA Jadeja',
#     'R Ashwin',
#     'B Laughlin',
#     'AS Rajpoot',
#     'DP Nannes'],
#    'Mumbai Indians': ['RT Ponting',
#     'SR Tendulkar',
#     'KD Karthik',
#     'RG Sharma',
#     'AT Rayudu',
#     'KA Pollard',
#     'DR Smith',
#     'Harbhajan Singh',
#     'MG Johnson',
#     'MM Patel',
#     'PP Ojha'],
#    'Umpire1': 'M Erasmus',
#    'Umpire2': 'VA Kulkarni'},
#   {'ID': 548379,
#    'Date': '2012-05-23',
#    'MatchNumber': 'Elimination Final',
#    'Venue': 'M Chinnaswamy Stadium',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 38.0,
#    'Player_of_Match': 'MS Dhoni',
#    'Chennai Super Kings': ['M Vijay',
#     'MEK Hussey',
#     'SK Raina',
#     'S Badrinath',
#     'MS Dhoni',
#     'RA Jadeja',
#     'DJ Bravo',
#     'JA Morkel',
#     'R Ashwin',
#     'BW Hilfenhaus',
#     'SB Jakati'],
#    'Mumbai Indians': ['SR Tendulkar',
#     'DR Smith',
#     'RG Sharma',
#     'KD Karthik',
#     'JEC Franklin',
#     'AT Rayudu',
#     'KA Pollard',
#     'Harbhajan Singh',
#     'SL Malinga',
#     'DS Kulkarni',
#     'RP Singh'],
#    'Umpire1': 'BF Bowden',
#    'Umpire2': 'HDPK Dharmasena'},
#   {'ID': 548355,
#    'Date': '2012-05-06',
#    'MatchNumber': '49',
#    'Venue': 'Wankhede Stadium',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 2.0,
#    'Player_of_Match': 'DR Smith',
#    'Chennai Super Kings': ['JEC Franklin',
#     'SR Tendulkar',
#     'RG Sharma',
#     'KD Karthik',
#     'AT Rayudu',
#     'DR Smith',
#     'RJ Peterson',
#     'Harbhajan Singh',
#     'SL Malinga',
#     'RP Singh',
#     'MM Patel'],
#    'Mumbai Indians': ['M Vijay',
#     'F du Plessis',
#     'SK Raina',
#     'DJ Bravo',
#     'MS Dhoni',
#     'JA Morkel',
#     'RA Jadeja',
#     'S Badrinath',
#     'R Ashwin',
#     'SB Jakati',
#     'BW Hilfenhaus'],
#    'Umpire1': 'Asad Rauf',
#    'Umpire2': 'S Asnani'},
#   {'ID': 548306,
#    'Date': '2012-04-04',
#    'MatchNumber': '1',
#    'Venue': 'MA Chidambaram Stadium, Chepauk',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 8.0,
#    'Player_of_Match': 'RE Levi',
#    'Chennai Super Kings': ['F du Plessis',
#     'M Vijay',
#     'SK Raina',
#     'DJ Bravo',
#     'JA Morkel',
#     'S Badrinath',
#     'MS Dhoni',
#     'RA Jadeja',
#     'R Ashwin',
#     'SB Jakati',
#     'DE Bollinger'],
#    'Mumbai Indians': ['RE Levi',
#     'SR Tendulkar',
#     'RG Sharma',
#     'AT Rayudu',
#     'JEC Franklin',
#     'KD Karthik',
#     'KA Pollard',
#     'Harbhajan Singh',
#     'SL Malinga',
#     'AN Ahmed',
#     'PP Ojha'],
#    'Umpire1': 'JD Cloete',
#    'Umpire2': 'SJA Taufel'},
#   {'ID': 501221,
#    'Date': '2011-04-22',
#    'MatchNumber': '25',
#    'Venue': 'Wankhede Stadium',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 8.0,
#    'Player_of_Match': 'Harbhajan Singh',
#    'Chennai Super Kings': ['R Sathish',
#     'SR Tendulkar',
#     'AT Rayudu',
#     'RG Sharma',
#     'A Symonds',
#     'KA Pollard',
#     'JEC Franklin',
#     'Harbhajan Singh',
#     'AN Ahmed',
#     'MM Patel',
#     'SL Malinga'],
#    'Mumbai Indians': ['MEK Hussey',
#     'M Vijay',
#     'SK Raina',
#     'S Badrinath',
#     'MS Dhoni',
#     'S Anirudha',
#     'JA Morkel',
#     'R Ashwin',
#     'Joginder Sharma',
#     'S Randiv',
#     'DE Bollinger'],
#    'Umpire1': 'Asad Rauf',
#    'Umpire2': 'AM Saheba'},
#   {'ID': 419165,
#    'Date': '2010-04-25',
#    'MatchNumber': 'Final',
#    'Venue': 'Dr DY Patil Sports Academy',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 22.0,
#    'Player_of_Match': 'SK Raina',
#    'Chennai Super Kings': ['M Vijay',
#     'ML Hayden',
#     'SK Raina',
#     'S Badrinath',
#     'MS Dhoni',
#     'JA Morkel',
#     'S Anirudha',
#     'R Ashwin',
#     'SB Jakati',
#     'DE Bollinger',
#     'M Muralitharan'],
#    'Mumbai Indians': ['S Dhawan',
#     'SR Tendulkar',
#     'AM Nayar',
#     'Harbhajan Singh',
#     'AT Rayudu',
#     'SS Tiwary',
#     'JP Duminy',
#     'KA Pollard',
#     'Z Khan',
#     'SL Malinga',
#     'CRD Fernando'],
#    'Umpire1': 'RE Koertzen',
#    'Umpire2': 'SJA Taufel'},
#   {'ID': 419142,
#    'Date': '2010-04-06',
#    'MatchNumber': '37',
#    'Venue': 'MA Chidambaram Stadium, Chepauk',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 24.0,
#    'Player_of_Match': 'SK Raina',
#    'Chennai Super Kings': ['M Vijay',
#     'ML Hayden',
#     'SK Raina',
#     'MS Dhoni',
#     'MEK Hussey',
#     'S Badrinath',
#     'R Ashwin',
#     'SB Jakati',
#     'DE Bollinger',
#     'S Tyagi',
#     'T Thushara'],
#    'Mumbai Indians': ['S Dhawan',
#     'SR Tendulkar',
#     'SS Tiwary',
#     'AT Rayudu',
#     'DJ Bravo',
#     'KA Pollard',
#     'R Sathish',
#     'R McLaren',
#     'Harbhajan Singh',
#     'AN Ahmed',
#     'SL Malinga'],
#    'Umpire1': 'S Asnani',
#    'Umpire2': 'DJ Harper'},
#   {'ID': 419125,
#    'Date': '2010-03-25',
#    'MatchNumber': '21',
#    'Venue': 'Brabourne Stadium, Mumbai',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 5.0,
#    'Player_of_Match': 'SR Tendulkar',
#    'Chennai Super Kings': ['PA Patel',
#     'ML Hayden',
#     'SK Raina',
#     'S Badrinath',
#     'MS Dhoni',
#     'JA Morkel',
#     'NLTC Perera',
#     'Joginder Sharma',
#     'L Balaji',
#     'M Muralitharan',
#     'SB Jakati'],
#    'Mumbai Indians': ['S Dhawan',
#     'SR Tendulkar',
#     'SS Tiwary',
#     'R Sathish',
#     'KA Pollard',
#     'DJ Bravo',
#     'R McLaren',
#     'AP Tare',
#     'Harbhajan Singh',
#     'Z Khan',
#     'SL Malinga'],
#    'Umpire1': 'AM Saheba',
#    'Umpire2': 'BF Bowden'},
#   {'ID': 392227,
#    'Date': '2009-05-16',
#    'MatchNumber': '47',
#    'Venue': "St George's Park",
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'bat',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 7.0,
#    'Player_of_Match': 'ML Hayden',
#    'Chennai Super Kings': ['PA Patel',
#     'ML Hayden',
#     'SK Raina',
#     'S Badrinath',
#     'MS Dhoni',
#     'JDP Oram',
#     'JA Morkel',
#     'SB Jakati',
#     'L Balaji',
#     'M Muralitharan',
#     'S Tyagi'],
#    'Mumbai Indians': ['ST Jayasuriya',
#     'DJ Bravo',
#     'JP Duminy',
#     'SR Tendulkar',
#     'AM Nayar',
#     'Harbhajan Singh',
#     'YV Takawale',
#     'AM Rahane',
#     'DS Kulkarni',
#     'SL Malinga',
#     'C Nanda'],
#    'Umpire1': 'SK Tarapore',
#    'Umpire2': 'SJA Taufel'},
#   {'ID': 392181,
#    'Date': '2009-04-18',
#    'MatchNumber': '1',
#    'Venue': 'Newlands',
#    'TossWinner': 'Chennai Super Kings',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 19.0,
#    'Player_of_Match': 'SR Tendulkar',
#    'Chennai Super Kings': ['PA Patel',
#     'ML Hayden',
#     'SK Raina',
#     'A Flintoff',
#     'MS Dhoni',
#     'JDP Oram',
#     'S Badrinath',
#     'Joginder Sharma',
#     'T Thushara',
#     'MS Gony',
#     'R Ashwin'],
#    'Mumbai Indians': ['ST Jayasuriya',
#     'SR Tendulkar',
#     'S Dhawan',
#     'JP Duminy',
#     'DJ Bravo',
#     'AM Nayar',
#     'Harbhajan Singh',
#     'Z Khan',
#     'PR Shah',
#     'SL Malinga',
#     'RR Raje'],
#    'Umpire1': 'BR Doctrove',
#    'Umpire2': 'K Hariharan'},
#   {'ID': 336018,
#    'Date': '2008-05-14',
#    'MatchNumber': '36',
#    'Venue': 'Wankhede Stadium',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Wickets',
#    'Margin': 9.0,
#    'Player_of_Match': 'ST Jayasuriya',
#    'Chennai Super Kings': ['ST Jayasuriya',
#     'SR Tendulkar',
#     'RV Uthappa',
#     'DJ Thornely',
#     'DJ Bravo',
#     'AM Nayar',
#     'SM Pollock',
#     'YV Takawale',
#     'RR Raje',
#     'A Nehra',
#     'DS Kulkarni'],
#    'Mumbai Indians': ['S Vidyut',
#     'SP Fleming',
#     'SK Raina',
#     'S Badrinath',
#     'CK Kapugedera',
#     'MS Dhoni',
#     'JA Morkel',
#     'Joginder Sharma',
#     'MS Gony',
#     'L Balaji',
#     'M Muralitharan'],
#    'Umpire1': 'BR Doctrove',
#    'Umpire2': 'AM Saheba'},
#   {'ID': 335989,
#    'Date': '2008-04-23',
#    'MatchNumber': '8',
#    'Venue': 'MA Chidambaram Stadium, Chepauk',
#    'TossWinner': 'Mumbai Indians',
#    'TossDecision': 'field',
#    'SuperOver': 'No',
#    'WonBy': 'Runs',
#    'Margin': 6.0,
#    'Player_of_Match': 'ML Hayden',
#    'Chennai Super Kings': ['PA Patel',
#     'ML Hayden',
#     'MEK Hussey',
#     'SK Raina',
#     'MS Dhoni',
#     'JDP Oram',
#     'S Badrinath',
#     'Joginder Sharma',
#     'P Amarnath',
#     'MS Gony',
#     'M Muralitharan'],
#    'Mumbai Indians': ['L Ronchi',
#     'ST Jayasuriya',
#     'RV Uthappa',
#     'SM Pollock',
#     'DJ Bravo',
#     'AM Nayar',
#     'MA Khote',
#     'Harbhajan Singh',
#     'A Nehra',
#     'VS Yeligati',
#     'DS Kulkarni'],
#    'Umpire1': 'DJ Harper',
#    'Umpire2': 'GA Pratapkumar'}],
#  'win_count': {'Chennai Super Kings': 14, 'Mumbai Indians': 20},
#  'win_percentage': {'Chennai Super Kings': '41.18%',
#   'Mumbai Indians': '58.82%'},
#  'close_matches': 12,
#  'super_over_count': 0,
#  'last_winner': 'Chennai Super Kings'}

# %% [markdown]
# ## Margin of Victory Analysis

# %%
def matches_by_margin(margin_type, margin_value):
    if margin_type not in ['Runs','Wickets']:
        return {'error':'Invalid Winning type'}
    
    # Filter matches meeting the margin criteria
    filtered_data = df.loc[(df['WonBy'] == margin_type) & (df['Margin'] >= margin_value)]
    
    if filtered_data.empty:
        return {
            "total_matches": 0,
            "average_margin": None,
            "top_winning_team": None,
            "matches": []
        }

    # Extract relevant match details
    margin_matches = filtered_data[['WinningTeam', 'Margin']].to_dict(orient='records')

    # Additional analysis
    total_matches = len(filtered_data)
    avg_margin = filtered_data['Margin'].mean()
    top_winning_team = filtered_data['WinningTeam'].mode()[0]  # Most frequent winning team

    return {
        "total_matches": total_matches,
        "average_margin": float(round(avg_margin, 2)),
        "top_winning_team": top_winning_team,
        "matches": margin_matches
    }

# %%
matches_by_margin('Runs',7)
# Out:
# {'total_matches': 364,
#  'average_margin': 34.39,
#  'top_winning_team': 'Mumbai Indians',
#  'matches': [{'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 14.0},
#   {'WinningTeam': 'Delhi Capitals', 'Margin': 17.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 24.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 54.0},
#   {'WinningTeam': 'Punjab Kings', 'Margin': 54.0},
#   {'WinningTeam': 'Gujarat Titans', 'Margin': 62.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 52.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 91.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 67.0},
#   {'WinningTeam': 'Lucknow Super Giants', 'Margin': 75.0},
#   {'WinningTeam': 'Delhi Capitals', 'Margin': 21.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 13.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 13.0},
#   {'WinningTeam': 'Lucknow Super Giants', 'Margin': 20.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 29.0},
#   {'WinningTeam': 'Punjab Kings', 'Margin': 11.0},
#   {'WinningTeam': 'Lucknow Super Giants', 'Margin': 36.0},
#   {'WinningTeam': 'Gujarat Titans', 'Margin': 8.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 15.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 18.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 7.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 16.0},
#   {'WinningTeam': 'Lucknow Super Giants', 'Margin': 18.0},
#   {'WinningTeam': 'Gujarat Titans', 'Margin': 37.0},
#   {'WinningTeam': 'Punjab Kings', 'Margin': 12.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 23.0},
#   {'WinningTeam': 'Delhi Capitals', 'Margin': 44.0},
#   {'WinningTeam': 'Lucknow Super Giants', 'Margin': 12.0},
#   {'WinningTeam': 'Punjab Kings', 'Margin': 54.0},
#   {'WinningTeam': 'Gujarat Titans', 'Margin': 14.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 23.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 61.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 27.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 42.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 86.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 54.0},
#   {'WinningTeam': 'Delhi Capitals', 'Margin': 33.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 20.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 55.0},
#   {'WinningTeam': 'Punjab Kings', 'Margin': 34.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 69.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 18.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 45.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 38.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 13.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 10.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 10.0},
#   {'WinningTeam': 'Delhi Capitals', 'Margin': 17.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 57.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 60.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 88.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 12.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 59.0},
#   {'WinningTeam': 'Delhi Capitals', 'Margin': 13.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 20.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 82.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 37.0},
#   {'WinningTeam': 'Delhi Capitals', 'Margin': 46.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 69.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 10.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 57.0},
#   {'WinningTeam': 'Delhi Capitals', 'Margin': 59.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 34.0},
#   {'WinningTeam': 'Delhi Capitals', 'Margin': 18.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 7.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 48.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 37.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 15.0},
#   {'WinningTeam': 'Delhi Capitals', 'Margin': 44.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 97.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 49.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 16.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 10.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 80.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 45.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 34.0},
#   {'WinningTeam': 'Delhi Capitals', 'Margin': 16.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 46.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 17.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 10.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 40.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 12.0},
#   {'WinningTeam': 'Delhi Capitals', 'Margin': 39.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 40.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 22.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 37.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 14.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 118.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 8.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 28.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 14.0},
#   {'WinningTeam': 'Delhi Capitals', 'Margin': 37.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 14.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 25.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 11.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 30.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 34.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 14.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 31.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 102.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 15.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 13.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 14.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 13.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 11.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 55.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 13.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 31.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 64.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 15.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 46.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 71.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 19.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 10.0},
#   {'WinningTeam': 'Rising Pune Supergiant', 'Margin': 20.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 10.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 9.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 7.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 7.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 14.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 146.0},
#   {'WinningTeam': 'Rising Pune Supergiant', 'Margin': 12.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 19.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 48.0},
#   {'WinningTeam': 'Rising Pune Supergiant', 'Margin': 61.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 26.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 82.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 26.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 14.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 15.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 21.0},
#   {'WinningTeam': 'Rising Pune Supergiant', 'Margin': 27.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 51.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 17.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 97.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 15.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 35.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 8.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 22.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 22.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 82.0},
#   {'WinningTeam': 'Rising Pune Supergiants', 'Margin': 19.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 80.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 144.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 85.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 9.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 7.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 23.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 27.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 15.0},
#   {'WinningTeam': 'Rising Pune Supergiants', 'Margin': 34.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 25.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 10.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 13.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 45.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 41.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 71.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 25.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 9.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 22.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 12.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 39.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 7.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 13.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 138.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 35.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 24.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 23.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 14.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 22.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 8.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 20.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 97.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 20.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 37.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 16.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 27.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 18.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 18.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 45.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 26.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 24.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 28.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 15.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 16.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 30.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 25.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 62.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 16.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 32.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 32.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 44.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 19.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 10.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 34.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 15.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 23.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 7.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 72.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 93.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 41.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 23.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 48.0},
#   {'WinningTeam': 'Pune Warriors', 'Margin': 38.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 24.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 50.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 23.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 7.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 14.0},
#   {'WinningTeam': 'Pune Warriors', 'Margin': 7.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 33.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 30.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 46.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 77.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 65.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 60.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 17.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 15.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 37.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 14.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 15.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 58.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 130.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 86.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 87.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 11.0},
#   {'WinningTeam': 'Pune Warriors', 'Margin': 24.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 48.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 41.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 44.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 19.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 9.0},
#   {'WinningTeam': 'Sunrisers Hyderabad', 'Margin': 22.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 86.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 38.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 18.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 9.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 34.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 21.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 32.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 45.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 27.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 35.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 25.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 43.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 7.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 10.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 13.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 47.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 7.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 37.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 18.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 46.0},
#   {'WinningTeam': 'Pune Warriors', 'Margin': 20.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 13.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 59.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 27.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 42.0},
#   {'WinningTeam': 'Pune Warriors', 'Margin': 22.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 22.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 74.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 20.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 31.0},
#   {'WinningTeam': 'Pune Warriors', 'Margin': 28.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 58.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 43.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 82.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 11.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 111.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 29.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 10.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 18.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 76.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 63.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 32.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 10.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 85.0},
#   {'WinningTeam': 'Kochi Tuskers Kerala', 'Margin': 17.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 21.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 20.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 23.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 19.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 38.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 26.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 17.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 55.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 25.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 37.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 29.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 8.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 48.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 16.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 21.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 33.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 9.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 22.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 38.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 35.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 11.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 57.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 39.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 13.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 37.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 14.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 24.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 37.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 63.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 23.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 24.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 67.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 40.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 41.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 17.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 39.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 17.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 31.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 36.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 10.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 34.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 98.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 55.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 31.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 11.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 12.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 24.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 14.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 12.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 53.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 16.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 12.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 19.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 78.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 78.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 18.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 9.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 8.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 38.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 92.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 27.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 12.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 9.0},
#   {'WinningTeam': 'Deccan Chargers', 'Margin': 24.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 11.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 92.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 75.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 19.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 105.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 41.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 10.0},
#   {'WinningTeam': 'Royal Challengers Bangalore', 'Margin': 14.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 25.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 65.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 12.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 23.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 23.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 18.0},
#   {'WinningTeam': 'Mumbai Indians', 'Margin': 29.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 9.0},
#   {'WinningTeam': 'Rajasthan Royals', 'Margin': 45.0},
#   {'WinningTeam': 'Delhi Daredevils', 'Margin': 10.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 13.0},
#   {'WinningTeam': 'Kings XI Punjab', 'Margin': 66.0},
#   {'WinningTeam': 'Chennai Super Kings', 'Margin': 33.0},
#   {'WinningTeam': 'Kolkata Knight Riders', 'Margin': 140.0}]}

# %% [markdown]
# ## Player Participation Analysis

# %%
def player_matches(player_name, data):
    # Explode the lists in Team1Players and Team2Players
    df_exploded = data.copy()
    df_exploded = df_exploded.explode(['Team1Players','Team2Players'])

    # Filter matches where the player participated
    player_matches = df_exploded[
        (df_exploded['Team1Players'] == player_name) | (df_exploded['Team2Players'] == player_name)
    ].drop_duplicates()

    # Return default values if no matches found
    if player_matches.empty:
        return {
            "total_matches": 0,
            "win_percentage": None,
            "matches_won": 0,
            "matches_lost": 0,
            "opponents_faced": [],
            "super_over_matches": 0,
            "top_venues": [],
            "matches": []
        }
    
    # Determine player's team & opponent using vectorized operations
    player_matches["team"] = player_matches.apply(
        lambda row: row["Team1"] if row["Team1Players"] == player_name else row["Team2"], axis=1
    )
    player_matches["opponent"] = player_matches.apply(
        lambda row: row["Team2"] if row["team"] == row["Team1"] else row["Team1"], axis=1
    )

    # Determine match result using vectorized comparison
    player_matches["result"] = player_matches["WinningTeam"] == player_matches["team"]
    player_matches["result"] = player_matches["result"].map({True: "Won", False: "Lost"})

    # Count wins & losses
    match_results = player_matches["result"].value_counts()
    matches_won = match_results.get("Won", 0)
    matches_lost = match_results.get("Lost", 0)
    total_matches = matches_won + matches_lost
    win_percentage = round((matches_won / total_matches) * 100, 2) if total_matches > 0 else None

    # Count unique opponents
    opponents_faced = player_matches["opponent"].unique().tolist()

    # Count super over matches
    super_over_matches = (player_matches["SuperOver"] == "Y").sum()

    # Find top 3 venues
    top_venues = player_matches["Venue"].value_counts().head(3).index.tolist()

    # Extract match details
    match_details = player_matches[[
        "team", "opponent", "Venue", "result", "Margin", "WonBy", "Player_of_Match"
    ]].copy()

    # Format margin
    match_details["margin"] = match_details.apply(
        lambda row: f"{row['Margin']} {row['WonBy']}" if pd.notna(row["WonBy"]) else "N/A", axis=1
    )

    # Check if player was Player of the Match
    match_details["player_of_match"] = match_details["Player_of_Match"] == player_name
    match_details.drop(columns=["Player_of_Match", "WonBy", "Margin"], inplace=True)

    # Rename columns
    match_details.rename(columns={"Venue": "venue"}, inplace=True)

    return {
        "total_matches": total_matches,
        "win_percentage": win_percentage,
        "matches_won": matches_won,
        "matches_lost": matches_lost,
        "opponents_faced": opponents_faced,
        "super_over_matches": super_over_matches,
        "top_venues": top_venues,
        "matches": match_details.to_dict(orient="records")
    }

# %%
player_matches('HH Pandya',df)
# Out:
# {'total_matches': np.int64(107),
#  'win_percentage': np.float64(64.49),
#  'matches_won': np.int64(69),
#  'matches_lost': np.int64(38),
#  'opponents_faced': ['Rajasthan Royals',
#   'Royal Challengers Bangalore',
#   'Chennai Super Kings',
#   'Lucknow Super Giants',
#   'Mumbai Indians',
#   'Punjab Kings',
#   'Sunrisers Hyderabad',
#   'Kolkata Knight Riders',
#   'Delhi Capitals',
#   'Kings XI Punjab',
#   'Delhi Daredevils',
#   'Rising Pune Supergiants',
#   'Gujarat Lions'],
#  'super_over_matches': np.int64(4),
#  'top_venues': ['Wankhede Stadium',
#   'Sheikh Zayed Stadium',
#   'MA Chidambaram Stadium, Chepauk, Chennai'],
#  'matches': [{'team': 'Gujarat Titans',
#    'opponent': 'Rajasthan Royals',
#    'venue': 'Narendra Modi Stadium, Ahmedabad',
#    'result': 'Won',
#    'margin': '7.0 Wickets',
#    'player_of_match': True},
#   {'team': 'Gujarat Titans',
#    'opponent': 'Rajasthan Royals',
#    'venue': 'Eden Gardens, Kolkata',
#    'result': 'Won',
#    'margin': '7.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Gujarat Titans',
#    'opponent': 'Royal Challengers Bangalore',
#    'venue': 'Wankhede Stadium, Mumbai',
#    'result': 'Lost',
#    'margin': '8.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Gujarat Titans',
#    'opponent': 'Chennai Super Kings',
#    'venue': 'Wankhede Stadium, Mumbai',
#    'result': 'Won',
#    'margin': '7.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Gujarat Titans',
#    'opponent': 'Lucknow Super Giants',
#    'venue': 'Maharashtra Cricket Association Stadium, Pune',
#    'result': 'Won',
#    'margin': '62.0 Runs',
#    'player_of_match': False},
#   {'team': 'Gujarat Titans',
#    'opponent': 'Mumbai Indians',
#    'venue': 'Brabourne Stadium, Mumbai',
#    'result': 'Lost',
#    'margin': '5.0 Runs',
#    'player_of_match': False},
#   {'team': 'Gujarat Titans',
#    'opponent': 'Punjab Kings',
#    'venue': 'Dr DY Patil Sports Academy, Mumbai',
#    'result': 'Lost',
#    'margin': '8.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Gujarat Titans',
#    'opponent': 'Royal Challengers Bangalore',
#    'venue': 'Brabourne Stadium, Mumbai',
#    'result': 'Won',
#    'margin': '6.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Gujarat Titans',
#    'opponent': 'Sunrisers Hyderabad',
#    'venue': 'Wankhede Stadium, Mumbai',
#    'result': 'Won',
#    'margin': '5.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Gujarat Titans',
#    'opponent': 'Kolkata Knight Riders',
#    'venue': 'Dr DY Patil Sports Academy, Mumbai',
#    'result': 'Won',
#    'margin': '8.0 Runs',
#    'player_of_match': False},
#   {'team': 'Gujarat Titans',
#    'opponent': 'Rajasthan Royals',
#    'venue': 'Dr DY Patil Sports Academy, Mumbai',
#    'result': 'Won',
#    'margin': '37.0 Runs',
#    'player_of_match': True},
#   {'team': 'Gujarat Titans',
#    'opponent': 'Sunrisers Hyderabad',
#    'venue': 'Dr DY Patil Sports Academy, Mumbai',
#    'result': 'Lost',
#    'margin': '8.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Gujarat Titans',
#    'opponent': 'Punjab Kings',
#    'venue': 'Brabourne Stadium, Mumbai',
#    'result': 'Won',
#    'margin': '6.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Gujarat Titans',
#    'opponent': 'Delhi Capitals',
#    'venue': 'Maharashtra Cricket Association Stadium, Pune',
#    'result': 'Won',
#    'margin': '14.0 Runs',
#    'player_of_match': False},
#   {'team': 'Gujarat Titans',
#    'opponent': 'Lucknow Super Giants',
#    'venue': 'Wankhede Stadium, Mumbai',
#    'result': 'Won',
#    'margin': '5.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Sunrisers Hyderabad',
#    'venue': 'Zayed Cricket Stadium, Abu Dhabi',
#    'result': 'Won',
#    'margin': '42.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Rajasthan Royals',
#    'venue': 'Sharjah Cricket Stadium',
#    'result': 'Won',
#    'margin': '8.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Delhi Capitals',
#    'venue': 'Sharjah Cricket Stadium',
#    'result': 'Lost',
#    'margin': '4.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Punjab Kings',
#    'venue': 'Zayed Cricket Stadium, Abu Dhabi',
#    'result': 'Won',
#    'margin': '6.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Royal Challengers Bangalore',
#    'venue': 'Dubai International Cricket Stadium',
#    'result': 'Lost',
#    'margin': '54.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Chennai Super Kings',
#    'venue': 'Arun Jaitley Stadium, Delhi',
#    'result': 'Won',
#    'margin': '4.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Rajasthan Royals',
#    'venue': 'Arun Jaitley Stadium, Delhi',
#    'result': 'Won',
#    'margin': '7.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Punjab Kings',
#    'venue': 'MA Chidambaram Stadium, Chepauk, Chennai',
#    'result': 'Lost',
#    'margin': '9.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Delhi Capitals',
#    'venue': 'MA Chidambaram Stadium, Chepauk, Chennai',
#    'result': 'Lost',
#    'margin': '6.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Sunrisers Hyderabad',
#    'venue': 'MA Chidambaram Stadium, Chepauk, Chennai',
#    'result': 'Won',
#    'margin': '13.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kolkata Knight Riders',
#    'venue': 'MA Chidambaram Stadium, Chepauk, Chennai',
#    'result': 'Won',
#    'margin': '10.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Royal Challengers Bangalore',
#    'venue': 'MA Chidambaram Stadium, Chepauk, Chennai',
#    'result': 'Lost',
#    'margin': '2.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Delhi Capitals',
#    'venue': 'Dubai International Cricket Stadium',
#    'result': 'Won',
#    'margin': '5.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Delhi Capitals',
#    'venue': 'Dubai International Cricket Stadium',
#    'result': 'Won',
#    'margin': '57.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Royal Challengers Bangalore',
#    'venue': 'Sheikh Zayed Stadium',
#    'result': 'Won',
#    'margin': '5.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Rajasthan Royals',
#    'venue': 'Sheikh Zayed Stadium',
#    'result': 'Lost',
#    'margin': '8.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Chennai Super Kings',
#    'venue': 'Sharjah Cricket Stadium',
#    'result': 'Won',
#    'margin': '10.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kings XI Punjab',
#    'venue': 'Dubai International Cricket Stadium',
#    'result': 'Lost',
#    'margin': '0.0 SuperOver',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kolkata Knight Riders',
#    'venue': 'Sheikh Zayed Stadium',
#    'result': 'Won',
#    'margin': '8.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Delhi Capitals',
#    'venue': 'Sheikh Zayed Stadium',
#    'result': 'Won',
#    'margin': '5.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Rajasthan Royals',
#    'venue': 'Sheikh Zayed Stadium',
#    'result': 'Won',
#    'margin': '57.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Sunrisers Hyderabad',
#    'venue': 'Sharjah Cricket Stadium',
#    'result': 'Won',
#    'margin': '34.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kings XI Punjab',
#    'venue': 'Sheikh Zayed Stadium',
#    'result': 'Won',
#    'margin': '48.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Royal Challengers Bangalore',
#    'venue': 'Dubai International Cricket Stadium',
#    'result': 'Lost',
#    'margin': '0.0 SuperOver',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kolkata Knight Riders',
#    'venue': 'Sheikh Zayed Stadium',
#    'result': 'Won',
#    'margin': '49.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Chennai Super Kings',
#    'venue': 'Sheikh Zayed Stadium',
#    'result': 'Lost',
#    'margin': '5.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Chennai Super Kings',
#    'venue': 'Rajiv Gandhi International Stadium',
#    'result': 'Won',
#    'margin': '1.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Chennai Super Kings',
#    'venue': 'MA Chidambaram Stadium',
#    'result': 'Won',
#    'margin': '6.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kolkata Knight Riders',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '9.0 Wickets',
#    'player_of_match': True},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Sunrisers Hyderabad',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '0.0 SuperOver',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kolkata Knight Riders',
#    'venue': 'Eden Gardens',
#    'result': 'Lost',
#    'margin': '34.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Chennai Super Kings',
#    'venue': 'MA Chidambaram Stadium',
#    'result': 'Won',
#    'margin': '46.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Rajasthan Royals',
#    'venue': 'Sawai Mansingh Stadium',
#    'result': 'Lost',
#    'margin': '5.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Delhi Capitals',
#    'venue': 'Arun Jaitley Stadium',
#    'result': 'Won',
#    'margin': '40.0 Runs',
#    'player_of_match': True},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Royal Challengers Bangalore',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '5.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Rajasthan Royals',
#    'venue': 'Wankhede Stadium',
#    'result': 'Lost',
#    'margin': '4.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kings XI Punjab',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '3.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Sunrisers Hyderabad',
#    'venue': 'Rajiv Gandhi International Stadium',
#    'result': 'Won',
#    'margin': '40.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Chennai Super Kings',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '37.0 Runs',
#    'player_of_match': True},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kings XI Punjab',
#    'venue': 'Punjab Cricket Association IS Bindra Stadium',
#    'result': 'Lost',
#    'margin': '8.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Royal Challengers Bangalore',
#    'venue': 'M.Chinnaswamy Stadium',
#    'result': 'Won',
#    'margin': '6.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Delhi Capitals',
#    'venue': 'Wankhede Stadium',
#    'result': 'Lost',
#    'margin': '37.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Delhi Daredevils',
#    'venue': 'Arun Jaitley Stadium',
#    'result': 'Lost',
#    'margin': '11.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kings XI Punjab',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '3.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Rajasthan Royals',
#    'venue': 'Wankhede Stadium',
#    'result': 'Lost',
#    'margin': '7.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kolkata Knight Riders',
#    'venue': 'Eden Gardens',
#    'result': 'Won',
#    'margin': '102.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kolkata Knight Riders',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '13.0 Runs',
#    'player_of_match': True},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kings XI Punjab',
#    'venue': 'Holkar Cricket Stadium',
#    'result': 'Won',
#    'margin': '6.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Royal Challengers Bangalore',
#    'venue': 'M.Chinnaswamy Stadium',
#    'result': 'Lost',
#    'margin': '14.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Chennai Super Kings',
#    'venue': 'Maharashtra Cricket Association Stadium',
#    'result': 'Won',
#    'margin': '8.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Sunrisers Hyderabad',
#    'venue': 'Wankhede Stadium',
#    'result': 'Lost',
#    'margin': '31.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Rajasthan Royals',
#    'venue': 'Sawai Mansingh Stadium',
#    'result': 'Lost',
#    'margin': '3.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Royal Challengers Bangalore',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '46.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Delhi Daredevils',
#    'venue': 'Wankhede Stadium',
#    'result': 'Lost',
#    'margin': '7.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Chennai Super Kings',
#    'venue': 'Wankhede Stadium',
#    'result': 'Lost',
#    'margin': '1.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Rising Pune Supergiants',
#    'venue': 'Rajiv Gandhi International Stadium, Uppal',
#    'result': 'Won',
#    'margin': '1.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kolkata Knight Riders',
#    'venue': 'M Chinnaswamy Stadium',
#    'result': 'Won',
#    'margin': '6.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Rising Pune Supergiants',
#    'venue': 'Wankhede Stadium',
#    'result': 'Lost',
#    'margin': '20.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kolkata Knight Riders',
#    'venue': 'Eden Gardens',
#    'result': 'Won',
#    'margin': '9.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kings XI Punjab',
#    'venue': 'Wankhede Stadium',
#    'result': 'Lost',
#    'margin': '7.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Sunrisers Hyderabad',
#    'venue': 'Rajiv Gandhi International Stadium, Uppal',
#    'result': 'Lost',
#    'margin': '7.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Delhi Daredevils',
#    'venue': 'Feroz Shah Kotla',
#    'result': 'Won',
#    'margin': '146.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Royal Challengers Bangalore',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '5.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Gujarat Lions',
#    'venue': 'Saurashtra Cricket Association Stadium',
#    'result': 'Won',
#    'margin': '0.0 SuperOver',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Rising Pune Supergiants',
#    'venue': 'Wankhede Stadium',
#    'result': 'Lost',
#    'margin': '3.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Delhi Daredevils',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '14.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kings XI Punjab',
#    'venue': 'Holkar Cricket Stadium',
#    'result': 'Won',
#    'margin': '8.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Gujarat Lions',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '6.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Royal Challengers Bangalore',
#    'venue': 'M Chinnaswamy Stadium',
#    'result': 'Won',
#    'margin': '4.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Sunrisers Hyderabad',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '4.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kolkata Knight Riders',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '4.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Rising Pune Supergiants',
#    'venue': 'Maharashtra Cricket Association Stadium',
#    'result': 'Lost',
#    'margin': '7.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Gujarat Lions',
#    'venue': 'Green Park',
#    'result': 'Lost',
#    'margin': '6.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Sunrisers Hyderabad',
#    'venue': 'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#    'result': 'Lost',
#    'margin': '85.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Rising Pune Supergiants',
#    'venue': 'Maharashtra Cricket Association Stadium',
#    'result': 'Won',
#    'margin': '8.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kolkata Knight Riders',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '6.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kings XI Punjab',
#    'venue': 'Punjab Cricket Association IS Bindra Stadium, Mohali',
#    'result': 'Won',
#    'margin': '25.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Delhi Daredevils',
#    'venue': 'Feroz Shah Kotla',
#    'result': 'Lost',
#    'margin': '10.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Royal Challengers Bangalore',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '6.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Sunrisers Hyderabad',
#    'venue': 'Rajiv Gandhi International Stadium, Uppal',
#    'result': 'Lost',
#    'margin': '7.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Gujarat Lions',
#    'venue': 'Wankhede Stadium',
#    'result': 'Lost',
#    'margin': '3.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kolkata Knight Riders',
#    'venue': 'Eden Gardens',
#    'result': 'Won',
#    'margin': '6.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Rising Pune Supergiants',
#    'venue': 'Wankhede Stadium',
#    'result': 'Lost',
#    'margin': '9.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Chennai Super Kings',
#    'venue': 'Eden Gardens',
#    'result': 'Won',
#    'margin': '41.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Chennai Super Kings',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '25.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Sunrisers Hyderabad',
#    'venue': 'Rajiv Gandhi International Stadium, Uppal',
#    'result': 'Won',
#    'margin': '9.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Kolkata Knight Riders',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '5.0 Runs',
#    'player_of_match': True},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Royal Challengers Bangalore',
#    'venue': 'Wankhede Stadium',
#    'result': 'Lost',
#    'margin': '39.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Chennai Super Kings',
#    'venue': 'MA Chidambaram Stadium, Chepauk',
#    'result': 'Won',
#    'margin': '6.0 Wickets',
#    'player_of_match': True},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Delhi Daredevils',
#    'venue': 'Wankhede Stadium',
#    'result': 'Won',
#    'margin': '5.0 Wickets',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Delhi Daredevils',
#    'venue': 'Feroz Shah Kotla',
#    'result': 'Lost',
#    'margin': '37.0 Runs',
#    'player_of_match': False},
#   {'team': 'Mumbai Indians',
#    'opponent': 'Royal Challengers Bangalore',
#    'venue': 'M Chinnaswamy Stadium',
#    'result': 'Won',
#    'margin': '18.0 Runs',
#    'player_of_match': False}]}

# %%
x = df.explode(['Team1Players','Team2Players'])

# %%
player = 'HH Pandya'
y = x[(x['Team1Players']==player) | (x['Team2Players']==player)]

# %%
y.head()
# Out:
#               City        Date Season  MatchNumber                Team1  \
# ID
# 1312200  Ahmedabad  2022-05-29   2022        Final     Rajasthan Royals
# 1312197    Kolkata  2022-05-24   2022  Qualifier 1     Rajasthan Royals
# 1304113     Mumbai  2022-05-19   2022           67       Gujarat Titans
# 1304108     Mumbai  2022-05-15   2022           62  Chennai Super Kings
# 1304103       Pune  2022-05-10   2022           57       Gujarat Titans
#
#                                Team2  \
# ID
# 1312200               Gujarat Titans
# 1312197               Gujarat Titans
# 1304113  Royal Challengers Bangalore
# 1304108               Gujarat Titans
# 1304103         Lucknow Super Giants
#
#                                                  Venue           TossWinner  \
# ID
# 1312200               Narendra Modi Stadium, Ahmedabad     Rajasthan Royals
# 1312197                          Eden Gardens, Kolkata       Gujarat Titans
# 1304113                       Wankhede Stadium, Mumbai       Gujarat Titans
# 1304108                       Wankhede Stadium, Mumbai  Chennai Super Kings
# 1304103  Maharashtra Cricket Association Stadium, Pune       Gujarat Titans
#
#         TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# ID
# 1312200          bat         N               Gujarat Titans  Wickets     7.0
# 1312197        field         N               Gujarat Titans  Wickets     7.0
# 1304113          bat         N  Royal Challengers Bangalore  Wickets     8.0
# 1304108          bat         N               Gujarat Titans  Wickets     7.0
# 1304103          bat         N               Gujarat Titans     Runs    62.0
#
#            method Player_of_Match  Team1Players Team2Players  \
# ID
# 1312200  Standard       HH Pandya    D Padikkal    HH Pandya
# 1312197  Standard       DA Miller    D Padikkal    HH Pandya
# 1304113  Standard         V Kohli     HH Pandya   KD Karthik
# 1304108  Standard         WP Saha  N Jagadeesan    HH Pandya
# 1304103  Standard    Shubman Gill     HH Pandya    KS Sharma
#
#                        Umpire1           Umpire2
# ID
# 1312200            CB Gaffaney       Nitin Menon
# 1312197           BNJ Oxenford         VK Sharma
# 1304113  KN Ananthapadmanabhan  GR Sadashiv Iyer
# 1304108               R Pandit         VK Sharma
# 1304103  KN Ananthapadmanabhan          MA Gough

# %%
y['Player_team'] = y.apply(lambda row: row['Team1'] if player in row['Team1Players'] else row['Team2'], axis=1)
y['Player_team'].unique()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_96704\2016590512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['Player_team'] = y.apply(lambda row: row['Team1'] if player in row['Team1Players'] else row['Team2'], axis=1)
# array(['Gujarat Titans', 'Mumbai Indians'], dtype=object)

# %%
y[y['Player_team'] == y['WinningTeam']]
# Out:
#               City        Date Season  MatchNumber  \
# ID
# 1312200  Ahmedabad  2022-05-29   2022        Final
# 1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 1304108     Mumbai  2022-05-15   2022           62
# 1304103       Pune  2022-05-10   2022           57
# 1304089     Mumbai  2022-04-30   2022           43
# ...            ...         ...    ...          ...
# 829815   Hyderabad  2015-05-17   2015           56
# 829805      Mumbai  2015-05-14   2015           51
# 829789     Chennai  2015-05-08   2015           43
# 829783      Mumbai  2015-05-05   2015           39
# 829737   Bangalore  2015-04-19   2015           16
#
#                                Team1                  Team2  \
# ID
# 1312200             Rajasthan Royals         Gujarat Titans
# 1312197             Rajasthan Royals         Gujarat Titans
# 1304108          Chennai Super Kings         Gujarat Titans
# 1304103               Gujarat Titans   Lucknow Super Giants
# 1304089  Royal Challengers Bangalore         Gujarat Titans
# ...                              ...                    ...
# 829815           Sunrisers Hyderabad         Mumbai Indians
# 829805                Mumbai Indians  Kolkata Knight Riders
# 829789           Chennai Super Kings         Mumbai Indians
# 829783                Mumbai Indians       Delhi Daredevils
# 829737   Royal Challengers Bangalore         Mumbai Indians
#
#                                                  Venue  \
# ID
# 1312200               Narendra Modi Stadium, Ahmedabad
# 1312197                          Eden Gardens, Kolkata
# 1304108                       Wankhede Stadium, Mumbai
# 1304103  Maharashtra Cricket Association Stadium, Pune
# 1304089                      Brabourne Stadium, Mumbai
# ...                                                ...
# 829815       Rajiv Gandhi International Stadium, Uppal
# 829805                                Wankhede Stadium
# 829789                 MA Chidambaram Stadium, Chepauk
# 829783                                Wankhede Stadium
# 829737                           M Chinnaswamy Stadium
#
#                           TossWinner TossDecision SuperOver     WinningTeam  \
# ID
# 1312200             Rajasthan Royals          bat         N  Gujarat Titans
# 1312197               Gujarat Titans        field         N  Gujarat Titans
# 1304108          Chennai Super Kings          bat         N  Gujarat Titans
# 1304103               Gujarat Titans          bat         N  Gujarat Titans
# 1304089  Royal Challengers Bangalore          bat         N  Gujarat Titans
# ...                              ...          ...       ...             ...
# 829815           Sunrisers Hyderabad          bat         N  Mumbai Indians
# 829805         Kolkata Knight Riders        field         N  Mumbai Indians
# 829789           Chennai Super Kings          bat         N  Mumbai Indians
# 829783              Delhi Daredevils          bat         N  Mumbai Indians
# 829737   Royal Challengers Bangalore        field         N  Mumbai Indians
#
#            WonBy  Margin    method  Player_of_Match   Team1Players  \
# ID
# 1312200  Wickets     7.0  Standard        HH Pandya     D Padikkal
# 1312197  Wickets     7.0  Standard        DA Miller     D Padikkal
# 1304108  Wickets     7.0  Standard          WP Saha   N Jagadeesan
# 1304103     Runs    62.0  Standard     Shubman Gill      HH Pandya
# 1304089  Wickets     6.0  Standard        R Tewatia     GJ Maxwell
# ...          ...     ...       ...              ...            ...
# 829815   Wickets     9.0  Standard   MJ McClenaghan        NV Ojha
# 829805      Runs     5.0  Standard        HH Pandya      HH Pandya
# 829789   Wickets     6.0  Standard        HH Pandya         P Negi
# 829783   Wickets     5.0  Standard  Harbhajan Singh      HH Pandya
# 829737      Runs    18.0  Standard  Harbhajan Singh  Iqbal Abdulla
#
#         Team2Players                Umpire1      Umpire2     Player_team
# ID
# 1312200    HH Pandya            CB Gaffaney  Nitin Menon  Gujarat Titans
# 1312197    HH Pandya           BNJ Oxenford    VK Sharma  Gujarat Titans
# 1304108    HH Pandya               R Pandit    VK Sharma  Gujarat Titans
# 1304103    KS Sharma  KN Ananthapadmanabhan     MA Gough  Gujarat Titans
# 1304089    HH Pandya             HAS Khalid    VK Sharma  Gujarat Titans
# ...              ...                    ...          ...             ...
# 829815     HH Pandya            CB Gaffaney    K Srinath  Mumbai Indians
# 829805    AD Russell         RK Illingworth  VA Kulkarni  Mumbai Indians
# 829789     HH Pandya            CB Gaffaney    CK Nandan  Mumbai Indians
# 829783     JP Duminy        HDPK Dharmasena  CB Gaffaney  Mumbai Indians
# 829737     HH Pandya         RK Illingworth  VA Kulkarni  Mumbai Indians
#
# [69 rows x 20 columns]

# %% [markdown]
# ## Season(Year)-wise Match Summary

# %%
import pandas as pd

def matches_by_season(season_year):
    # Filter matches for the given season
    season_matches = df[df['Season'] == season_year]
    
    # Extract relevant match details
    matches_list = season_matches.apply(lambda match: {
        "date": match['Date'],
        "team1": match['Team1'],
        "team2": match['Team2'],
        "winning_team": match['WinningTeam'],
        "match_type": match['MatchNumber']
    }, axis=1).tolist()
    
    # Find the final match
    final_match = season_matches[season_matches['MatchNumber'] == 'Final']
    
    # Extract final match details
    final_match_details = None
    final_winner = None
    
    if not final_match.empty:
        final_match_details = {
            "date": final_match.iloc[0]['Date'],
            "team1": final_match.iloc[0]['Team1'],
            "team2": final_match.iloc[0]['Team2'],
            "winning_team": final_match.iloc[0]['WinningTeam'],
            "venue": final_match.iloc[0]['Venue'],
            "player_of_match": final_match.iloc[0]['Player_of_Match']
        }
        final_winner = final_match.iloc[0]['WinningTeam']
    
    # Player with the most "Player of the Match" awards
    player_of_match_counts = season_matches['Player_of_Match'].value_counts()
    top_player = player_of_match_counts.head(3).to_dict() if not player_of_match_counts.empty else None
    
    # Team performance (matches won, lost, win rate)
    teams = pd.concat([season_matches['Team1'], season_matches['Team2']]).unique()
    team_performance = {}
    
    for team in teams:
        matches_played = season_matches[(season_matches['Team1'] == team) | (season_matches['Team2'] == team)]
        matches_won = season_matches[season_matches['WinningTeam'] == team]
        matches_lost = matches_played.shape[0] - matches_won.shape[0]
        win_rate = (matches_won.shape[0] / matches_played.shape[0]) * 100 if matches_played.shape[0] > 0 else 0
        
        team_performance[team] = {
            "matches_played": matches_played.shape[0],
            "matches_won": matches_won.shape[0],
            "matches_lost": matches_lost,
            "win_rate": round(win_rate, 2)
        }
    
    # Venue that hosted the most matches
    venue_counts = season_matches['Venue'].value_counts()
    top_venue = venue_counts.head(3).to_dict() if not venue_counts.empty else None
    
    return {
        "season": season_year,
        "matches": matches_list,
        "final_match": final_match_details,
        "final_winner": final_winner,
        "top_player_of_match": top_player,
        "team_performance": team_performance,
        "top_venue": top_venue
    }

# %%
matches_by_season("2021")
# Out:
# {'season': '2021',
#  'matches': [{'date': '2021-10-15',
#    'team1': 'Chennai Super Kings',
#    'team2': 'Kolkata Knight Riders',
#    'winning_team': 'Chennai Super Kings',
#    'match_type': 'Final'},
#   {'date': '2021-10-13',
#    'team1': 'Delhi Capitals',
#    'team2': 'Kolkata Knight Riders',
#    'winning_team': 'Kolkata Knight Riders',
#    'match_type': 'Qualifier 2'},
#   {'date': '2021-10-11',
#    'team1': 'Royal Challengers Bangalore',
#    'team2': 'Kolkata Knight Riders',
#    'winning_team': 'Kolkata Knight Riders',
#    'match_type': 'Eliminator'},
#   {'date': '2021-10-10',
#    'team1': 'Delhi Capitals',
#    'team2': 'Chennai Super Kings',
#    'winning_team': 'Chennai Super Kings',
#    'match_type': 'Qualifier 1'},
#   {'date': '2021-10-08',
#    'team1': 'Delhi Capitals',
#    'team2': 'Royal Challengers Bangalore',
#    'winning_team': 'Royal Challengers Bangalore',
#    'match_type': '56'},
#   {'date': '2021-10-08',
#    'team1': 'Mumbai Indians',
#    'team2': 'Sunrisers Hyderabad',
#    'winning_team': 'Mumbai Indians',
#    'match_type': '55'},
#   {'date': '2021-10-07',
#    'team1': 'Kolkata Knight Riders',
#    'team2': 'Rajasthan Royals',
#    'winning_team': 'Kolkata Knight Riders',
#    'match_type': '54'},
#   {'date': '2021-10-07',
#    'team1': 'Chennai Super Kings',
#    'team2': 'Punjab Kings',
#    'winning_team': 'Punjab Kings',
#    'match_type': '53'},
#   {'date': '2021-10-06',
#    'team1': 'Sunrisers Hyderabad',
#    'team2': 'Royal Challengers Bangalore',
#    'winning_team': 'Sunrisers Hyderabad',
#    'match_type': '52'},
#   {'date': '2021-10-05',
#    'team1': 'Rajasthan Royals',
#    'team2': 'Mumbai Indians',
#    'winning_team': 'Mumbai Indians',
#    'match_type': '51'},
#   {'date': '2021-10-04',
#    'team1': 'Chennai Super Kings',
#    'team2': 'Delhi Capitals',
#    'winning_team': 'Delhi Capitals',
#    'match_type': '50'},
#   {'date': '2021-10-03',
#    'team1': 'Royal Challengers Bangalore',
#    'team2': 'Punjab Kings',
#    'winning_team': 'Royal Challengers Bangalore',
#    'match_type': '48'},
#   {'date': '2021-10-03',
#    'team1': 'Sunrisers Hyderabad',
#    'team2': 'Kolkata Knight Riders',
#    'winning_team': 'Kolkata Knight Riders',
#    'match_type': '49'},
#   {'date': '2021-10-02',
#    'team1': 'Mumbai Indians',
#    'team2': 'Delhi Capitals',
#    'winning_team': 'Delhi Capitals',
#    'match_type': '46'},
#   {'date': '2021-10-02',
#    'team1': 'Chennai Super Kings',
#    'team2': 'Rajasthan Royals',
#    'winning_team': 'Rajasthan Royals',
#    'match_type': '47'},
#   {'date': '2021-10-01',
#    'team1': 'Kolkata Knight Riders',
#    'team2': 'Punjab Kings',
#    'winning_team': 'Punjab Kings',
#    'match_type': '45'},
#   {'date': '2021-09-30',
#    'team1': 'Sunrisers Hyderabad',
#    'team2': 'Chennai Super Kings',
#    'winning_team': 'Chennai Super Kings',
#    'match_type': '44'},
#   {'date': '2021-09-29',
#    'team1': 'Rajasthan Royals',
#    'team2': 'Royal Challengers Bangalore',
#    'winning_team': 'Royal Challengers Bangalore',
#    'match_type': '43'},
#   {'date': '2021-09-28',
#    'team1': 'Punjab Kings',
#    'team2': 'Mumbai Indians',
#    'winning_team': 'Mumbai Indians',
#    'match_type': '42'},
#   {'date': '2021-09-28',
#    'team1': 'Delhi Capitals',
#    'team2': 'Kolkata Knight Riders',
#    'winning_team': 'Kolkata Knight Riders',
#    'match_type': '41'},
#   {'date': '2021-09-27',
#    'team1': 'Rajasthan Royals',
#    'team2': 'Sunrisers Hyderabad',
#    'winning_team': 'Sunrisers Hyderabad',
#    'match_type': '40'},
#   {'date': '2021-09-26',
#    'team1': 'Kolkata Knight Riders',
#    'team2': 'Chennai Super Kings',
#    'winning_team': 'Chennai Super Kings',
#    'match_type': '38'},
#   {'date': '2021-09-26',
#    'team1': 'Royal Challengers Bangalore',
#    'team2': 'Mumbai Indians',
#    'winning_team': 'Royal Challengers Bangalore',
#    'match_type': '39'},
#   {'date': '2021-09-25',
#    'team1': 'Delhi Capitals',
#    'team2': 'Rajasthan Royals',
#    'winning_team': 'Delhi Capitals',
#    'match_type': '36'},
#   {'date': '2021-09-25',
#    'team1': 'Punjab Kings',
#    'team2': 'Sunrisers Hyderabad',
#    'winning_team': 'Punjab Kings',
#    'match_type': '37'},
#   {'date': '2021-09-24',
#    'team1': 'Royal Challengers Bangalore',
#    'team2': 'Chennai Super Kings',
#    'winning_team': 'Chennai Super Kings',
#    'match_type': '35'},
#   {'date': '2021-09-23',
#    'team1': 'Mumbai Indians',
#    'team2': 'Kolkata Knight Riders',
#    'winning_team': 'Kolkata Knight Riders',
#    'match_type': '34'},
#   {'date': '2021-09-22',
#    'team1': 'Sunrisers Hyderabad',
#    'team2': 'Delhi Capitals',
#    'winning_team': 'Delhi Capitals',
#    'match_type': '33'},
#   {'date': '2021-09-21',
#    'team1': 'Rajasthan Royals',
#    'team2': 'Punjab Kings',
#    'winning_team': 'Rajasthan Royals',
#    'match_type': '32'},
#   {'date': '2021-09-20',
#    'team1': 'Royal Challengers Bangalore',
#    'team2': 'Kolkata Knight Riders',
#    'winning_team': 'Kolkata Knight Riders',
#    'match_type': '31'},
#   {'date': '2021-09-19',
#    'team1': 'Chennai Super Kings',
#    'team2': 'Mumbai Indians',
#    'winning_team': 'Chennai Super Kings',
#    'match_type': '30'},
#   {'date': '2021-05-02',
#    'team1': 'Punjab Kings',
#    'team2': 'Delhi Capitals',
#    'winning_team': 'Delhi Capitals',
#    'match_type': '29'},
#   {'date': '2021-05-02',
#    'team1': 'Rajasthan Royals',
#    'team2': 'Sunrisers Hyderabad',
#    'winning_team': 'Rajasthan Royals',
#    'match_type': '28'},
#   {'date': '2021-05-01',
#    'team1': 'Chennai Super Kings',
#    'team2': 'Mumbai Indians',
#    'winning_team': 'Mumbai Indians',
#    'match_type': '27'},
#   {'date': '2021-04-30',
#    'team1': 'Punjab Kings',
#    'team2': 'Royal Challengers Bangalore',
#    'winning_team': 'Punjab Kings',
#    'match_type': '26'},
#   {'date': '2021-04-29',
#    'team1': 'Kolkata Knight Riders',
#    'team2': 'Delhi Capitals',
#    'winning_team': 'Delhi Capitals',
#    'match_type': '25'},
#   {'date': '2021-04-29',
#    'team1': 'Rajasthan Royals',
#    'team2': 'Mumbai Indians',
#    'winning_team': 'Mumbai Indians',
#    'match_type': '24'},
#   {'date': '2021-04-28',
#    'team1': 'Sunrisers Hyderabad',
#    'team2': 'Chennai Super Kings',
#    'winning_team': 'Chennai Super Kings',
#    'match_type': '23'},
#   {'date': '2021-04-27',
#    'team1': 'Royal Challengers Bangalore',
#    'team2': 'Delhi Capitals',
#    'winning_team': 'Royal Challengers Bangalore',
#    'match_type': '22'},
#   {'date': '2021-04-26',
#    'team1': 'Punjab Kings',
#    'team2': 'Kolkata Knight Riders',
#    'winning_team': 'Kolkata Knight Riders',
#    'match_type': '21'},
#   {'date': '2021-04-25',
#    'team1': 'Delhi Capitals',
#    'team2': 'Sunrisers Hyderabad',
#    'winning_team': 'Delhi Capitals',
#    'match_type': '20'},
#   {'date': '2021-04-25',
#    'team1': 'Chennai Super Kings',
#    'team2': 'Royal Challengers Bangalore',
#    'winning_team': 'Chennai Super Kings',
#    'match_type': '19'},
#   {'date': '2021-04-24',
#    'team1': 'Kolkata Knight Riders',
#    'team2': 'Rajasthan Royals',
#    'winning_team': 'Rajasthan Royals',
#    'match_type': '18'},
#   {'date': '2021-04-23',
#    'team1': 'Mumbai Indians',
#    'team2': 'Punjab Kings',
#    'winning_team': 'Punjab Kings',
#    'match_type': '17'},
#   {'date': '2021-04-22',
#    'team1': 'Rajasthan Royals',
#    'team2': 'Royal Challengers Bangalore',
#    'winning_team': 'Royal Challengers Bangalore',
#    'match_type': '16'},
#   {'date': '2021-04-21',
#    'team1': 'Chennai Super Kings',
#    'team2': 'Kolkata Knight Riders',
#    'winning_team': 'Chennai Super Kings',
#    'match_type': '15'},
#   {'date': '2021-04-21',
#    'team1': 'Punjab Kings',
#    'team2': 'Sunrisers Hyderabad',
#    'winning_team': 'Sunrisers Hyderabad',
#    'match_type': '14'},
#   {'date': '2021-04-20',
#    'team1': 'Mumbai Indians',
#    'team2': 'Delhi Capitals',
#    'winning_team': 'Delhi Capitals',
#    'match_type': '13'},
#   {'date': '2021-04-19',
#    'team1': 'Chennai Super Kings',
#    'team2': 'Rajasthan Royals',
#    'winning_team': 'Chennai Super Kings',
#    'match_type': '12'},
#   {'date': '2021-04-18',
#    'team1': 'Punjab Kings',
#    'team2': 'Delhi Capitals',
#    'winning_team': 'Delhi Capitals',
#    'match_type': '11'},
#   {'date': '2021-04-18',
#    'team1': 'Royal Challengers Bangalore',
#    'team2': 'Kolkata Knight Riders',
#    'winning_team': 'Royal Challengers Bangalore',
#    'match_type': '10'},
#   {'date': '2021-04-17',
#    'team1': 'Mumbai Indians',
#    'team2': 'Sunrisers Hyderabad',
#    'winning_team': 'Mumbai Indians',
#    'match_type': '9'},
#   {'date': '2021-04-16',
#    'team1': 'Punjab Kings',
#    'team2': 'Chennai Super Kings',
#    'winning_team': 'Chennai Super Kings',
#    'match_type': '8'},
#   {'date': '2021-04-15',
#    'team1': 'Delhi Capitals',
#    'team2': 'Rajasthan Royals',
#    'winning_team': 'Rajasthan Royals',
#    'match_type': '7'},
#   {'date': '2021-04-14',
#    'team1': 'Royal Challengers Bangalore',
#    'team2': 'Sunrisers Hyderabad',
#    'winning_team': 'Royal Challengers Bangalore',
#    'match_type': '6'},
#   {'date': '2021-04-13',
#    'team1': 'Mumbai Indians',
#    'team2': 'Kolkata Knight Riders',
#    'winning_team': 'Mumbai Indians',
#    'match_type': '5'},
#   {'date': '2021-04-12',
#    'team1': 'Punjab Kings',
#    'team2': 'Rajasthan Royals',
#    'winning_team': 'Punjab Kings',
#    'match_type': '4'},
#   {'date': '2021-04-11',
#    'team1': 'Kolkata Knight Riders',
#    'team2': 'Sunrisers Hyderabad',
#    'winning_team': 'Kolkata Knight Riders',
#    'match_type': '3'},
#   {'date': '2021-04-10',
#    'team1': 'Chennai Super Kings',
#    'team2': 'Delhi Capitals',
#    'winning_team': 'Delhi Capitals',
#    'match_type': '2'},
#   {'date': '2021-04-09',
#    'team1': 'Mumbai Indians',
#    'team2': 'Royal Challengers Bangalore',
#    'winning_team': 'Royal Challengers Bangalore',
#    'match_type': '1'}],
#  'final_match': {'date': '2021-10-15',
#   'team1': 'Chennai Super Kings',
#   'team2': 'Kolkata Knight Riders',
#   'winning_team': 'Chennai Super Kings',
#   'venue': 'Dubai International Cricket Stadium',
#   'player_of_match': 'F du Plessis'},
#  'final_winner': 'Chennai Super Kings',
#  'top_player_of_match': 'RD Gaikwad',
#  'team_performance': {'Chennai Super Kings': {'matches_played': 16,
#    'matches_won': 11,
#    'matches_lost': 5,
#    'win_rate': 68.75},
#   'Delhi Capitals': {'matches_played': 16,
#    'matches_won': 10,
#    'matches_lost': 6,
#    'win_rate': 62.5},
#   'Royal Challengers Bangalore': {'matches_played': 15,
#    'matches_won': 9,
#    'matches_lost': 6,
#    'win_rate': 60.0},
#   'Mumbai Indians': {'matches_played': 14,
#    'matches_won': 7,
#    'matches_lost': 7,
#    'win_rate': 50.0},
#   'Kolkata Knight Riders': {'matches_played': 17,
#    'matches_won': 9,
#    'matches_lost': 8,
#    'win_rate': 52.94},
#   'Sunrisers Hyderabad': {'matches_played': 14,
#    'matches_won': 3,
#    'matches_lost': 11,
#    'win_rate': 21.43},
#   'Rajasthan Royals': {'matches_played': 14,
#    'matches_won': 5,
#    'matches_lost': 9,
#    'win_rate': 35.71},
#   'Punjab Kings': {'matches_played': 14,
#    'matches_won': 6,
#    'matches_lost': 8,
#    'win_rate': 42.86}},
#  'top_venue': 'Dubai International Cricket Stadium'}

# %%
df['Season'].unique()
# Out:
# array(['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08'],
#       dtype=object)

# %%
s = df[df['Season'] == '2021']
s
# Out:
#               City        Date Season  MatchNumber  \
# ID
# 1254117      Dubai  2021-10-15   2021        Final
# 1254116    Sharjah  2021-10-13   2021  Qualifier 2
# 1254115    Sharjah  2021-10-11   2021   Eliminator
# 1254114      Dubai  2021-10-10   2021  Qualifier 1
# 1254101      Dubai  2021-10-08   2021           56
# 1254088  Abu Dhabi  2021-10-08   2021           55
# 1254106    Sharjah  2021-10-07   2021           54
# 1254094      Dubai  2021-10-07   2021           53
# 1254095  Abu Dhabi  2021-10-06   2021           52
# 1254093    Sharjah  2021-10-05   2021           51
# 1254110      Dubai  2021-10-04   2021           50
# 1254090    Sharjah  2021-10-03   2021           48
# 1254109      Dubai  2021-10-03   2021           49
# 1254112    Sharjah  2021-10-02   2021           46
# 1254089  Abu Dhabi  2021-10-02   2021           47
# 1254102      Dubai  2021-10-01   2021           45
# 1254091    Sharjah  2021-09-30   2021           44
# 1254103      Dubai  2021-09-29   2021           43
# 1254099  Abu Dhabi  2021-09-28   2021           42
# 1254092    Sharjah  2021-09-28   2021           41
# 1254100      Dubai  2021-09-27   2021           40
# 1254098  Abu Dhabi  2021-09-26   2021           38
# 1254108      Dubai  2021-09-26   2021           39
# 1254097  Abu Dhabi  2021-09-25   2021           36
# 1254107    Sharjah  2021-09-25   2021           37
# 1254113    Sharjah  2021-09-24   2021           35
# 1254096  Abu Dhabi  2021-09-23   2021           34
# 1254105      Dubai  2021-09-22   2021           33
# 1254111      Dubai  2021-09-21   2021           32
# 1254087  Abu Dhabi  2021-09-20   2021           31
# 1254104      Dubai  2021-09-19   2021           30
# 1254086  Ahmedabad  2021-05-02   2021           29
# 1254085      Delhi  2021-05-02   2021           28
# 1254084      Delhi  2021-05-01   2021           27
# 1254083  Ahmedabad  2021-04-30   2021           26
# 1254082  Ahmedabad  2021-04-29   2021           25
# 1254081      Delhi  2021-04-29   2021           24
# 1254080      Delhi  2021-04-28   2021           23
# 1254079  Ahmedabad  2021-04-27   2021           22
# 1254078  Ahmedabad  2021-04-26   2021           21
# 1254077    Chennai  2021-04-25   2021           20
# 1254076     Mumbai  2021-04-25   2021           19
# 1254075     Mumbai  2021-04-24   2021           18
# 1254074    Chennai  2021-04-23   2021           17
# 1254073     Mumbai  2021-04-22   2021           16
# 1254072     Mumbai  2021-04-21   2021           15
# 1254071    Chennai  2021-04-21   2021           14
# 1254070    Chennai  2021-04-20   2021           13
# 1254069     Mumbai  2021-04-19   2021           12
# 1254068     Mumbai  2021-04-18   2021           11
# 1254067    Chennai  2021-04-18   2021           10
# 1254066    Chennai  2021-04-17   2021            9
# 1254065     Mumbai  2021-04-16   2021            8
# 1254064     Mumbai  2021-04-15   2021            7
# 1254063    Chennai  2021-04-14   2021            6
# 1254062    Chennai  2021-04-13   2021            5
# 1254061     Mumbai  2021-04-12   2021            4
# 1254060    Chennai  2021-04-11   2021            3
# 1254059     Mumbai  2021-04-10   2021            2
# 1254058    Chennai  2021-04-09   2021            1
#
#                                Team1                        Team2  \
# ID
# 1254117          Chennai Super Kings        Kolkata Knight Riders
# 1254116               Delhi Capitals        Kolkata Knight Riders
# 1254115  Royal Challengers Bangalore        Kolkata Knight Riders
# 1254114               Delhi Capitals          Chennai Super Kings
# 1254101               Delhi Capitals  Royal Challengers Bangalore
# 1254088               Mumbai Indians          Sunrisers Hyderabad
# 1254106        Kolkata Knight Riders             Rajasthan Royals
# 1254094          Chennai Super Kings                 Punjab Kings
# 1254095          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1254093             Rajasthan Royals               Mumbai Indians
# 1254110          Chennai Super Kings               Delhi Capitals
# 1254090  Royal Challengers Bangalore                 Punjab Kings
# 1254109          Sunrisers Hyderabad        Kolkata Knight Riders
# 1254112               Mumbai Indians               Delhi Capitals
# 1254089          Chennai Super Kings             Rajasthan Royals
# 1254102        Kolkata Knight Riders                 Punjab Kings
# 1254091          Sunrisers Hyderabad          Chennai Super Kings
# 1254103             Rajasthan Royals  Royal Challengers Bangalore
# 1254099                 Punjab Kings               Mumbai Indians
# 1254092               Delhi Capitals        Kolkata Knight Riders
# 1254100             Rajasthan Royals          Sunrisers Hyderabad
# 1254098        Kolkata Knight Riders          Chennai Super Kings
# 1254108  Royal Challengers Bangalore               Mumbai Indians
# 1254097               Delhi Capitals             Rajasthan Royals
# 1254107                 Punjab Kings          Sunrisers Hyderabad
# 1254113  Royal Challengers Bangalore          Chennai Super Kings
# 1254096               Mumbai Indians        Kolkata Knight Riders
# 1254105          Sunrisers Hyderabad               Delhi Capitals
# 1254111             Rajasthan Royals                 Punjab Kings
# 1254087  Royal Challengers Bangalore        Kolkata Knight Riders
# 1254104          Chennai Super Kings               Mumbai Indians
# 1254086                 Punjab Kings               Delhi Capitals
# 1254085             Rajasthan Royals          Sunrisers Hyderabad
# 1254084          Chennai Super Kings               Mumbai Indians
# 1254083                 Punjab Kings  Royal Challengers Bangalore
# 1254082        Kolkata Knight Riders               Delhi Capitals
# 1254081             Rajasthan Royals               Mumbai Indians
# 1254080          Sunrisers Hyderabad          Chennai Super Kings
# 1254079  Royal Challengers Bangalore               Delhi Capitals
# 1254078                 Punjab Kings        Kolkata Knight Riders
# 1254077               Delhi Capitals          Sunrisers Hyderabad
# 1254076          Chennai Super Kings  Royal Challengers Bangalore
# 1254075        Kolkata Knight Riders             Rajasthan Royals
# 1254074               Mumbai Indians                 Punjab Kings
# 1254073             Rajasthan Royals  Royal Challengers Bangalore
# 1254072          Chennai Super Kings        Kolkata Knight Riders
# 1254071                 Punjab Kings          Sunrisers Hyderabad
# 1254070               Mumbai Indians               Delhi Capitals
# 1254069          Chennai Super Kings             Rajasthan Royals
# 1254068                 Punjab Kings               Delhi Capitals
# 1254067  Royal Challengers Bangalore        Kolkata Knight Riders
# 1254066               Mumbai Indians          Sunrisers Hyderabad
# 1254065                 Punjab Kings          Chennai Super Kings
# 1254064               Delhi Capitals             Rajasthan Royals
# 1254063  Royal Challengers Bangalore          Sunrisers Hyderabad
# 1254062               Mumbai Indians        Kolkata Knight Riders
# 1254061                 Punjab Kings             Rajasthan Royals
# 1254060        Kolkata Knight Riders          Sunrisers Hyderabad
# 1254059          Chennai Super Kings               Delhi Capitals
# 1254058               Mumbai Indians  Royal Challengers Bangalore
#
#                                             Venue  \
# ID
# 1254117       Dubai International Cricket Stadium
# 1254116                   Sharjah Cricket Stadium
# 1254115                   Sharjah Cricket Stadium
# 1254114       Dubai International Cricket Stadium
# 1254101       Dubai International Cricket Stadium
# 1254088          Zayed Cricket Stadium, Abu Dhabi
# 1254106                   Sharjah Cricket Stadium
# 1254094       Dubai International Cricket Stadium
# 1254095          Zayed Cricket Stadium, Abu Dhabi
# 1254093                   Sharjah Cricket Stadium
# 1254110       Dubai International Cricket Stadium
# 1254090                   Sharjah Cricket Stadium
# 1254109       Dubai International Cricket Stadium
# 1254112                   Sharjah Cricket Stadium
# 1254089          Zayed Cricket Stadium, Abu Dhabi
# 1254102       Dubai International Cricket Stadium
# 1254091                   Sharjah Cricket Stadium
# 1254103       Dubai International Cricket Stadium
# 1254099          Zayed Cricket Stadium, Abu Dhabi
# 1254092                   Sharjah Cricket Stadium
# 1254100       Dubai International Cricket Stadium
# 1254098          Zayed Cricket Stadium, Abu Dhabi
# 1254108       Dubai International Cricket Stadium
# 1254097          Zayed Cricket Stadium, Abu Dhabi
# 1254107                   Sharjah Cricket Stadium
# 1254113                   Sharjah Cricket Stadium
# 1254096          Zayed Cricket Stadium, Abu Dhabi
# 1254105       Dubai International Cricket Stadium
# 1254111       Dubai International Cricket Stadium
# 1254087          Zayed Cricket Stadium, Abu Dhabi
# 1254104       Dubai International Cricket Stadium
# 1254086          Narendra Modi Stadium, Ahmedabad
# 1254085               Arun Jaitley Stadium, Delhi
# 1254084               Arun Jaitley Stadium, Delhi
# 1254083          Narendra Modi Stadium, Ahmedabad
# 1254082          Narendra Modi Stadium, Ahmedabad
# 1254081               Arun Jaitley Stadium, Delhi
# 1254080               Arun Jaitley Stadium, Delhi
# 1254079          Narendra Modi Stadium, Ahmedabad
# 1254078          Narendra Modi Stadium, Ahmedabad
# 1254077  MA Chidambaram Stadium, Chepauk, Chennai
# 1254076                  Wankhede Stadium, Mumbai
# 1254075                  Wankhede Stadium, Mumbai
# 1254074  MA Chidambaram Stadium, Chepauk, Chennai
# 1254073                  Wankhede Stadium, Mumbai
# 1254072                  Wankhede Stadium, Mumbai
# 1254071  MA Chidambaram Stadium, Chepauk, Chennai
# 1254070  MA Chidambaram Stadium, Chepauk, Chennai
# 1254069                  Wankhede Stadium, Mumbai
# 1254068                  Wankhede Stadium, Mumbai
# 1254067  MA Chidambaram Stadium, Chepauk, Chennai
# 1254066  MA Chidambaram Stadium, Chepauk, Chennai
# 1254065                  Wankhede Stadium, Mumbai
# 1254064                  Wankhede Stadium, Mumbai
# 1254063  MA Chidambaram Stadium, Chepauk, Chennai
# 1254062  MA Chidambaram Stadium, Chepauk, Chennai
# 1254061                  Wankhede Stadium, Mumbai
# 1254060  MA Chidambaram Stadium, Chepauk, Chennai
# 1254059                  Wankhede Stadium, Mumbai
# 1254058  MA Chidambaram Stadium, Chepauk, Chennai
#
#                           TossWinner TossDecision SuperOver  \
# ID
# 1254117        Kolkata Knight Riders        field         N
# 1254116        Kolkata Knight Riders        field         N
# 1254115  Royal Challengers Bangalore          bat         N
# 1254114          Chennai Super Kings        field         N
# 1254101  Royal Challengers Bangalore        field         N
# 1254088               Mumbai Indians          bat         N
# 1254106             Rajasthan Royals        field         N
# 1254094                 Punjab Kings        field         N
# 1254095  Royal Challengers Bangalore        field         N
# 1254093               Mumbai Indians        field         N
# 1254110               Delhi Capitals        field         N
# 1254090  Royal Challengers Bangalore          bat         N
# 1254109          Sunrisers Hyderabad          bat         N
# 1254112               Delhi Capitals        field         N
# 1254089             Rajasthan Royals        field         N
# 1254102                 Punjab Kings        field         N
# 1254091          Chennai Super Kings        field         N
# 1254103  Royal Challengers Bangalore        field         N
# 1254099               Mumbai Indians        field         N
# 1254092        Kolkata Knight Riders        field         N
# 1254100             Rajasthan Royals          bat         N
# 1254098        Kolkata Knight Riders          bat         N
# 1254108               Mumbai Indians        field         N
# 1254097             Rajasthan Royals        field         N
# 1254107          Sunrisers Hyderabad        field         N
# 1254113          Chennai Super Kings        field         N
# 1254096        Kolkata Knight Riders        field         N
# 1254105          Sunrisers Hyderabad          bat         N
# 1254111                 Punjab Kings        field         N
# 1254087  Royal Challengers Bangalore          bat         N
# 1254104          Chennai Super Kings          bat         N
# 1254086               Delhi Capitals        field         N
# 1254085          Sunrisers Hyderabad        field         N
# 1254084               Mumbai Indians        field         N
# 1254083  Royal Challengers Bangalore        field         N
# 1254082               Delhi Capitals        field         N
# 1254081               Mumbai Indians        field         N
# 1254080          Sunrisers Hyderabad          bat         N
# 1254079               Delhi Capitals        field         N
# 1254078        Kolkata Knight Riders        field         N
# 1254077               Delhi Capitals          bat         Y
# 1254076          Chennai Super Kings          bat         N
# 1254075             Rajasthan Royals        field         N
# 1254074                 Punjab Kings        field         N
# 1254073  Royal Challengers Bangalore        field         N
# 1254072        Kolkata Knight Riders        field         N
# 1254071                 Punjab Kings          bat         N
# 1254070               Mumbai Indians          bat         N
# 1254069             Rajasthan Royals        field         N
# 1254068               Delhi Capitals        field         N
# 1254067  Royal Challengers Bangalore          bat         N
# 1254066               Mumbai Indians          bat         N
# 1254065          Chennai Super Kings        field         N
# 1254064             Rajasthan Royals        field         N
# 1254063          Sunrisers Hyderabad        field         N
# 1254062        Kolkata Knight Riders        field         N
# 1254061             Rajasthan Royals        field         N
# 1254060          Sunrisers Hyderabad        field         N
# 1254059               Delhi Capitals        field         N
# 1254058  Royal Challengers Bangalore        field         N
#
#                          WinningTeam      WonBy  Margin    method  \
# ID
# 1254117          Chennai Super Kings       Runs    27.0  Standard
# 1254116        Kolkata Knight Riders    Wickets     3.0  Standard
# 1254115        Kolkata Knight Riders    Wickets     4.0  Standard
# 1254114          Chennai Super Kings    Wickets     4.0  Standard
# 1254101  Royal Challengers Bangalore    Wickets     7.0  Standard
# 1254088               Mumbai Indians       Runs    42.0  Standard
# 1254106        Kolkata Knight Riders       Runs    86.0  Standard
# 1254094                 Punjab Kings    Wickets     6.0  Standard
# 1254095          Sunrisers Hyderabad       Runs     4.0  Standard
# 1254093               Mumbai Indians    Wickets     8.0  Standard
# 1254110               Delhi Capitals    Wickets     3.0  Standard
# 1254090  Royal Challengers Bangalore       Runs     6.0  Standard
# 1254109        Kolkata Knight Riders    Wickets     6.0  Standard
# 1254112               Delhi Capitals    Wickets     4.0  Standard
# 1254089             Rajasthan Royals    Wickets     7.0  Standard
# 1254102                 Punjab Kings    Wickets     5.0  Standard
# 1254091          Chennai Super Kings    Wickets     6.0  Standard
# 1254103  Royal Challengers Bangalore    Wickets     7.0  Standard
# 1254099               Mumbai Indians    Wickets     6.0  Standard
# 1254092        Kolkata Knight Riders    Wickets     3.0  Standard
# 1254100          Sunrisers Hyderabad    Wickets     7.0  Standard
# 1254098          Chennai Super Kings    Wickets     2.0  Standard
# 1254108  Royal Challengers Bangalore       Runs    54.0  Standard
# 1254097               Delhi Capitals       Runs    33.0  Standard
# 1254107                 Punjab Kings       Runs     5.0  Standard
# 1254113          Chennai Super Kings    Wickets     6.0  Standard
# 1254096        Kolkata Knight Riders    Wickets     7.0  Standard
# 1254105               Delhi Capitals    Wickets     8.0  Standard
# 1254111             Rajasthan Royals       Runs     2.0  Standard
# 1254087        Kolkata Knight Riders    Wickets     9.0  Standard
# 1254104          Chennai Super Kings       Runs    20.0  Standard
# 1254086               Delhi Capitals    Wickets     7.0  Standard
# 1254085             Rajasthan Royals       Runs    55.0  Standard
# 1254084               Mumbai Indians    Wickets     4.0  Standard
# 1254083                 Punjab Kings       Runs    34.0  Standard
# 1254082               Delhi Capitals    Wickets     7.0  Standard
# 1254081               Mumbai Indians    Wickets     7.0  Standard
# 1254080          Chennai Super Kings    Wickets     7.0  Standard
# 1254079  Royal Challengers Bangalore       Runs     1.0  Standard
# 1254078        Kolkata Knight Riders    Wickets     5.0  Standard
# 1254077               Delhi Capitals  SuperOver     0.0  Standard
# 1254076          Chennai Super Kings       Runs    69.0  Standard
# 1254075             Rajasthan Royals    Wickets     6.0  Standard
# 1254074                 Punjab Kings    Wickets     9.0  Standard
# 1254073  Royal Challengers Bangalore    Wickets    10.0  Standard
# 1254072          Chennai Super Kings       Runs    18.0  Standard
# 1254071          Sunrisers Hyderabad    Wickets     9.0  Standard
# 1254070               Delhi Capitals    Wickets     6.0  Standard
# 1254069          Chennai Super Kings       Runs    45.0  Standard
# 1254068               Delhi Capitals    Wickets     6.0  Standard
# 1254067  Royal Challengers Bangalore       Runs    38.0  Standard
# 1254066               Mumbai Indians       Runs    13.0  Standard
# 1254065          Chennai Super Kings    Wickets     6.0  Standard
# 1254064             Rajasthan Royals    Wickets     3.0  Standard
# 1254063  Royal Challengers Bangalore       Runs     6.0  Standard
# 1254062               Mumbai Indians       Runs    10.0  Standard
# 1254061                 Punjab Kings       Runs     4.0  Standard
# 1254060        Kolkata Knight Riders       Runs    10.0  Standard
# 1254059               Delhi Capitals    Wickets     7.0  Standard
# 1254058  Royal Challengers Bangalore    Wickets     2.0  Standard
#
#          Player_of_Match                                       Team1Players  \
# ID
# 1254117     F du Plessis  [RD Gaikwad, F du Plessis, RV Uthappa, MM Ali,...
# 1254116          VR Iyer  [PP Shaw, S Dhawan, MP Stoinis, SS Iyer, RR Pa...
# 1254115        SP Narine  [D Padikkal, V Kohli, KS Bharat, GJ Maxwell, A...
# 1254114       RD Gaikwad  [PP Shaw, S Dhawan, SS Iyer, AR Patel, RR Pant...
# 1254101        KS Bharat  [PP Shaw, S Dhawan, RR Pant, SS Iyer, SO Hetmy...
# 1254088     Ishan Kishan  [RG Sharma, Ishan Kishan, HH Pandya, KA Pollar...
# 1254106      Shivam Mavi  [Shubman Gill, VR Iyer, N Rana, RA Tripathi, K...
# 1254094         KL Rahul  [RD Gaikwad, F du Plessis, MM Ali, RV Uthappa,...
# 1254095    KS Williamson  [JJ Roy, Abhishek Sharma, KS Williamson, PK Ga...
# 1254093  NM Coulter-Nile  [E Lewis, YBK Jaiswal, SV Samson, S Dube, GD P...
# 1254110         AR Patel  [RD Gaikwad, F du Plessis, RV Uthappa, MM Ali,...
# 1254090       GJ Maxwell  [V Kohli, D Padikkal, DT Christian, GJ Maxwell...
# 1254109     Shubman Gill  [JJ Roy, WP Saha, KS Williamson, PK Garg, Abhi...
# 1254112         AR Patel  [RG Sharma, Q de Kock, SA Yadav, SS Tiwary, KA...
# 1254089       RD Gaikwad  [RD Gaikwad, F du Plessis, SK Raina, MM Ali, A...
# 1254102         KL Rahul  [VR Iyer, Shubman Gill, RA Tripathi, N Rana, E...
# 1254091     JR Hazlewood  [JJ Roy, WP Saha, KS Williamson, PK Garg, Abhi...
# 1254103        YS Chahal  [E Lewis, YBK Jaiswal, SV Samson, MK Lomror, L...
# 1254099       KA Pollard  [KL Rahul, Mandeep Singh, CH Gayle, AK Markram...
# 1254092        SP Narine  [SPD Smith, S Dhawan, SS Iyer, RR Pant, SO Het...
# 1254100           JJ Roy  [E Lewis, YBK Jaiswal, SV Samson, LS Livingsto...
# 1254098        RA Jadeja  [Shubman Gill, VR Iyer, RA Tripathi, EJG Morga...
# 1254108       GJ Maxwell  [V Kohli, D Padikkal, KS Bharat, GJ Maxwell, A...
# 1254097          SS Iyer  [PP Shaw, S Dhawan, SS Iyer, RR Pant, SO Hetmy...
# 1254107        JO Holder  [KL Rahul, MA Agarwal, CH Gayle, AK Markram, N...
# 1254113         DJ Bravo  [V Kohli, D Padikkal, AB de Villiers, GJ Maxwe...
# 1254096        SP Narine  [RG Sharma, Q de Kock, SA Yadav, Ishan Kishan,...
# 1254105         A Nortje  [DA Warner, WP Saha, KS Williamson, MK Pandey,...
# 1254111     Kartik Tyagi  [E Lewis, YBK Jaiswal, SV Samson, LS Livingsto...
# 1254087         CV Varun  [V Kohli, D Padikkal, KS Bharat, GJ Maxwell, A...
# 1254104       RD Gaikwad  [RD Gaikwad, F du Plessis, MM Ali, AT Rayudu, ...
# 1254086       MA Agarwal  [P Simran Singh, MA Agarwal, CH Gayle, DJ Mala...
# 1254085       JC Buttler  [JC Buttler, YBK Jaiswal, SV Samson, R Parag, ...
# 1254084       KA Pollard  [RD Gaikwad, F du Plessis, MM Ali, SK Raina, A...
# 1254083    Harpreet Brar  [KL Rahul, P Simran Singh, CH Gayle, N Pooran,...
# 1254082          PP Shaw  [N Rana, Shubman Gill, RA Tripathi, EJG Morgan...
# 1254081        Q de Kock  [JC Buttler, YBK Jaiswal, SV Samson, S Dube, D...
# 1254080       RD Gaikwad  [DA Warner, JM Bairstow, MK Pandey, KS William...
# 1254079   AB de Villiers  [V Kohli, D Padikkal, RM Patidar, GJ Maxwell, ...
# 1254078       EJG Morgan  [KL Rahul, MA Agarwal, CH Gayle, DJ Hooda, N P...
# 1254077          PP Shaw  [PP Shaw, S Dhawan, RR Pant, SPD Smith, SO Het...
# 1254076        RA Jadeja  [RD Gaikwad, F du Plessis, SK Raina, AT Rayudu...
# 1254075        CH Morris  [N Rana, Shubman Gill, RA Tripathi, SP Narine,...
# 1254074         KL Rahul  [Q de Kock, RG Sharma, Ishan Kishan, SA Yadav,...
# 1254073       D Padikkal  [JC Buttler, M Vohra, SV Samson, DA Miller, S ...
# 1254072     F du Plessis  [RD Gaikwad, F du Plessis, MM Ali, MS Dhoni, R...
# 1254071      JM Bairstow  [KL Rahul, MA Agarwal, CH Gayle, N Pooran, DJ ...
# 1254070         A Mishra  [RG Sharma, Q de Kock, SA Yadav, Ishan Kishan,...
# 1254069           MM Ali  [RD Gaikwad, F du Plessis, MM Ali, SK Raina, A...
# 1254068         S Dhawan  [KL Rahul, MA Agarwal, CH Gayle, DJ Hooda, N P...
# 1254067   AB de Villiers  [V Kohli, D Padikkal, RM Patidar, GJ Maxwell, ...
# 1254066       KA Pollard  [Q de Kock, RG Sharma, SA Yadav, Ishan Kishan,...
# 1254065        DL Chahar  [KL Rahul, MA Agarwal, CH Gayle, DJ Hooda, N P...
# 1254064       JD Unadkat  [PP Shaw, S Dhawan, AM Rahane, RR Pant, MP Sto...
# 1254063       GJ Maxwell  [V Kohli, D Padikkal, Shahbaz Ahmed, GJ Maxwel...
# 1254062        RD Chahar  [RG Sharma, Q de Kock, SA Yadav, Ishan Kishan,...
# 1254061        SV Samson  [KL Rahul, MA Agarwal, CH Gayle, DJ Hooda, N P...
# 1254060           N Rana  [N Rana, Shubman Gill, RA Tripathi, AD Russell...
# 1254059         S Dhawan  [RD Gaikwad, F du Plessis, MM Ali, SK Raina, A...
# 1254058         HV Patel  [RG Sharma, CA Lynn, SA Yadav, Ishan Kishan, H...
#
#                                               Team2Players  \
# ID
# 1254117  [Shubman Gill, VR Iyer, N Rana, SP Narine, EJG...
# 1254116  [Shubman Gill, VR Iyer, N Rana, RA Tripathi, K...
# 1254115  [Shubman Gill, VR Iyer, RA Tripathi, N Rana, S...
# 1254114  [RD Gaikwad, F du Plessis, RV Uthappa, SN Thak...
# 1254101  [V Kohli, D Padikkal, KS Bharat, AB de Villier...
# 1254088  [JJ Roy, Abhishek Sharma, MK Pandey, Mohammad ...
# 1254106  [YBK Jaiswal, LS Livingstone, SV Samson, S Dub...
# 1254094  [KL Rahul, MA Agarwal, SN Khan, M Shahrukh Kha...
# 1254095  [V Kohli, D Padikkal, DT Christian, KS Bharat,...
# 1254093  [RG Sharma, Ishan Kishan, SA Yadav, HH Pandya,...
# 1254110  [PP Shaw, S Dhawan, SS Iyer, RR Pant, RV Patel...
# 1254090  [KL Rahul, MA Agarwal, N Pooran, AK Markram, S...
# 1254109  [Shubman Gill, VR Iyer, RA Tripathi, N Rana, K...
# 1254112  [PP Shaw, S Dhawan, SPD Smith, RR Pant, SS Iye...
# 1254089  [E Lewis, YBK Jaiswal, SV Samson, S Dube, GD P...
# 1254102  [KL Rahul, MA Agarwal, N Pooran, AK Markram, D...
# 1254091  [RD Gaikwad, F du Plessis, MM Ali, SK Raina, A...
# 1254103  [V Kohli, D Padikkal, KS Bharat, GJ Maxwell, A...
# 1254099  [RG Sharma, Q de Kock, SA Yadav, SS Tiwary, HH...
# 1254092  [Shubman Gill, VR Iyer, RA Tripathi, N Rana, E...
# 1254100  [JJ Roy, WP Saha, KS Williamson, PK Garg, Abhi...
# 1254098  [RD Gaikwad, F du Plessis, MM Ali, AT Rayudu, ...
# 1254108  [RG Sharma, Q de Kock, Ishan Kishan, SA Yadav,...
# 1254097  [LS Livingstone, YBK Jaiswal, SV Samson, DA Mi...
# 1254107  [DA Warner, WP Saha, KS Williamson, MK Pandey,...
# 1254113  [RD Gaikwad, F du Plessis, MM Ali, AT Rayudu, ...
# 1254096  [Shubman Gill, VR Iyer, RA Tripathi, EJG Morga...
# 1254105  [PP Shaw, S Dhawan, SS Iyer, RR Pant, MP Stoin...
# 1254111  [KL Rahul, MA Agarwal, AK Markram, N Pooran, D...
# 1254087  [Shubman Gill, VR Iyer, AD Russell, N Rana, RA...
# 1254104  [Q de Kock, Anmolpreet Singh, SA Yadav, Ishan ...
# 1254086  [PP Shaw, S Dhawan, SPD Smith, RR Pant, SO Het...
# 1254085  [MK Pandey, JM Bairstow, KS Williamson, V Shan...
# 1254084  [Q de Kock, RG Sharma, SA Yadav, KH Pandya, KA...
# 1254083  [V Kohli, D Padikkal, RM Patidar, GJ Maxwell, ...
# 1254082  [PP Shaw, S Dhawan, RR Pant, MP Stoinis, SO He...
# 1254081  [RG Sharma, Q de Kock, SA Yadav, KH Pandya, KA...
# 1254080  [RD Gaikwad, F du Plessis, MM Ali, RA Jadeja, ...
# 1254079  [PP Shaw, S Dhawan, SPD Smith, RR Pant, MP Sto...
# 1254078  [Shubman Gill, N Rana, RA Tripathi, SP Narine,...
# 1254077  [DA Warner, JM Bairstow, KS Williamson, Virat ...
# 1254076  [V Kohli, D Padikkal, Washington Sundar, GJ Ma...
# 1254075  [JC Buttler, YBK Jaiswal, SV Samson, S Dube, R...
# 1254074  [KL Rahul, MA Agarwal, CH Gayle, DJ Hooda, N P...
# 1254073  [V Kohli, D Padikkal, GJ Maxwell, AB de Villie...
# 1254072  [N Rana, Shubman Gill, RA Tripathi, EJG Morgan...
# 1254071  [DA Warner, JM Bairstow, KS Williamson, Virat ...
# 1254070  [PP Shaw, S Dhawan, SPD Smith, Lalit Yadav, RR...
# 1254069  [JC Buttler, M Vohra, SV Samson, S Dube, DA Mi...
# 1254068  [PP Shaw, S Dhawan, SPD Smith, RR Pant, MP Sto...
# 1254067  [N Rana, Shubman Gill, RA Tripathi, EJG Morgan...
# 1254066  [DA Warner, JM Bairstow, MK Pandey, Virat Sing...
# 1254065  [RD Gaikwad, F du Plessis, MM Ali, SK Raina, A...
# 1254064  [JC Buttler, M Vohra, SV Samson, S Dube, DA Mi...
# 1254063  [WP Saha, DA Warner, MK Pandey, JM Bairstow, A...
# 1254062  [N Rana, Shubman Gill, RA Tripathi, EJG Morgan...
# 1254061  [BA Stokes, M Vohra, SV Samson, JC Buttler, S ...
# 1254060  [WP Saha, DA Warner, MK Pandey, JM Bairstow, M...
# 1254059  [PP Shaw, S Dhawan, RR Pant, MP Stoinis, SO He...
# 1254058  [Washington Sundar, V Kohli, RM Patidar, GJ Ma...
#
#                        Umpire1                Umpire2
# ID
# 1254117            Nitin Menon         RK Illingworth
# 1254116  KN Ananthapadmanabhan               MA Gough
# 1254115            CB Gaffaney              VK Sharma
# 1254114            Nitin Menon         RK Illingworth
# 1254101  KN Ananthapadmanabhan            Nitin Menon
# 1254088           Tapan Sharma              VK Sharma
# 1254106               MA Gough             HAS Khalid
# 1254094           K Srinivasan         RK Illingworth
# 1254095                 S Ravi              UV Gandhe
# 1254093           AK Chaudhary               MA Gough
# 1254110           AK Chaudhary            Nitin Menon
# 1254090  KN Ananthapadmanabhan         RK Illingworth
# 1254109          J Madanagopal               MA Gough
# 1254112           AK Chaudhary               MA Gough
# 1254089            CB Gaffaney              VK Sharma
# 1254102  KN Ananthapadmanabhan         RK Illingworth
# 1254091            Nitin Menon               YC Barde
# 1254103            AY Dandekar  KN Ananthapadmanabhan
# 1254099                 S Ravi              VK Sharma
# 1254092            Nitin Menon             HAS Khalid
# 1254100  KN Ananthapadmanabhan          Navdeep Singh
# 1254098            CB Gaffaney           Tapan Sharma
# 1254108           AK Chaudhary               MA Gough
# 1254097            CB Gaffaney              UV Gandhe
# 1254107         RK Illingworth               YC Barde
# 1254113           AK Chaudhary            Nitin Menon
# 1254096                 S Ravi              VK Sharma
# 1254105  KN Ananthapadmanabhan         RK Illingworth
# 1254111           AK Chaudhary               MA Gough
# 1254087            CB Gaffaney                 S Ravi
# 1254104            Nitin Menon         RK Illingworth
# 1254086           AK Chaudhary            AY Dandekar
# 1254085          C Shamshuddin            CB Gaffaney
# 1254084  KN Ananthapadmanabhan              CK Nandan
# 1254083                 S Ravi              VK Sharma
# 1254082           AK Chaudhary               YC Barde
# 1254081            CB Gaffaney  KN Ananthapadmanabhan
# 1254080          C Shamshuddin              CK Nandan
# 1254079                 S Ravi              VK Sharma
# 1254078             PR Reiffel               YC Barde
# 1254077            CB Gaffaney  KN Ananthapadmanabhan
# 1254076           AK Chaudhary              VK Sharma
# 1254075          Navdeep Singh                 S Ravi
# 1254074          C Shamshuddin            Nitin Menon
# 1254073          J Madanagopal                 S Ravi
# 1254072            AY Dandekar             PR Reiffel
# 1254071           K Srinivasan            Nitin Menon
# 1254070          C Shamshuddin            CB Gaffaney
# 1254069             PR Reiffel              VK Sharma
# 1254068           AK Chaudhary             PR Reiffel
# 1254067          C Shamshuddin            Nitin Menon
# 1254066            CB Gaffaney           K Srinivasan
# 1254065           AK Chaudhary            AY Dandekar
# 1254064                 S Ravi              VK Sharma
# 1254063            Nitin Menon              UV Gandhe
# 1254062          C Shamshuddin            CB Gaffaney
# 1254061           AK Chaudhary                 S Ravi
# 1254060  KN Ananthapadmanabhan            Nitin Menon
# 1254059           AK Chaudhary              VK Sharma
# 1254058  KN Ananthapadmanabhan            Nitin Menon

# %%
s['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# RD Gaikwad         4
# KL Rahul           3
# SP Narine          3
# KA Pollard         3
# GJ Maxwell         3
# AR Patel           2
# F du Plessis       2
# PP Shaw            2
# RA Jadeja          2
# S Dhawan           2
# AB de Villiers     2
# NM Coulter-Nile    1
# KS Williamson      1
# Ishan Kishan       1
# Shivam Mavi        1
# KS Bharat          1
# VR Iyer            1
# YS Chahal          1
# Shubman Gill       1
# JO Holder          1
# DJ Bravo           1
# A Nortje           1
# Kartik Tyagi       1
# CV Varun           1
# JR Hazlewood       1
# JJ Roy             1
# SS Iyer            1
# Harpreet Brar      1
# JC Buttler         1
# MA Agarwal         1
# Q de Kock          1
# CH Morris          1
# D Padikkal         1
# JM Bairstow        1
# EJG Morgan         1
# A Mishra           1
# MM Ali             1
# DL Chahar          1
# JD Unadkat         1
# RD Chahar          1
# SV Samson          1
# N Rana             1
# HV Patel           1
# Name: count, dtype: int64

# %%
df['Player_of_Match'].value_counts().to_dict()
# Out:
# {'AB de Villiers': 25,
#  'CH Gayle': 22,
#  'RG Sharma': 18,
#  'DA Warner': 18,
#  'MS Dhoni': 17,
#  'SR Watson': 16,
#  'YK Pathan': 16,
#  'KA Pollard': 14,
#  'SK Raina': 14,
#  'V Kohli': 14,
#  'G Gambhir': 13,
#  'MEK Hussey': 12,
#  'AM Rahane': 12,
#  'KL Rahul': 12,
#  'A Mishra': 12,
#  'AD Russell': 12,
#  'SP Narine': 12,
#  'V Sehwag': 11,
#  'DR Smith': 11,
#  'RA Jadeja': 11,
#  'S Dhawan': 11,
#  'JC Buttler': 10,
#  'UT Yadav': 10,
#  'AT Rayudu': 10,
#  'JH Kallis': 10,
#  'SV Samson': 9,
#  'Rashid Khan': 9,
#  'SE Marsh': 9,
#  'Harbhajan Singh': 8,
#  'GJ Maxwell': 8,
#  'JJ Bumrah': 8,
#  'SR Tendulkar': 8,
#  'RD Gaikwad': 8,
#  'HH Pandya': 8,
#  'AC Gilchrist': 7,
#  'AR Patel': 7,
#  'KD Karthik': 7,
#  'RV Uthappa': 7,
#  'F du Plessis': 7,
#  'JD Unadkat': 6,
#  'RR Pant': 6,
#  'SL Malinga': 6,
#  'Sandeep Sharma': 6,
#  'KS Williamson': 6,
#  'SS Iyer': 6,
#  'M Vijay': 6,
#  'BJ Hodge': 6,
#  'SA Yadav': 6,
#  'A Nehra': 6,
#  'YS Chahal': 6,
#  'Q de Kock': 6,
#  'PA Patel': 5,
#  'SPD Smith': 5,
#  'NM Coulter-Nile': 5,
#  'BA Stokes': 5,
#  'B Kumar': 5,
#  'AJ Finch': 5,
#  'BB McCullum': 5,
#  'JP Faulkner': 5,
#  'Yuvraj Singh': 5,
#  'Shubman Gill': 5,
#  'N Rana': 5,
#  'MK Pandey': 5,
#  'WP Saha': 5,
#  'Kuldeep Yadav': 5,
#  'DA Miller': 5,
#  'TA Boult': 5,
#  'JM Bairstow': 5,
#  'SC Ganguly': 5,
#  'DW Steyn': 5,
#  'KH Pandya': 5,
#  'KC Sangakkara': 5,
#  'DPMD Jayawardene': 5,
#  'RA Tripathi': 4,
#  'PP Shaw': 4,
#  'DJ Bravo': 4,
#  'MA Agarwal': 4,
#  'no one': 4,
#  'ML Hayden': 4,
#  'JP Duminy': 4,
#  'HV Patel': 4,
#  'SK Warne': 4,
#  'R Ashwin': 4,
#  'MP Stoinis': 4,
#  'CA Lynn': 4,
#  'CJ Anderson': 3,
#  'LRPL Taylor': 3,
#  'Mandeep Singh': 3,
#  'PP Chawla': 3,
#  'R Vinay Kumar': 3,
#  'M Vohra': 3,
#  'KP Pietersen': 3,
#  'LH Ferguson': 3,
#  'A Nortje': 3,
#  'CH Morris': 3,
#  'LMP Simmons': 3,
#  'KK Nair': 3,
#  'Ishan Kishan': 3,
#  'MK Tiwary': 3,
#  'A Symonds': 3,
#  'A Kumble': 3,
#  'L Balaji': 3,
#  'MG Johnson': 2,
#  'S Gopal': 2,
#  'AS Rajpoot': 2,
#  'VR Aaron': 2,
#  'MM Sharma': 2,
#  'AJ Tye': 2,
#  'Mohammed Siraj': 2,
#  'M Ntini': 2,
#  'PJ Cummins': 2,
#  'Harpreet Brar': 2,
#  'S Nadeem': 2,
#  'CV Varun': 2,
#  'EJG Morgan': 2,
#  'Shivam Mavi': 2,
#  'JJ Roy': 2,
#  'DL Chahar': 2,
#  'Mohammed Shami': 2,
#  'JA Morkel': 2,
#  'DE Bollinger': 2,
#  'R Tewatia': 2,
#  'M Morkel': 2,
#  'PV Tambe': 2,
#  'MC Henriques': 2,
#  'KM Jadhav': 2,
#  'R Dravid': 2,
#  'Azhar Mahmood': 2,
#  'GH Vihari': 2,
#  'SK Trivedi': 2,
#  'ST Jayasuriya': 2,
#  'SM Pollock': 2,
#  'Umran Malik': 2,
#  'MV Boucher': 2,
#  'Sohail Tanvir': 2,
#  'PC Valthaty': 2,
#  'Shakib Al Hasan': 2,
#  'GC Smith': 2,
#  'M Muralitharan': 2,
#  'BW Hilfenhaus': 2,
#  'DJ Hussey': 2,
#  'I Sharma': 2,
#  'K Rabada': 2,
#  'Avesh Khan': 2,
#  'PWH de Silva': 2,
#  'P Negi': 2,
#  'P Kumar': 2,
#  'AB Dinda': 2,
#  'MR Marsh': 2,
#  'MJ McClenaghan': 2,
#  'HM Amla': 2,
#  'MM Patel': 2,
#  'R Sharma': 2,
#  'Iqbal Abdulla': 2,
#  'B Lee': 2,
#  'IK Pathan': 2,
#  'Harmeet Singh': 2,
#  'TG Southee': 1,
#  'JC Archer': 1,
#  'SM Curran': 1,
#  'KK Ahmed': 1,
#  'PK Garg': 1,
#  'SO Hetmyer': 1,
#  'Imran Tahir': 1,
#  'KMA Paul': 1,
#  'HF Gurney': 1,
#  'AS Joseph': 1,
#  'M Jansen': 1,
#  'R Parag': 1,
#  'SP Goswami': 1,
#  'Umar Gul': 1,
#  'RP Singh': 1,
#  'RS Bopara': 1,
#  'DL Vettori': 1,
#  'CRD Fernando': 1,
#  'PP Ojha': 1,
#  'TM Dilshan': 1,
#  'HH Gibbs': 1,
#  'DP Nannes': 1,
#  'RM Patidar': 1,
#  'SN Thakur': 1,
#  'SB Jakati': 1,
#  'DR Sams': 1,
#  'Kartik Tyagi': 1,
#  'JO Holder': 1,
#  'JR Hazlewood': 1,
#  'VR Iyer': 1,
#  'D Padikkal': 1,
#  'MM Ali': 1,
#  'OF Smith': 1,
#  'KS Bharat': 1,
#  'RD Chahar': 1,
#  'CJ Jordan': 1,
#  'S Dube': 1,
#  'Mukesh Choudhary': 1,
#  'LS Livingstone': 1,
#  'Abhishek Sharma': 1,
#  'Anuj Rawat': 1,
#  'E Lewis': 1,
#  'B Stanlake': 1,
#  'SW Billings': 1,
#  'KV Sharma': 1,
#  'Washington Sundar': 1,
#  'L Ngidi': 1,
#  'Mujeeb Ur Rahman': 1,
#  'MS Gony': 1,
#  'DJG Sammy': 1,
#  'Mohsin Khan': 1,
#  'CR Brathwaite': 1,
#  'A Zampa': 1,
#  'Z Khan': 1,
#  'MA Starc': 1,
#  'GJ Bailey': 1,
#  'DJ Hooda': 1,
#  'DP Conway': 1,
#  'Mustafizur Rahman': 1,
#  'BCJ Cutting': 1,
#  'AP Tare': 1,
#  'KK Cooper': 1,
#  'LJ Wright': 1,
#  'RK Singh': 1,
#  'YBK Jaiswal': 1,
#  'TH David': 1,
#  'MN Samuels': 1,
#  'P Parameswaran': 1,
#  'KMDN Kulasekara': 1,
#  'AD Mascarenhas': 1,
#  'A Chandila': 1,
#  'MS Bisla': 1,
#  'CL White': 1,
#  'JD Ryder': 1,
#  'S Sohal': 1,
#  'J Botha': 1,
#  'BA Bhatt': 1,
#  'RE Levi': 1,
#  'S Aravind': 1,
#  'JEC Franklin': 1,
#  'S Anirudha': 1,
#  'MD Mishra': 1,
#  'RJ Harris': 1,
#  'TL Suman': 1,
#  'MJ Lumb': 1,
#  'PD Collingwood': 1,
#  'NV Ojha': 1,
#  'SB Wagh': 1,
#  'M Kartik': 1,
#  'R McLaren': 1,
#  'AA Jhunjhunwala': 1,
#  'J Theron': 1,
#  'AC Voges': 1,
#  'WPUJC Vaas': 1,
#  'LR Shukla': 1,
#  'R Bhatia': 1,
#  'S Badrinath': 1,
#  'AD Mathews': 1,
#  'A Singh': 1,
#  'Shoaib Akhtar': 1,
#  'S Sreesanth': 1,
#  'SA Asnodkar': 1,
#  'GD McGrath': 1,
#  'SM Katich': 1,
#  'JDP Oram': 1,
#  'MF Maharoof': 1}

# %% [markdown]
# ## super over matches analysis

# %%
def super_over_matches():
    # Filter matches that had a Super Over
    super_over_df = df[df['SuperOver'] == 'Y']
    
    # List of all Super Over matches
    super_over_matches = super_over_df.apply(lambda match: {
        "season": match['Season'],
        "city": match['City'],
        "date": match['Date'],
        "team1": match['Team1'],
        "team2": match['Team2'],
        "winning_team": match['WinningTeam'],
        "venue": match['Venue']
    }, axis=1).tolist()

    # Count of Super Over matches per season
    super_over_per_season = super_over_df['Season'].value_counts().to_dict()

    # Team performance in Super Overs
    teams = pd.concat([super_over_df['Team1'], super_over_df['Team2']]).unique()
    super_over_team_stats = {}

    for team in teams:
        matches_played = super_over_df[(super_over_df['Team1'] == team) | (super_over_df['Team2'] == team)].shape[0]
        matches_won = super_over_df[super_over_df['WinningTeam'] == team].shape[0]

        super_over_team_stats[team] = {
            "super_over_played": matches_played,
            "super_over_won": matches_won,
            "win_rate": round((matches_won / matches_played) * 100, 2) if matches_played > 0 else 0
        }

    # Most frequent Super Over venue
    if not super_over_df.empty:
        most_frequent_venue = super_over_df['Venue'].value_counts().idxmax()
        most_frequent_venue_count = super_over_df['Venue'].value_counts().max()
    else:
        most_frequent_venue = None
        most_frequent_venue_count = 0

    # Most thrilling Super Over match-up (teams that played Super Over the most)
    matchups = super_over_df.apply(lambda row: tuple(sorted([row['Team1'], row['Team2']])), axis=1)
    most_common_matchup = matchups.value_counts().idxmax() if not matchups.empty else None
    most_common_matchup_count = matchups.value_counts().max() if not matchups.empty else 0

    return {
        "total_super_over_matches": len(super_over_matches),
        "super_over_matches": super_over_matches,
        "super_over_per_season": super_over_per_season,
        "team_super_over_performance": super_over_team_stats,
        "most_frequent_super_over_venue": {
            "venue": most_frequent_venue,
            "matches_hosted": int(most_frequent_venue_count)
        },
        "most_thrilling_super_over_rivalry": {
            "teams": most_common_matchup,
            "times_faced": int(most_common_matchup_count)
        }
    }

# %%
super_over_matches()
# Out:
# {'total_super_over_matches': 14,
#  'super_over_matches': [{'season': '2021',
#    'city': 'Chennai',
#    'date': '2021-04-25',
#    'team1': 'Delhi Capitals',
#    'team2': 'Sunrisers Hyderabad',
#    'winning_team': 'Delhi Capitals',
#    'venue': 'MA Chidambaram Stadium, Chepauk, Chennai'},
#   {'season': '2020/21',
#    'city': 'Abu Dhabi',
#    'date': '2020-10-18',
#    'team1': 'Kolkata Knight Riders',
#    'team2': 'Sunrisers Hyderabad',
#    'winning_team': 'Kolkata Knight Riders',
#    'venue': 'Sheikh Zayed Stadium'},
#   {'season': '2020/21',
#    'city': 'Unknown',
#    'date': '2020-10-18',
#    'team1': 'Mumbai Indians',
#    'team2': 'Kings XI Punjab',
#    'winning_team': 'Kings XI Punjab',
#    'venue': 'Dubai International Cricket Stadium'},
#   {'season': '2020/21',
#    'city': 'Unknown',
#    'date': '2020-09-28',
#    'team1': 'Royal Challengers Bangalore',
#    'team2': 'Mumbai Indians',
#    'winning_team': 'Royal Challengers Bangalore',
#    'venue': 'Dubai International Cricket Stadium'},
#   {'season': '2020/21',
#    'city': 'Unknown',
#    'date': '2020-09-20',
#    'team1': 'Delhi Capitals',
#    'team2': 'Kings XI Punjab',
#    'winning_team': 'Delhi Capitals',
#    'venue': 'Dubai International Cricket Stadium'},
#   {'season': '2019',
#    'city': 'Mumbai',
#    'date': '2019-05-02',
#    'team1': 'Mumbai Indians',
#    'team2': 'Sunrisers Hyderabad',
#    'winning_team': 'Mumbai Indians',
#    'venue': 'Wankhede Stadium'},
#   {'season': '2019',
#    'city': 'Delhi',
#    'date': '2019-03-30',
#    'team1': 'Kolkata Knight Riders',
#    'team2': 'Delhi Capitals',
#    'winning_team': 'Delhi Capitals',
#    'venue': 'Arun Jaitley Stadium'},
#   {'season': '2017',
#    'city': 'Rajkot',
#    'date': '2017-04-29',
#    'team1': 'Gujarat Lions',
#    'team2': 'Mumbai Indians',
#    'winning_team': 'Mumbai Indians',
#    'venue': 'Saurashtra Cricket Association Stadium'},
#   {'season': '2015',
#    'city': 'Ahmedabad',
#    'date': '2015-04-21',
#    'team1': 'Rajasthan Royals',
#    'team2': 'Kings XI Punjab',
#    'winning_team': 'Kings XI Punjab',
#    'venue': 'Sardar Patel Stadium, Motera'},
#   {'season': '2014',
#    'city': 'Abu Dhabi',
#    'date': '2014-04-29',
#    'team1': 'Kolkata Knight Riders',
#    'team2': 'Rajasthan Royals',
#    'winning_team': 'Rajasthan Royals',
#    'venue': 'Sheikh Zayed Stadium'},
#   {'season': '2013',
#    'city': 'Bangalore',
#    'date': '2013-04-16',
#    'team1': 'Royal Challengers Bangalore',
#    'team2': 'Delhi Daredevils',
#    'winning_team': 'Royal Challengers Bangalore',
#    'venue': 'M Chinnaswamy Stadium'},
#   {'season': '2013',
#    'city': 'Hyderabad',
#    'date': '2013-04-07',
#    'team1': 'Sunrisers Hyderabad',
#    'team2': 'Royal Challengers Bangalore',
#    'winning_team': 'Sunrisers Hyderabad',
#    'venue': 'Rajiv Gandhi International Stadium, Uppal'},
#   {'season': '2009/10',
#    'city': 'Chennai',
#    'date': '2010-03-21',
#    'team1': 'Chennai Super Kings',
#    'team2': 'Kings XI Punjab',
#    'winning_team': 'Kings XI Punjab',
#    'venue': 'MA Chidambaram Stadium, Chepauk'},
#   {'season': '2009',
#    'city': 'Cape Town',
#    'date': '2009-04-23',
#    'team1': 'Kolkata Knight Riders',
#    'team2': 'Rajasthan Royals',
#    'winning_team': 'Rajasthan Royals',
#    'venue': 'Newlands'}],
#  'super_over_per_season': {'2020/21': 4,
#   '2013': 2,
#   '2019': 2,
#   '2021': 1,
#   '2017': 1,
#   '2015': 1,
#   '2014': 1,
#   '2009/10': 1,
#   '2009': 1},
#  'team_super_over_performance': {'Delhi Capitals': {'super_over_played': 3,
#    'super_over_won': 3,
#    'win_rate': 100.0},
#   'Kolkata Knight Riders': {'super_over_played': 4,
#    'super_over_won': 1,
#    'win_rate': 25.0},
#   'Mumbai Indians': {'super_over_played': 4,
#    'super_over_won': 2,
#    'win_rate': 50.0},
#   'Royal Challengers Bangalore': {'super_over_played': 3,
#    'super_over_won': 2,
#    'win_rate': 66.67},
#   'Gujarat Lions': {'super_over_played': 1,
#    'super_over_won': 0,
#    'win_rate': 0.0},
#   'Rajasthan Royals': {'super_over_played': 3,
#    'super_over_won': 2,
#    'win_rate': 66.67},
#   'Sunrisers Hyderabad': {'super_over_played': 4,
#    'super_over_won': 1,
#    'win_rate': 25.0},
#   'Chennai Super Kings': {'super_over_played': 1,
#    'super_over_won': 0,
#    'win_rate': 0.0},
#   'Kings XI Punjab': {'super_over_played': 4,
#    'super_over_won': 3,
#    'win_rate': 75.0},
#   'Delhi Daredevils': {'super_over_played': 1,
#    'super_over_won': 0,
#    'win_rate': 0.0}},
#  'most_frequent_super_over_venue': {'venue': 'Dubai International Cricket Stadium',
#   'matches_hosted': 3},
#  'most_thrilling_super_over_rivalry': {'teams': ('Kolkata Knight Riders',
#    'Rajasthan Royals'),
#   'times_faced': 2}}

# %% [markdown]
# ## Highest Victory Margins

# %%
def highest_margin_matches():
    # Convert numeric columns if needed
    df['Margin'] = pd.to_numeric(df['Margin'], errors='coerce')

    # Separate highest wins by runs and wickets
    max_run_margin = df[df['WonBy'] == 'Runs']['Margin'].max()
    max_wicket_margin = df[df['WonBy'] == 'Wickets']['Margin'].max()

    # Get matches with highest run margin
    highest_run_margin_matches = df[(df['WonBy'] == 'Runs') & (df['Margin'] == max_run_margin)].apply(lambda match: {
        "season": match['Season'],
        "winning_team": match['WinningTeam'],
        "won_by": match['WonBy'],
        "margin": match['Margin'],
        "opponent": match['Team1'] if match['WinningTeam'] != match['Team1'] else match['Team2'],
        "venue": match['Venue']
    }, axis=1).tolist()

    # Get matches with highest wicket margin
    highest_wicket_margin_matches = df[(df['WonBy'] == 'Wickets') & (df['Margin'] == max_wicket_margin)].apply(lambda match: {
        "season": match['Season'],
        "winning_team": match['WinningTeam'],
        "won_by": match['WonBy'],
        "margin": match['Margin'],
        "opponent": match['Team1'] if match['WinningTeam'] != match['Team1'] else match['Team2'],
        "venue": match['Venue']
    }, axis=1).tolist()

    # Calculate average winning margin separately for "Runs" and "Wickets"
    dominant_teams_runs = df[df['WonBy'] == 'Runs'].groupby('WinningTeam')['Margin'].mean().sort_values(ascending=False).to_dict()
    dominant_teams_wickets = df[df['WonBy'] == 'Wickets'].groupby('WinningTeam')['Margin'].mean().sort_values(ascending=False).to_dict()

    # Count how many times each team won by a large margin (let's say 50+ runs or 8+ wickets)
    large_margin_wins = df[((df['WonBy'] == 'Runs') & (df['Margin'] >= 50)) | 
                            ((df['WonBy'] == 'Wickets') & (df['Margin'] >= 8))]['WinningTeam'].value_counts().to_dict()

    # Find the venue where highest margin wins occurred the most
    venue_max_margin = df[df['Margin'].isin([max_run_margin, max_wicket_margin])]['Venue'].value_counts()
    most_frequent_high_margin_venue = venue_max_margin.idxmax() if not venue_max_margin.empty else None
    most_frequent_high_margin_count = venue_max_margin.max() if not venue_max_margin.empty else 0

    return {
        "highest_run_margin": max_run_margin,
        "highest_wicket_margin": max_wicket_margin,
        "highest_margin_matches_by_runs": highest_run_margin_matches,
        "highest_margin_matches_by_wickets": highest_wicket_margin_matches,
        "most_dominant_teams_by_runs": dominant_teams_runs,
        "most_dominant_teams_by_wickets": dominant_teams_wickets,
        "teams_with_most_large_margin_wins": large_margin_wins,
        "most_frequent_high_margin_venue": {
            "venue": most_frequent_high_margin_venue,
            "times_hosted": int(most_frequent_high_margin_count)
        }
    }

# %%
highest_margin_matches()
# Out:
# {'highest_run_margin': np.float64(146.0),
#  'highest_wicket_margin': np.float64(10.0),
#  'highest_margin_matches_by_runs': [{'season': '2017',
#    'winning_team': 'Mumbai Indians',
#    'won_by': 'Runs',
#    'margin': 146.0,
#    'opponent': 'Delhi Daredevils',
#    'venue': 'Feroz Shah Kotla'}],
#  'highest_margin_matches_by_wickets': [{'season': '2021',
#    'winning_team': 'Royal Challengers Bangalore',
#    'won_by': 'Wickets',
#    'margin': 10.0,
#    'opponent': 'Rajasthan Royals',
#    'venue': 'Wankhede Stadium, Mumbai'},
#   {'season': '2020/21',
#    'winning_team': 'Sunrisers Hyderabad',
#    'won_by': 'Wickets',
#    'margin': 10.0,
#    'opponent': 'Mumbai Indians',
#    'venue': 'Sharjah Cricket Stadium'},
#   {'season': '2020/21',
#    'winning_team': 'Mumbai Indians',
#    'won_by': 'Wickets',
#    'margin': 10.0,
#    'opponent': 'Chennai Super Kings',
#    'venue': 'Sharjah Cricket Stadium'},
#   {'season': '2020/21',
#    'winning_team': 'Chennai Super Kings',
#    'won_by': 'Wickets',
#    'margin': 10.0,
#    'opponent': 'Kings XI Punjab',
#    'venue': 'Dubai International Cricket Stadium'},
#   {'season': '2018',
#    'winning_team': 'Royal Challengers Bangalore',
#    'won_by': 'Wickets',
#    'margin': 10.0,
#    'opponent': 'Kings XI Punjab',
#    'venue': 'Holkar Cricket Stadium'},
#   {'season': '2017',
#    'winning_team': 'Kings XI Punjab',
#    'won_by': 'Wickets',
#    'margin': 10.0,
#    'opponent': 'Delhi Daredevils',
#    'venue': 'Punjab Cricket Association IS Bindra Stadium, Mohali'},
#   {'season': '2017',
#    'winning_team': 'Kolkata Knight Riders',
#    'won_by': 'Wickets',
#    'margin': 10.0,
#    'opponent': 'Gujarat Lions',
#    'venue': 'Saurashtra Cricket Association Stadium'},
#   {'season': '2016',
#    'winning_team': 'Sunrisers Hyderabad',
#    'won_by': 'Wickets',
#    'margin': 10.0,
#    'opponent': 'Gujarat Lions',
#    'venue': 'Saurashtra Cricket Association Stadium'},
#   {'season': '2015',
#    'winning_team': 'Royal Challengers Bangalore',
#    'won_by': 'Wickets',
#    'margin': 10.0,
#    'opponent': 'Delhi Daredevils',
#    'venue': 'Feroz Shah Kotla'},
#   {'season': '2013',
#    'winning_team': 'Chennai Super Kings',
#    'won_by': 'Wickets',
#    'margin': 10.0,
#    'opponent': 'Kings XI Punjab',
#    'venue': 'Punjab Cricket Association Stadium, Mohali'},
#   {'season': '2012',
#    'winning_team': 'Mumbai Indians',
#    'won_by': 'Wickets',
#    'margin': 10.0,
#    'opponent': 'Rajasthan Royals',
#    'venue': 'Sawai Mansingh Stadium'},
#   {'season': '2011',
#    'winning_team': 'Rajasthan Royals',
#    'won_by': 'Wickets',
#    'margin': 10.0,
#    'opponent': 'Mumbai Indians',
#    'venue': 'Wankhede Stadium'},
#   {'season': '2009/10',
#    'winning_team': 'Royal Challengers Bangalore',
#    'won_by': 'Wickets',
#    'margin': 10.0,
#    'opponent': 'Rajasthan Royals',
#    'venue': 'M Chinnaswamy Stadium'},
#   {'season': '2009',
#    'winning_team': 'Delhi Daredevils',
#    'won_by': 'Wickets',
#    'margin': 10.0,
#    'opponent': 'Kings XI Punjab',
#    'venue': 'Newlands'},
#   {'season': '2007/08',
#    'winning_team': 'Deccan Chargers',
#    'won_by': 'Wickets',
#    'margin': 10.0,
#    'opponent': 'Mumbai Indians',
#    'venue': 'Dr DY Patil Sports Academy'}],
#  'most_dominant_teams_by_runs': {'Chennai Super Kings': 34.49180327868852,
#   'Royal Challengers Bangalore': 33.625,
#   'Mumbai Indians': 33.04545454545455,
#   'Kolkata Knight Riders': 32.355555555555554,
#   'Delhi Capitals': 31.076923076923077,
#   'Rajasthan Royals': 30.54054054054054,
#   'Gujarat Titans': 30.25,
#   'Delhi Daredevils': 27.0,
#   'Kings XI Punjab': 25.85,
#   'Rising Pune Supergiants': 25.142857142857142,
#   'Sunrisers Hyderabad': 24.97222222222222,
#   'Punjab Kings': 24.857142857142858,
#   'Lucknow Super Giants': 24.142857142857142,
#   'Deccan Chargers': 23.38888888888889,
#   'Pune Warriors': 23.166666666666668,
#   'Kochi Tuskers Kerala': 11.5,
#   'Gujarat Lions': 1.0},
#  'most_dominant_teams_by_wickets': {'Kochi Tuskers Kerala': 7.5,
#   'Sunrisers Hyderabad': 6.7631578947368425,
#   'Delhi Daredevils': 6.5476190476190474,
#   'Deccan Chargers': 6.545454545454546,
#   'Royal Challengers Bangalore': 6.52542372881356,
#   'Kings XI Punjab': 6.4222222222222225,
#   'Rising Pune Supergiants': 6.375,
#   'Punjab Kings': 6.333333333333333,
#   'Mumbai Indians': 6.174603174603175,
#   'Kolkata Knight Riders': 6.161764705882353,
#   'Chennai Super Kings': 6.016666666666667,
#   'Pune Warriors': 6.0,
#   'Lucknow Super Giants': 6.0,
#   'Rajasthan Royals': 5.9298245614035086,
#   'Gujarat Titans': 5.75,
#   'Delhi Capitals': 5.65,
#   'Gujarat Lions': 5.416666666666667},
#  'teams_with_most_large_margin_wins': {'Royal Challengers Bangalore': 30,
#   'Chennai Super Kings': 29,
#   'Mumbai Indians': 29,
#   'Kolkata Knight Riders': 25,
#   'Rajasthan Royals': 20,
#   'Sunrisers Hyderabad': 18,
#   'Delhi Daredevils': 17,
#   'Kings XI Punjab': 16,
#   'Deccan Chargers': 5,
#   'Delhi Capitals': 4,
#   'Punjab Kings': 4,
#   'Rising Pune Supergiants': 3,
#   'Kochi Tuskers Kerala': 2,
#   'Lucknow Super Giants': 1,
#   'Gujarat Titans': 1},
#  'most_frequent_high_margin_venue': {'venue': 'Feroz Shah Kotla',
#   'times_hosted': 5}}

# %%
df[df['WonBy'].isin(['Runs',])].groupby('WinningTeam')['Margin'].mean()
# Out:
# WinningTeam
# Chennai Super Kings            34.491803
# Deccan Chargers                23.388889
# Delhi Capitals                 31.076923
# Delhi Daredevils               27.000000
# Gujarat Lions                   1.000000
# Gujarat Titans                 30.250000
# Kings XI Punjab                25.850000
# Kochi Tuskers Kerala           11.500000
# Kolkata Knight Riders          32.355556
# Lucknow Super Giants           24.142857
# Mumbai Indians                 33.045455
# Pune Warriors                  23.166667
# Punjab Kings                   24.857143
# Rajasthan Royals               30.540541
# Rising Pune Supergiants        25.142857
# Royal Challengers Bangalore    33.625000
# Sunrisers Hyderabad            24.972222
# Name: Margin, dtype: float64

# %%
df['WinningTeam'].nunique()
# Out:
# 18

# %% [markdown]
# ## season summary

# %%
def season_summary(season_year):
    season_matches = df[df['Season'] == season_year]
    if season_matches.empty:
        return {"error": "Season not found"}
    
    total_matches = len(season_matches)
    teams = list(set(season_matches['Team1'].tolist() + season_matches['Team2'].tolist()))
    venues = season_matches['Venue'].nunique()
    player_of_match_counts = season_matches['Player_of_Match'].value_counts().head(5).to_dict()
    winner = season_matches.iloc[0]['WinningTeam']
    return {
        "season": season_year,
        "total_matches": total_matches,
        "teams": teams,
        "Winner": winner,
        "unique_venues": venues,
        "top_players_of_match": player_of_match_counts
    }

# %%
season_summary('2021')
# Out:
# {'season': '2021',
#  'total_matches': 60,
#  'teams': ['Kolkata Knight Riders',
#   'Chennai Super Kings',
#   'Rajasthan Royals',
#   'Delhi Capitals',
#   'Punjab Kings',
#   'Mumbai Indians',
#   'Royal Challengers Bangalore',
#   'Sunrisers Hyderabad'],
#  'Winner': 'Chennai Super Kings',
#  'unique_venues': 7,
#  'top_players_of_match': {'RD Gaikwad': 4,
#   'KL Rahul': 3,
#   'SP Narine': 3,
#   'KA Pollard': 3,
#   'GJ Maxwell': 3}}

# %%
season_summary('2015')
# Out:
# {'season': '2015',
#  'total_matches': 59,
#  'teams': ['Kolkata Knight Riders',
#   'Chennai Super Kings',
#   'Rajasthan Royals',
#   'Kings XI Punjab',
#   'Delhi Daredevils',
#   'Mumbai Indians',
#   'Royal Challengers Bangalore',
#   'Sunrisers Hyderabad'],
#  'Winner': 'Mumbai Indians',
#  'unique_venues': 13,
#  'top_players_of_match': {'DA Warner': 4,
#   'A Nehra': 3,
#   'AD Russell': 3,
#   'AM Rahane': 3,
#   'HH Pandya': 2}}

# %% [markdown]
# ## Team Performance Analysis

# %%
def team_performance_over_seasons(team):
    team_matches = df[(df['Team1'] == team) | (df['Team2'] == team)]
    if team_matches.empty:
        return {"error": "Team not found"}
    
    performance = {}
    total_final_played,total_final_wins = 0,0
    for season in sorted(team_matches['Season'].unique()):
        season_matches = team_matches[team_matches['Season'] == season]
        matches_played = len(season_matches)
        wins_in_season = season_matches[season_matches['WinningTeam'] == team]
        matches_won = len(wins_in_season)
        # we have put "NoResults" for ties 
        matches_lost = len(season_matches[(season_matches['WinningTeam'] != team) & (season_matches['WinningTeam'] != "NoResults")])
        ties = len(season_matches[season_matches['WinningTeam']=="NoResults"])  # If ties exist
        win_rate = (matches_won / matches_played) * 100 if matches_played > 0 else 0
    
        
        avg_margin_of_victory_by_runs = wins_in_season[wins_in_season['WonBy'] == "Runs"]['Margin'].mean()
        avg_margin_of_victory_by_wickets = wins_in_season[wins_in_season['WonBy'] == "Wickets"]['Margin'].mean()
        # team1, team2, winner = season_matches.iloc[0]['Team1'], season_matches.iloc[0]['Team2'], season_matches.iloc[0]['WinningTeam']
        final_match = season_matches[season_matches['MatchNumber'] == "Final"]
        was_in_final = False
        final_winner = False
        if not final_match.empty:
            was_in_final = True
            total_final_played+=1
            if not final_match[final_match['WinningTeam']==team].empty:
                final_winner = "yes"
                total_final_wins+=1            
    
        performance[season] = {
            "matches_played": matches_played,
            "matches_won": matches_won,
            "matches_lost": matches_lost,
            "ties": ties,
            "was_in_final": was_in_final,
            "final_winner": final_winner,
            "avg_margin_of_victory_by_runs": float(round(avg_margin_of_victory_by_runs, 2)) if avg_margin_of_victory_by_runs is not None else None,
            "avg_margin_of_victory_by_wickets": float(round(avg_margin_of_victory_by_wickets, 2)) if avg_margin_of_victory_by_wickets is not None else None
        }
    
    return {team: {
        'performance' : performance,
        'total_final_played' : total_final_played,
        'total_final_wins' : total_final_wins
    }}

# %%
team_performance_over_seasons('Mumbai Indians')
# Out:
# {'Mumbai Indians': {'performance': {'2007/08': {'matches_played': 14,
#     'matches_won': 7,
#     'matches_lost': 7,
#     'ties': 0,
#     'was_in_final': False,
#     'final_winner': False,
#     'avg_margin_of_victory_by_runs': 27.0,
#     'avg_margin_of_victory_by_wickets': 8.0},
#    '2009': {'matches_played': 13,
#     'matches_won': 5,
#     'matches_lost': 8,
#     'ties': 0,
#     'was_in_final': False,
#     'final_winner': False,
#     'avg_margin_of_victory_by_runs': 34.0,
#     'avg_margin_of_victory_by_wickets': 8.0},
#    '2009/10': {'matches_played': 16,
#     'matches_won': 11,
#     'matches_lost': 5,
#     'ties': 0,
#     'was_in_final': True,
#     'final_winner': False,
#     'avg_margin_of_victory_by_runs': 46.75,
#     'avg_margin_of_victory_by_wickets': 5.33},
#    '2011': {'matches_played': 16,
#     'matches_won': 10,
#     'matches_lost': 6,
#     'ties': 0,
#     'was_in_final': False,
#     'final_winner': False,
#     'avg_margin_of_victory_by_runs': 24.2,
#     'avg_margin_of_victory_by_wickets': 6.6},
#    '2012': {'matches_played': 17,
#     'matches_won': 10,
#     'matches_lost': 7,
#     'ties': 0,
#     'was_in_final': False,
#     'final_winner': False,
#     'avg_margin_of_victory_by_runs': 18.33,
#     'avg_margin_of_victory_by_wickets': 5.57},
#    '2013': {'matches_played': 19,
#     'matches_won': 13,
#     'matches_lost': 6,
#     'ties': 0,
#     'was_in_final': True,
#     'final_winner': 'yes',
#     'avg_margin_of_victory_by_runs': 35.33,
#     'avg_margin_of_victory_by_wickets': 5.25},
#    '2014': {'matches_played': 15,
#     'matches_won': 7,
#     'matches_lost': 8,
#     'ties': 0,
#     'was_in_final': False,
#     'final_winner': False,
#     'avg_margin_of_victory_by_runs': 19.67,
#     'avg_margin_of_victory_by_wickets': 6.0},
#    '2015': {'matches_played': 16,
#     'matches_won': 10,
#     'matches_lost': 6,
#     'ties': 0,
#     'was_in_final': True,
#     'final_winner': 'yes',
#     'avg_margin_of_victory_by_runs': 20.0,
#     'avg_margin_of_victory_by_wickets': 6.67},
#    '2016': {'matches_played': 14,
#     'matches_won': 7,
#     'matches_lost': 7,
#     'ties': 0,
#     'was_in_final': False,
#     'final_winner': False,
#     'avg_margin_of_victory_by_runs': 52.5,
#     'avg_margin_of_victory_by_wickets': 6.4},
#    '2017': {'matches_played': 17,
#     'matches_won': 12,
#     'matches_lost': 5,
#     'ties': 0,
#     'was_in_final': True,
#     'final_winner': 'yes',
#     'avg_margin_of_victory_by_runs': 42.5,
#     'avg_margin_of_victory_by_wickets': 5.29},
#    '2018': {'matches_played': 14,
#     'matches_won': 6,
#     'matches_lost': 8,
#     'ties': 0,
#     'was_in_final': False,
#     'final_winner': False,
#     'avg_margin_of_victory_by_runs': 41.0,
#     'avg_margin_of_victory_by_wickets': 7.0},
#    '2019': {'matches_played': 16,
#     'matches_won': 11,
#     'matches_lost': 5,
#     'ties': 0,
#     'was_in_final': True,
#     'final_winner': 'yes',
#     'avg_margin_of_victory_by_runs': 28.33,
#     'avg_margin_of_victory_by_wickets': 5.75},
#    '2020/21': {'matches_played': 16,
#     'matches_won': 11,
#     'matches_lost': 5,
#     'ties': 0,
#     'was_in_final': True,
#     'final_winner': 'yes',
#     'avg_margin_of_victory_by_runs': 49.0,
#     'avg_margin_of_victory_by_wickets': 7.0},
#    '2021': {'matches_played': 14,
#     'matches_won': 7,
#     'matches_lost': 7,
#     'ties': 0,
#     'was_in_final': False,
#     'final_winner': False,
#     'avg_margin_of_victory_by_runs': 21.67,
#     'avg_margin_of_victory_by_wickets': 6.25},
#    '2022': {'matches_played': 14,
#     'matches_won': 4,
#     'matches_lost': 10,
#     'ties': 0,
#     'was_in_final': False,
#     'final_winner': False,
#     'avg_margin_of_victory_by_runs': 5.0,
#     'avg_margin_of_victory_by_wickets': 5.0}},
#   'total_final_played': 6,
#   'total_final_wins': 5}}

# %%
s = df[df['Season']=='2013']
team =  'Mumbai Indians'
s = s[(s['Team1']==team) | (s['Team2']==team)]
s
# Out:
#               City        Date Season  MatchNumber  \
# ID
# 598073     Kolkata  2013-05-26   2013        Final
# 598072     Kolkata  2013-05-24   2013  Qualifier 2
# 598070       Delhi  2013-05-21   2013  Qualifier 1
# 598066  Dharamsala  2013-05-18   2013           69
# 598063      Mumbai  2013-05-15   2013           66
# 598060      Mumbai  2013-05-13   2013           62
# 598055        Pune  2013-05-11   2013           58
# 598050      Mumbai  2013-05-07   2013           53
# 598046      Mumbai  2013-05-05   2013           49
# 598039   Hyderabad  2013-05-01   2013           43
# 598037      Mumbai  2013-04-29   2013           41
# 598033      Mumbai  2013-04-27   2013           37
# 598029     Kolkata  2013-04-24   2013           33
# 598024       Delhi  2013-04-21   2013           28
# 598019      Jaipur  2013-04-17   2013           23
# 598011      Mumbai  2013-04-13   2013           15
# 598006      Mumbai  2013-04-09   2013           10
# 598002     Chennai  2013-04-06   2013            5
# 597999   Bangalore  2013-04-04   2013            2
#
#                               Team1                        Team2  \
# ID
# 598073          Chennai Super Kings               Mumbai Indians
# 598072               Mumbai Indians             Rajasthan Royals
# 598070          Chennai Super Kings               Mumbai Indians
# 598066              Kings XI Punjab               Mumbai Indians
# 598063               Mumbai Indians             Rajasthan Royals
# 598060               Mumbai Indians          Sunrisers Hyderabad
# 598055                Pune Warriors               Mumbai Indians
# 598050               Mumbai Indians        Kolkata Knight Riders
# 598046               Mumbai Indians          Chennai Super Kings
# 598039          Sunrisers Hyderabad               Mumbai Indians
# 598037               Mumbai Indians              Kings XI Punjab
# 598033               Mumbai Indians  Royal Challengers Bangalore
# 598029        Kolkata Knight Riders               Mumbai Indians
# 598024             Delhi Daredevils               Mumbai Indians
# 598019             Rajasthan Royals               Mumbai Indians
# 598011               Mumbai Indians                Pune Warriors
# 598006               Mumbai Indians             Delhi Daredevils
# 598002          Chennai Super Kings               Mumbai Indians
# 597999  Royal Challengers Bangalore               Mumbai Indians
#
#                                                Venue             TossWinner  \
# ID
# 598073                                  Eden Gardens         Mumbai Indians
# 598072                                  Eden Gardens       Rajasthan Royals
# 598070                              Feroz Shah Kotla    Chennai Super Kings
# 598066  Himachal Pradesh Cricket Association Stadium         Mumbai Indians
# 598063                              Wankhede Stadium       Rajasthan Royals
# 598060                              Wankhede Stadium    Sunrisers Hyderabad
# 598055                    Subrata Roy Sahara Stadium          Pune Warriors
# 598050                              Wankhede Stadium         Mumbai Indians
# 598046                              Wankhede Stadium         Mumbai Indians
# 598039     Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 598037                              Wankhede Stadium         Mumbai Indians
# 598033                              Wankhede Stadium         Mumbai Indians
# 598029                                  Eden Gardens  Kolkata Knight Riders
# 598024                              Feroz Shah Kotla         Mumbai Indians
# 598019                        Sawai Mansingh Stadium       Rajasthan Royals
# 598011                              Wankhede Stadium         Mumbai Indians
# 598006                              Wankhede Stadium         Mumbai Indians
# 598002               MA Chidambaram Stadium, Chepauk         Mumbai Indians
# 597999                         M Chinnaswamy Stadium         Mumbai Indians
#
#        TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# ID
# 598073          bat         N               Mumbai Indians     Runs    23.0
# 598072          bat         N               Mumbai Indians  Wickets     4.0
# 598070          bat         N          Chennai Super Kings     Runs    48.0
# 598066        field         N              Kings XI Punjab     Runs    50.0
# 598063        field         N               Mumbai Indians     Runs    14.0
# 598060          bat         N               Mumbai Indians  Wickets     7.0
# 598055          bat         N               Mumbai Indians  Wickets     5.0
# 598050          bat         N               Mumbai Indians     Runs    65.0
# 598046          bat         N               Mumbai Indians     Runs    60.0
# 598039          bat         N          Sunrisers Hyderabad  Wickets     7.0
# 598037          bat         N               Mumbai Indians     Runs     4.0
# 598033          bat         N               Mumbai Indians     Runs    58.0
# 598029          bat         N               Mumbai Indians  Wickets     5.0
# 598024          bat         N             Delhi Daredevils  Wickets     9.0
# 598019          bat         N             Rajasthan Royals     Runs    87.0
# 598011          bat         N               Mumbai Indians     Runs    41.0
# 598006          bat         N               Mumbai Indians     Runs    44.0
# 598002          bat         N               Mumbai Indians     Runs     9.0
# 597999        field         N  Royal Challengers Bangalore     Runs     2.0
#
#           method  Player_of_Match  \
# ID
# 598073  Standard       KA Pollard
# 598072  Standard  Harbhajan Singh
# 598070  Standard       MEK Hussey
# 598066  Standard    Azhar Mahmood
# 598063  Standard          AP Tare
# 598060  Standard       KA Pollard
# 598055  Standard       MG Johnson
# 598050  Standard     SR Tendulkar
# 598046  Standard       MG Johnson
# 598039  Standard         I Sharma
# 598037  Standard        RG Sharma
# 598033  Standard         DR Smith
# 598029  Standard         DR Smith
# 598024  Standard         V Sehwag
# 598019  Standard        AM Rahane
# 598011  Standard        RG Sharma
# 598006  Standard       KD Karthik
# 598002  Standard       KA Pollard
# 597999  Standard         CH Gayle
#
#                                              Team1Players  \
# ID
# 598073  [MEK Hussey, M Vijay, SK Raina, S Badrinath, D...
# 598072  [DR Smith, AP Tare, KD Karthik, RG Sharma, KA ...
# 598070  [MEK Hussey, M Vijay, SK Raina, MS Dhoni, RA J...
# 598066  [AC Gilchrist, Mandeep Singh, Azhar Mahmood, S...
# 598063  [GJ Maxwell, AP Tare, KD Karthik, RG Sharma, K...
# 598060  [DR Smith, SR Tendulkar, KD Karthik, RG Sharma...
# 598055  [RV Uthappa, AJ Finch, MK Pandey, Yuvraj Singh...
# 598050  [DR Smith, SR Tendulkar, KD Karthik, RG Sharma...
# 598046  [DR Smith, SR Tendulkar, KD Karthik, KA Pollar...
# 598039  [PA Reddy, S Dhawan, KC Sangakkara, GH Vihari,...
# 598037  [DR Smith, SR Tendulkar, KD Karthik, RG Sharma...
# 598033  [DR Smith, SR Tendulkar, KD Karthik, RG Sharma...
# 598029  [YK Pathan, G Gambhir, JH Kallis, MK Tiwary, E...
# 598024  [DPMD Jayawardene, V Sehwag, DA Warner, Y Venu...
# 598019  [SR Watson, AM Rahane, DH Yagnik, STR Binny, B...
# 598011  [RT Ponting, SR Tendulkar, KD Karthik, RG Shar...
# 598006  [RT Ponting, SR Tendulkar, KD Karthik, RG Shar...
# 598002  [MEK Hussey, M Vijay, SK Raina, DJ Bravo, S Ba...
# 597999  [CH Gayle, TM Dilshan, V Kohli, MA Agarwal, DT...
#
#                                              Team2Players          Umpire1  \
# ID
# 598073  [DR Smith, AP Tare, KD Karthik, RG Sharma, AT ...  HDPK Dharmasena
# 598072  [R Dravid, AM Rahane, SR Watson, SV Samson, ST...    C Shamshuddin
# 598070  [DR Smith, AP Tare, KD Karthik, RG Sharma, KA ...         NJ Llong
# 598066  [GJ Maxwell, AP Tare, AT Rayudu, RG Sharma, KD...  HDPK Dharmasena
# 598063  [R Dravid, AM Rahane, JP Faulkner, SV Samson, ...        Asad Rauf
# 598060  [PA Patel, S Dhawan, GH Vihari, CL White, NLTC...     AK Chaudhary
# 598055  [DR Smith, SR Tendulkar, KD Karthik, RG Sharma...        Asad Rauf
# 598050  [MS Bisla, G Gambhir, JH Kallis, YK Pathan, EJ...  HDPK Dharmasena
# 598046  [MEK Hussey, M Vijay, SK Raina, S Badrinath, D...  HDPK Dharmasena
# 598039  [DR Smith, SR Tendulkar, KD Karthik, RG Sharma...        Asad Rauf
# 598037  [Mandeep Singh, SE Marsh, M Vohra, DJ Hussey, ...        Asad Rauf
# 598033  [CH Gayle, TM Dilshan, V Kohli, AB de Villiers...        Asad Rauf
# 598029  [DR Smith, SR Tendulkar, KD Karthik, RG Sharma...  HDPK Dharmasena
# 598024  [DR Smith, SR Tendulkar, KD Karthik, RG Sharma...  HDPK Dharmasena
# 598019  [SR Tendulkar, RT Ponting, KD Karthik, RG Shar...        Aleem Dar
# 598011  [AJ Finch, RV Uthappa, LRPL Taylor, Yuvraj Sin...           S Ravi
# 598006  [UBT Chand, DA Warner, DPMD Jayawardene, MC Ju...        M Erasmus
# 598002  [RT Ponting, SR Tendulkar, KD Karthik, RG Shar...        M Erasmus
# 597999  [RT Ponting, SR Tendulkar, KD Karthik, RG Shar...      VA Kulkarni
#
#               Umpire2
# ID
# 598073     SJA Taufel
# 598072     SJA Taufel
# 598070      RJ Tucker
# 598066      CK Nandan
# 598063       S Asnani
# 598060     SJA Taufel
# 598055   AK Chaudhary
# 598050         S Ravi
# 598046      CK Nandan
# 598039       S Asnani
# 598037   AK Chaudhary
# 598033       S Asnani
# 598029         S Ravi
# 598024         S Ravi
# 598019  C Shamshuddin
# 598011     SJA Taufel
# 598006    VA Kulkarni
# 598002    VA Kulkarni
# 597999  C Shamshuddin

# %% [markdown]
# ## Player career

# %%
def player_career_summary(player_name):
    # Filter matches where the player participated
    player_matches = df[
        df['Team1Players'].apply(lambda x: player_name in x) |
        df['Team2Players'].apply(lambda x: player_name in x)
    ]

    if player_matches.empty:
        return {"error": "Player not found"}   

    # Count total matches played
    total_matches_played = len(player_matches)

    # Count matches won by the player's team
    matches_won_by_team = player_matches.apply(
        lambda row: row['WinningTeam'] == (row['Team1'] if player_name in row['Team1Players'] else row['Team2']),
        axis=1
    ).sum()
    player_of_match = len(player_matches[player_matches['Player_of_Match'] == player_name])
    
     # Win percentage
    win_percentage = round((matches_won_by_team / total_matches_played) * 100, 2) if total_matches_played > 0 else 0

    # Teams played for
    teams_played_for = set(
        player_matches.apply(lambda row: row['Team1'] if player_name in row['Team1Players'] else row['Team2'], axis=1)
    )

    # Performance across seasons
    season_wise_stats = player_matches.groupby('Season').apply(
        lambda x: {
            "team": x.iloc[0]['Team1'] if player_name in x.iloc[0]['Team1Players'] else x.iloc[0]['Team2'],  # Extract team name
            "matches_played": len(x),
            "matches_won_by_team": int((x['WinningTeam'] == (x.iloc[0]['Team1'] if player_name in x.iloc[0]['Team1Players'] else x.iloc[0]['Team2'])).sum()),
            "win_rate": float(round((x['WinningTeam'] == (x.iloc[0]['Team1'] if player_name in x.iloc[0]['Team1Players'] else x.iloc[0]['Team2'])).sum() / len(x) * 100, 2))
        }
    ).to_dict()

    # Performance in finals
    finals_matches = player_matches[player_matches['MatchNumber'] == 'Final']
    finals_won = finals_matches.apply(
        lambda row: row['WinningTeam'] == (row['Team1'] if player_name in row['Team1Players'] else row['Team2']), axis=1
    ).sum()    

    return {
        "player_name": player_name,
        "total_matches_played": total_matches_played,
        "matches_won_by_team": int(matches_won_by_team),
        "win_percentage": win_percentage,
        "player_of_match_awards": player_of_match,
        "teams_played_for": list(teams_played_for),
        "season_wise_performance": season_wise_stats,
        "finals_played": len(finals_matches),
        "finals_won": int(finals_won)
    }

# %%
player_name = 'HH Pandya'
player_career_summary(player_name)
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_64412\4022679346.py:30: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   season_wise_stats = player_matches.groupby('Season').apply(
# {'player_name': 'HH Pandya',
#  'total_matches_played': 107,
#  'matches_won_by_team': 69,
#  'win_percentage': np.float64(64.49),
#  'player_of_match_awards': 8,
#  'teams_played_for': ['Mumbai Indians', 'Gujarat Titans'],
#  'season_wise_performance': {'2015': {'team': 'Mumbai Indians',
#    'matches_played': 9,
#    'matches_won_by_team': 7,
#    'win_rate': 77.78},
#   '2016': {'team': 'Mumbai Indians',
#    'matches_played': 11,
#    'matches_won_by_team': 5,
#    'win_rate': 45.45},
#   '2017': {'team': 'Mumbai Indians',
#    'matches_played': 17,
#    'matches_won_by_team': 12,
#    'win_rate': 70.59},
#   '2018': {'team': 'Mumbai Indians',
#    'matches_played': 13,
#    'matches_won_by_team': 6,
#    'win_rate': 46.15},
#   '2019': {'team': 'Mumbai Indians',
#    'matches_played': 16,
#    'matches_won_by_team': 11,
#    'win_rate': 68.75},
#   '2020/21': {'team': 'Mumbai Indians',
#    'matches_played': 14,
#    'matches_won_by_team': 10,
#    'win_rate': 71.43},
#   '2021': {'team': 'Mumbai Indians',
#    'matches_played': 12,
#    'matches_won_by_team': 7,
#    'win_rate': 58.33},
#   '2022': {'team': 'Gujarat Titans',
#    'matches_played': 15,
#    'matches_won_by_team': 11,
#    'win_rate': 73.33}},
#  'finals_played': 5,
#  'finals_won': 5}

# %%
x = df.copy()

# %%
x = x[(x['Team1Players'].apply(lambda name : player_name in name)) | (x['Team2Players'].apply(lambda name : player_name in name))]

# %%
x['Team'] = x.apply(lambda row : row['Team1'] if player_name in row['Team1Players'] else row['Team2'] if player_name in row['Team2Players'] else None, axis=1)

# %%
x
# Out:
#               City        Date Season  MatchNumber  \
# ID
# 1312200  Ahmedabad  2022-05-29   2022        Final
# 1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 1304113     Mumbai  2022-05-19   2022           67
# 1304108     Mumbai  2022-05-15   2022           62
# 1304103       Pune  2022-05-10   2022           57
# ...            ...         ...    ...          ...
# 829795      Mumbai  2015-05-10   2015           46
# 829789     Chennai  2015-05-08   2015           43
# 829783      Mumbai  2015-05-05   2015           39
# 829747       Delhi  2015-04-23   2015           21
# 829737   Bangalore  2015-04-19   2015           16
#
#                                Team1                        Team2  \
# ID
# 1312200             Rajasthan Royals               Gujarat Titans
# 1312197             Rajasthan Royals               Gujarat Titans
# 1304113               Gujarat Titans  Royal Challengers Bangalore
# 1304108          Chennai Super Kings               Gujarat Titans
# 1304103               Gujarat Titans         Lucknow Super Giants
# ...                              ...                          ...
# 829795                Mumbai Indians  Royal Challengers Bangalore
# 829789           Chennai Super Kings               Mumbai Indians
# 829783                Mumbai Indians             Delhi Daredevils
# 829747              Delhi Daredevils               Mumbai Indians
# 829737   Royal Challengers Bangalore               Mumbai Indians
#
#                                                  Venue  \
# ID
# 1312200               Narendra Modi Stadium, Ahmedabad
# 1312197                          Eden Gardens, Kolkata
# 1304113                       Wankhede Stadium, Mumbai
# 1304108                       Wankhede Stadium, Mumbai
# 1304103  Maharashtra Cricket Association Stadium, Pune
# ...                                                ...
# 829795                                Wankhede Stadium
# 829789                 MA Chidambaram Stadium, Chepauk
# 829783                                Wankhede Stadium
# 829747                                Feroz Shah Kotla
# 829737                           M Chinnaswamy Stadium
#
#                           TossWinner TossDecision SuperOver  \
# ID
# 1312200             Rajasthan Royals          bat         N
# 1312197               Gujarat Titans        field         N
# 1304113               Gujarat Titans          bat         N
# 1304108          Chennai Super Kings          bat         N
# 1304103               Gujarat Titans          bat         N
# ...                              ...          ...       ...
# 829795   Royal Challengers Bangalore          bat         N
# 829789           Chennai Super Kings          bat         N
# 829783              Delhi Daredevils          bat         N
# 829747                Mumbai Indians        field         N
# 829737   Royal Challengers Bangalore        field         N
#
#                          WinningTeam    WonBy  Margin    method  \
# ID
# 1312200               Gujarat Titans  Wickets     7.0  Standard
# 1312197               Gujarat Titans  Wickets     7.0  Standard
# 1304113  Royal Challengers Bangalore  Wickets     8.0  Standard
# 1304108               Gujarat Titans  Wickets     7.0  Standard
# 1304103               Gujarat Titans     Runs    62.0  Standard
# ...                              ...      ...     ...       ...
# 829795   Royal Challengers Bangalore     Runs    39.0  Standard
# 829789                Mumbai Indians  Wickets     6.0  Standard
# 829783                Mumbai Indians  Wickets     5.0  Standard
# 829747              Delhi Daredevils     Runs    37.0  Standard
# 829737                Mumbai Indians     Runs    18.0  Standard
#
#          Player_of_Match                                       Team1Players  \
# ID
# 1312200        HH Pandya  [YBK Jaiswal, JC Buttler, SV Samson, D Padikka...
# 1312197        DA Miller  [YBK Jaiswal, JC Buttler, SV Samson, D Padikka...
# 1304113          V Kohli  [WP Saha, Shubman Gill, MS Wade, HH Pandya, DA...
# 1304108          WP Saha  [RD Gaikwad, DP Conway, MM Ali, N Jagadeesan, ...
# 1304103     Shubman Gill  [WP Saha, Shubman Gill, MS Wade, HH Pandya, DA...
# ...                  ...                                                ...
# 829795    AB de Villiers  [PA Patel, LMP Simmons, RG Sharma, KA Pollard,...
# 829789         HH Pandya  [DR Smith, BB McCullum, SK Raina, F du Plessis...
# 829783   Harbhajan Singh  [LMP Simmons, PA Patel, HH Pandya, RG Sharma, ...
# 829747           SS Iyer  [MA Agarwal, SS Iyer, JP Duminy, AD Mathews, Y...
# 829737   Harbhajan Singh  [CH Gayle, MS Bisla, V Kohli, KD Karthik, AB d...
#
#                                               Team2Players  \
# ID
# 1312200  [WP Saha, Shubman Gill, MS Wade, HH Pandya, DA...
# 1312197  [WP Saha, Shubman Gill, MS Wade, HH Pandya, DA...
# 1304113  [V Kohli, F du Plessis, GJ Maxwell, KD Karthik...
# 1304108  [WP Saha, Shubman Gill, MS Wade, HH Pandya, DA...
# 1304103  [Q de Kock, KL Rahul, DJ Hooda, KS Sharma, KH ...
# ...                                                    ...
# 829795   [CH Gayle, V Kohli, AB de Villiers, KD Karthik...
# 829789   [LMP Simmons, PA Patel, RG Sharma, KA Pollard,...
# 829783   [MA Agarwal, SS Iyer, JP Duminy, KM Jadhav, Yu...
# 829747   [LMP Simmons, PA Patel, UBT Chand, RG Sharma, ...
# 829737   [LMP Simmons, PA Patel, UBT Chand, RG Sharma, ...
#
#                        Umpire1           Umpire2            Team
# ID
# 1312200            CB Gaffaney       Nitin Menon  Gujarat Titans
# 1312197           BNJ Oxenford         VK Sharma  Gujarat Titans
# 1304113  KN Ananthapadmanabhan  GR Sadashiv Iyer  Gujarat Titans
# 1304108               R Pandit         VK Sharma  Gujarat Titans
# 1304103  KN Ananthapadmanabhan          MA Gough  Gujarat Titans
# ...                        ...               ...             ...
# 829795               JD Cloete     C Shamshuddin  Mumbai Indians
# 829789             CB Gaffaney         CK Nandan  Mumbai Indians
# 829783         HDPK Dharmasena       CB Gaffaney  Mumbai Indians
# 829747                  SD Fry         CK Nandan  Mumbai Indians
# 829737          RK Illingworth       VA Kulkarni  Mumbai Indians
#
# [107 rows x 20 columns]

# %%
x['Team'].value_counts()
# Out:
# Team
# Mumbai Indians    92
# Gujarat Titans    15
# Name: count, dtype: int64

# %%
x[x['WinningTeam'] == x['Team']]
# Out:
#               City        Date Season  MatchNumber  \
# ID
# 1312200  Ahmedabad  2022-05-29   2022        Final
# 1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 1304108     Mumbai  2022-05-15   2022           62
# 1304103       Pune  2022-05-10   2022           57
# 1304089     Mumbai  2022-04-30   2022           43
# ...            ...         ...    ...          ...
# 829815   Hyderabad  2015-05-17   2015           56
# 829805      Mumbai  2015-05-14   2015           51
# 829789     Chennai  2015-05-08   2015           43
# 829783      Mumbai  2015-05-05   2015           39
# 829737   Bangalore  2015-04-19   2015           16
#
#                                Team1                  Team2  \
# ID
# 1312200             Rajasthan Royals         Gujarat Titans
# 1312197             Rajasthan Royals         Gujarat Titans
# 1304108          Chennai Super Kings         Gujarat Titans
# 1304103               Gujarat Titans   Lucknow Super Giants
# 1304089  Royal Challengers Bangalore         Gujarat Titans
# ...                              ...                    ...
# 829815           Sunrisers Hyderabad         Mumbai Indians
# 829805                Mumbai Indians  Kolkata Knight Riders
# 829789           Chennai Super Kings         Mumbai Indians
# 829783                Mumbai Indians       Delhi Daredevils
# 829737   Royal Challengers Bangalore         Mumbai Indians
#
#                                                  Venue  \
# ID
# 1312200               Narendra Modi Stadium, Ahmedabad
# 1312197                          Eden Gardens, Kolkata
# 1304108                       Wankhede Stadium, Mumbai
# 1304103  Maharashtra Cricket Association Stadium, Pune
# 1304089                      Brabourne Stadium, Mumbai
# ...                                                ...
# 829815       Rajiv Gandhi International Stadium, Uppal
# 829805                                Wankhede Stadium
# 829789                 MA Chidambaram Stadium, Chepauk
# 829783                                Wankhede Stadium
# 829737                           M Chinnaswamy Stadium
#
#                           TossWinner TossDecision SuperOver     WinningTeam  \
# ID
# 1312200             Rajasthan Royals          bat         N  Gujarat Titans
# 1312197               Gujarat Titans        field         N  Gujarat Titans
# 1304108          Chennai Super Kings          bat         N  Gujarat Titans
# 1304103               Gujarat Titans          bat         N  Gujarat Titans
# 1304089  Royal Challengers Bangalore          bat         N  Gujarat Titans
# ...                              ...          ...       ...             ...
# 829815           Sunrisers Hyderabad          bat         N  Mumbai Indians
# 829805         Kolkata Knight Riders        field         N  Mumbai Indians
# 829789           Chennai Super Kings          bat         N  Mumbai Indians
# 829783              Delhi Daredevils          bat         N  Mumbai Indians
# 829737   Royal Challengers Bangalore        field         N  Mumbai Indians
#
#            WonBy  Margin    method  Player_of_Match  \
# ID
# 1312200  Wickets     7.0  Standard        HH Pandya
# 1312197  Wickets     7.0  Standard        DA Miller
# 1304108  Wickets     7.0  Standard          WP Saha
# 1304103     Runs    62.0  Standard     Shubman Gill
# 1304089  Wickets     6.0  Standard        R Tewatia
# ...          ...     ...       ...              ...
# 829815   Wickets     9.0  Standard   MJ McClenaghan
# 829805      Runs     5.0  Standard        HH Pandya
# 829789   Wickets     6.0  Standard        HH Pandya
# 829783   Wickets     5.0  Standard  Harbhajan Singh
# 829737      Runs    18.0  Standard  Harbhajan Singh
#
#                                               Team1Players  \
# ID
# 1312200  [YBK Jaiswal, JC Buttler, SV Samson, D Padikka...
# 1312197  [YBK Jaiswal, JC Buttler, SV Samson, D Padikka...
# 1304108  [RD Gaikwad, DP Conway, MM Ali, N Jagadeesan, ...
# 1304103  [WP Saha, Shubman Gill, MS Wade, HH Pandya, DA...
# 1304089  [V Kohli, F du Plessis, RM Patidar, GJ Maxwell...
# ...                                                    ...
# 829815   [DA Warner, S Dhawan, MC Henriques, EJG Morgan...
# 829805   [LMP Simmons, PA Patel, RG Sharma, AT Rayudu, ...
# 829789   [DR Smith, BB McCullum, SK Raina, F du Plessis...
# 829783   [LMP Simmons, PA Patel, HH Pandya, RG Sharma, ...
# 829737   [CH Gayle, MS Bisla, V Kohli, KD Karthik, AB d...
#
#                                               Team2Players  \
# ID
# 1312200  [WP Saha, Shubman Gill, MS Wade, HH Pandya, DA...
# 1312197  [WP Saha, Shubman Gill, MS Wade, HH Pandya, DA...
# 1304108  [WP Saha, Shubman Gill, MS Wade, HH Pandya, DA...
# 1304103  [Q de Kock, KL Rahul, DJ Hooda, KS Sharma, KH ...
# 1304089  [WP Saha, Shubman Gill, B Sai Sudharsan, HH Pa...
# ...                                                    ...
# 829815   [LMP Simmons, PA Patel, RG Sharma, AT Rayudu, ...
# 829805   [RV Uthappa, G Gambhir, MK Pandey, YK Pathan, ...
# 829789   [LMP Simmons, PA Patel, RG Sharma, KA Pollard,...
# 829783   [MA Agarwal, SS Iyer, JP Duminy, KM Jadhav, Yu...
# 829737   [LMP Simmons, PA Patel, UBT Chand, RG Sharma, ...
#
#                        Umpire1      Umpire2            Team
# ID
# 1312200            CB Gaffaney  Nitin Menon  Gujarat Titans
# 1312197           BNJ Oxenford    VK Sharma  Gujarat Titans
# 1304108               R Pandit    VK Sharma  Gujarat Titans
# 1304103  KN Ananthapadmanabhan     MA Gough  Gujarat Titans
# 1304089             HAS Khalid    VK Sharma  Gujarat Titans
# ...                        ...          ...             ...
# 829815             CB Gaffaney    K Srinath  Mumbai Indians
# 829805          RK Illingworth  VA Kulkarni  Mumbai Indians
# 829789             CB Gaffaney    CK Nandan  Mumbai Indians
# 829783         HDPK Dharmasena  CB Gaffaney  Mumbai Indians
# 829737          RK Illingworth  VA Kulkarni  Mumbai Indians
#
# [69 rows x 20 columns]
